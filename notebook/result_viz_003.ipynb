# %%
# parameters
config_dir = "../experiments"
exp_name = "084_q_log_same_scale/base"

# %%
# %cd /kaggle/working

from pathlib import Path

from hydra import compose, initialize
from omegaconf import OmegaConf

with initialize(
    version_base=None, config_path=f"{config_dir}/{exp_name.split('/')[0]}"
):
    cfg = compose(
        config_name="config.yaml",
        overrides=[f"exp={exp_name.split('/')[-1]}"],
        return_hydra_config=True,
    )
import pickle

import matplotlib.pyplot as plt
import numpy as np
import polars as pl
import seaborn as sns

# 定数定義
output_dir = Path(f"output/experiments/{exp_name}")
gcs_path = f"gs://{cfg.dir.gcs_bucket}/{cfg.dir.gcs_base_dir}/experiments/{exp_name}/"

# カラムの定義
single_targets = [
    "cam_out_NETSW",
    "cam_out_FLWDS",
    "cam_out_PRECSC",
    "cam_out_PRECC",
    "cam_out_SOLS",
    "cam_out_SOLL",
    "cam_out_SOLSD",
    "cam_out_SOLLD",
]
seq_targets = [
    "ptend_t",
    "ptend_q0001",
    "ptend_q0002",
    "ptend_q0003",
    "ptend_u",
    "ptend_v",
]
target_columns = []
for col in seq_targets:
    for i in range(60):
        target_columns.append(f"{col}_{i}")
target_columns.extend(single_targets)


# 結果などの読み込み
r2_score_dict = pickle.load(open(output_dir / "r2_score_dict.pkl", "rb"))
print("read predict")
predict_df = pl.read_parquet(gcs_path + "predict.parquet", retries=5)
print("read label")
label_df = pl.read_parquet(gcs_path + "label.parquet", retries=5)
ss_df = pl.read_csv(
    "input/leap-atmospheric-physics-ai-climsim/sample_submission.csv", n_rows=1
)
weight_array = ss_df.select([x for x in ss_df.columns if x != "sample_id"]).to_numpy()[
    0
]
# Out:
# /kaggle/working
# read predict
# read label

# %% [markdown]
# ## 全体概要

# %%
print("r2: ", np.mean(list(r2_score_dict.values())))
# Out:
# r2:  -4.6087494943490054e+17

# %% [markdown]
# ## sequential target

# %%
for col in seq_targets:
    fig, ax = plt.subplots(figsize=(8, 4))

    sns.scatterplot(
        x=range(60),
        y=[r2_score_dict[f"{col}_{i}"] for i in range(60)],
        label="R2 scores",
        ax=ax,
    )
    sns.scatterplot(
        x=range(60),
        y=[(ss_df[f"{col}_{i}"].to_numpy()[0] != 0) for i in range(60)],
        alpha=0.5,
        label="ss_weight != 0",
        ax=ax,
    )

    ax.set_title(f"{col}, 60 values")
    ax.grid(True)
    ax.set_ylim(-0.1, 1.1)
    ax.legend()

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## single target

# %%
# single scaler target
plt.figure(figsize=(16, 5))
sns.set(style="whitegrid")

sns.barplot(
    x=np.array(single_targets),
    y=np.array([r2_score_dict[col] for col in single_targets]),
)

plt.xlabel("Single Targets")
plt.ylabel("R2 Scores")
plt.title("R2 Scores for Single Targets")

for col in single_targets:
    print(f"{col} : {r2_score_dict[col]}")

plt.tight_layout()
plt.show()
# Out:
# cam_out_NETSW : -0.0004632527263075392
# cam_out_FLWDS : -0.026932142972126316
# cam_out_PRECSC : -0.006649590681109707
# cam_out_PRECC : -0.006255311105635153
# cam_out_SOLS : -3.5019418796133905e-05
# cam_out_SOLL : -8.08947395976034e-05
# cam_out_SOLSD : -0.00021759913062413538
# cam_out_SOLLD : -1.16339496163409e-05

# %% [markdown]
# ## マイナスが大きいターゲットについて確認

# %%
preds = predict_df[:, 1:].to_numpy()
labels = label_df[:, 1:].to_numpy()

scale_dir = ""
y_nanmean = np.load(Path(cfg.exp.scale_dir) / "y_nanmean.npy")
y_rms_sub = np.load(Path(cfg.exp.scale_dir) / "y_rms_sub.npy")
y_lower_bound = np.load(Path(cfg.exp.scale_dir) / "y_nanmin.npy")
y_upper_bound = np.load(Path(cfg.exp.scale_dir) / "y_nanmax.npy")


for ci, col in enumerate(target_columns):
    r2_score = r2_score_dict[col]
    if r2_score > 0.01:
        continue

    print("【", col, "】")
    print(f"{r2_score=:.5g}")

    mse = (preds[:, ci] - labels[:, ci]) ** 2
    base = (labels[:, ci] - labels[:, ci].mean()) ** 2
    ri = np.nonzero(mse == np.max(mse))[0][0]
    print(f"{ri=}, {ci=}")
    print(f"{preds[ri,ci]=:.5g}, {labels[ri,ci]=:.5g}")
    print(f"{mse[ri]=:.5g}, r2: 1-({mse.mean()=:.5g})/({base.mean()=:.5g})")

    print(
        f"{y_rms_sub[ci]=:.5g}, {y_nanmean[ci]=:.5g}, {y_lower_bound[ci]=:.5g}, {y_upper_bound[ci]=:.5g}"
    )
    print(
        f"{preds[:,ci].mean()=:.5g}, {preds[:,ci].min()=:.5g}, {preds[:,ci].max()=:.5g}"
    )
    print(
        f"{labels[:,ci].mean()=:.5g}, {labels[:,ci].min()=:.5g}, {labels[:,ci].max()=:.5g}"
    )
    print()
# Out:
# 【 ptend_t_0 】
# r2_score=-0.020982
# ri=80, ci=0
# preds[ri,ci]=3.0149e-05, labels[ri,ci]=-2.9155e-05
# mse[ri]=3.517e-09, r2: 1-(mse.mean()=6.9864e-10)/(base.mean()=6.8428e-10)
# y_rms_sub[ci]=3.2278e-05, y_nanmean[ci]=1.0293e-05, y_lower_bound[ci]=-0.0020301, y_upper_bound[ci]=0.00794
# preds[:,ci].mean()=1.5914e-05, preds[:,ci].min()=5.9916e-07, preds[:,ci].max()=3.1056e-05
# labels[:,ci].mean()=1.119e-05, labels[:,ci].min()=-4.3717e-05, labels[:,ci].max()=5.9823e-05
#
# 【 ptend_t_1 】
# r2_score=-0.097995
# ri=353, ci=1
# preds[ri,ci]=9.0533e-07, labels[ri,ci]=-0.00013155
# mse[ri]=1.7544e-08, r2: 1-(mse.mean()=2.4005e-09)/(base.mean()=2.1862e-09)
# y_rms_sub[ci]=4.444e-05, y_nanmean[ci]=-7.0281e-06, y_lower_bound[ci]=-0.0037861, y_upper_bound[ci]=0.021563
# preds[:,ci].mean()=5.4132e-06, preds[:,ci].min()=-1.8455e-05, preds[:,ci].max()=2.4775e-05
# labels[:,ci].mean()=-1.2631e-05, labels[:,ci].min()=-0.00013155, labels[:,ci].max()=7.682e-05
#
# 【 ptend_t_2 】
# r2_score=0.0048213
# ri=348, ci=2
# preds[ri,ci]=-8.5951e-07, labels[ri,ci]=-0.00014766
# mse[ri]=2.1551e-08, r2: 1-(mse.mean()=3.2787e-09)/(base.mean()=3.2946e-09)
# y_rms_sub[ci]=5.2926e-05, y_nanmean[ci]=-3.1783e-06, y_lower_bound[ci]=-0.006704, y_upper_bound[ci]=0.0035969
# preds[:,ci].mean()=1.3565e-05, preds[:,ci].min()=-1.5602e-05, preds[:,ci].max()=3.7187e-05
# labels[:,ci].mean()=-6.0102e-06, labels[:,ci].min()=-0.00014766, labels[:,ci].max()=8.4963e-05
#
# 【 ptend_t_3 】
# r2_score=-0.02784
# ri=343, ci=3
# preds[ri,ci]=5.0322e-05, labels[ri,ci]=-0.00010035
# mse[ri]=2.2703e-08, r2: 1-(mse.mean()=5.105e-09)/(base.mean()=4.9668e-09)
# y_rms_sub[ci]=6.8898e-05, y_nanmean[ci]=-3.1923e-06, y_lower_bound[ci]=-0.0043876, y_upper_bound[ci]=0.00019506
# preds[:,ci].mean()=2.1023e-05, preds[:,ci].min()=-1.9218e-05, preds[:,ci].max()=5.3333e-05
# labels[:,ci].mean()=-3.6777e-06, labels[:,ci].min()=-0.00012878, labels[:,ci].max()=0.00010731
#
# 【 ptend_t_4 】
# r2_score=-0.066879
# ri=99, ci=4
# preds[ri,ci]=5.4757e-05, labels[ri,ci]=-9.4657e-05
# mse[ri]=2.2325e-08, r2: 1-(mse.mean()=8.8339e-09)/(base.mean()=8.2801e-09)
# y_rms_sub[ci]=9.1371e-05, y_nanmean[ci]=-3.6305e-06, y_lower_bound[ci]=-0.00034036, y_upper_bound[ci]=0.00019247
# preds[:,ci].mean()=3.0973e-05, preds[:,ci].min()=-2.4018e-05, preds[:,ci].max()=7.354e-05
# labels[:,ci].mean()=-2.584e-06, labels[:,ci].min()=-0.00010922, labels[:,ci].max()=0.00013952
#
# 【 ptend_t_5 】
# r2_score=-0.08691
# ri=102, ci=5
# preds[ri,ci]=7.1369e-05, labels[ri,ci]=-0.00011268
# mse[ri]=3.3874e-08, r2: 1-(mse.mean()=1.3784e-08)/(base.mean()=1.2681e-08)
# y_rms_sub[ci]=0.00011031, y_nanmean[ci]=-2.223e-06, y_lower_bound[ci]=-0.00028664, y_upper_bound[ci]=0.00025084
# preds[:,ci].mean()=4.1866e-05, preds[:,ci].min()=-2.2175e-05, preds[:,ci].max()=7.9668e-05
# labels[:,ci].mean()=-1.7908e-07, labels[:,ci].min()=-0.00012817, labels[:,ci].max()=0.00020203
#
# 【 ptend_t_6 】
# r2_score=-0.12494
# ri=155, ci=6
# preds[ri,ci]=5.1265e-05, labels[ri,ci]=0.0002236
# mse[ri]=2.9698e-08, r2: 1-(mse.mean()=1.2707e-08)/(base.mean()=1.1295e-08)
# y_rms_sub[ci]=0.00010348, y_nanmean[ci]=-3.1574e-07, y_lower_bound[ci]=-0.00021098, y_upper_bound[ci]=0.00027464
# preds[:,ci].mean()=4.4199e-05, preds[:,ci].min()=-1.3406e-05, preds[:,ci].max()=8.6819e-05
# labels[:,ci].mean()=7.4104e-07, labels[:,ci].min()=-0.00012188, labels[:,ci].max()=0.0002236
#
# 【 ptend_t_7 】
# r2_score=-0.14945
# ri=155, ci=7
# preds[ri,ci]=3.8964e-05, labels[ri,ci]=0.00018809
# mse[ri]=2.2238e-08, r2: 1-(mse.mean()=7.6693e-09)/(base.mean()=6.6722e-09)
# y_rms_sub[ci]=7.8811e-05, y_nanmean[ci]=3.9614e-07, y_lower_bound[ci]=-0.00020027, y_upper_bound[ci]=0.00023456
# preds[:,ci].mean()=3.58e-05, preds[:,ci].min()=-9.7225e-06, preds[:,ci].max()=6.5144e-05
# labels[:,ci].mean()=6.3943e-07, labels[:,ci].min()=-9.4221e-05, labels[:,ci].max()=0.00018809
#
# 【 ptend_t_8 】
# r2_score=-0.14944
# ri=155, ci=8
# preds[ri,ci]=2.5795e-05, labels[ri,ci]=0.00013791
# mse[ri]=1.2571e-08, r2: 1-(mse.mean()=3.2723e-09)/(base.mean()=2.8468e-09)
# y_rms_sub[ci]=5.0276e-05, y_nanmean[ci]=1.835e-07, y_lower_bound[ci]=-0.00012703, y_upper_bound[ci]=0.00015887
# preds[:,ci].mean()=2.3462e-05, preds[:,ci].min()=-5.6552e-06, preds[:,ci].max()=3.719e-05
# labels[:,ci].mean()=2.2718e-07, labels[:,ci].min()=-6.053e-05, labels[:,ci].max()=0.00013791
#
# 【 ptend_t_9 】
# r2_score=-0.18785
# ri=155, ci=9
# preds[ri,ci]=2.2087e-05, labels[ri,ci]=0.0001135
# mse[ri]=8.3559e-09, r2: 1-(mse.mean()=2.0308e-09)/(base.mean()=1.7097e-09)
# y_rms_sub[ci]=3.8713e-05, y_nanmean[ci]=-1.5025e-08, y_lower_bound[ci]=-9.4898e-05, y_upper_bound[ci]=0.00013054
# preds[:,ci].mean()=1.962e-05, preds[:,ci].min()=-3.9993e-06, preds[:,ci].max()=2.8318e-05
# labels[:,ci].mean()=1.4343e-07, labels[:,ci].min()=-4.809e-05, labels[:,ci].max()=0.0001135
#
# 【 ptend_t_10 】
# r2_score=-0.23166
# ri=155, ci=10
# preds[ri,ci]=1.914e-05, labels[ri,ci]=8.1467e-05
# mse[ri]=3.8847e-09, r2: 1-(mse.mean()=1.2097e-09)/(base.mean()=9.8213e-10)
# y_rms_sub[ci]=2.9507e-05, y_nanmean[ci]=1.414e-07, y_lower_bound[ci]=-7.5106e-05, y_upper_bound[ci]=9.9978e-05
# preds[:,ci].mean()=1.6039e-05, preds[:,ci].min()=-2.7682e-06, preds[:,ci].max()=2.1959e-05
# labels[:,ci].mean()=3.5348e-07, labels[:,ci].min()=-4.1485e-05, labels[:,ci].max()=8.1467e-05
#
# 【 ptend_t_11 】
# r2_score=-0.22433
# ri=147, ci=11
# preds[ri,ci]=1.3096e-05, labels[ri,ci]=5.8872e-05
# mse[ri]=2.0954e-09, r2: 1-(mse.mean()=6.8429e-10)/(base.mean()=5.5891e-10)
# y_rms_sub[ci]=2.2664e-05, y_nanmean[ci]=1.8991e-07, y_lower_bound[ci]=-5.857e-05, y_upper_bound[ci]=7.5129e-05
# preds[:,ci].mean()=1.2208e-05, preds[:,ci].min()=-1.7056e-06, preds[:,ci].max()=1.5649e-05
# labels[:,ci].mean()=4.5217e-07, labels[:,ci].min()=-2.9763e-05, labels[:,ci].max()=5.8872e-05
#
# 【 ptend_t_12 】
# r2_score=-0.19946
# ri=309, ci=12
# preds[ri,ci]=1.0676e-05, labels[ri,ci]=-2.298e-05
# mse[ri]=1.1328e-09, r2: 1-(mse.mean()=3.5126e-10)/(base.mean()=2.9285e-10)
# y_rms_sub[ci]=1.6719e-05, y_nanmean[ci]=2.9911e-07, y_lower_bound[ci]=-4.351e-05, y_upper_bound[ci]=5.6758e-05
# preds[:,ci].mean()=8.77e-06, preds[:,ci].min()=-8.4344e-07, preds[:,ci].max()=1.1199e-05
# labels[:,ci].mean()=6.5065e-07, labels[:,ci].min()=-2.3704e-05, labels[:,ci].max()=4.3794e-05
#
# 【 ptend_t_13 】
# r2_score=-0.18599
# ri=309, ci=13
# preds[ri,ci]=8.2216e-06, labels[ri,ci]=-1.9419e-05
# mse[ri]=7.6399e-10, r2: 1-(mse.mean()=1.8984e-10)/(base.mean()=1.6007e-10)
# y_rms_sub[ci]=1.2589e-05, y_nanmean[ci]=3.7836e-07, y_lower_bound[ci]=-3.7031e-05, y_upper_bound[ci]=4.0806e-05
# preds[:,ci].mean()=6.5928e-06, preds[:,ci].min()=-2.3182e-07, preds[:,ci].max()=8.5486e-06
# labels[:,ci].mean()=7.2329e-07, labels[:,ci].min()=-2.0247e-05, labels[:,ci].max()=3.0413e-05
#
# 【 ptend_t_14 】
# r2_score=-0.18953
# ri=295, ci=14
# preds[ri,ci]=7.6148e-06, labels[ri,ci]=-1.7193e-05
# mse[ri]=6.1545e-10, r2: 1-(mse.mean()=1.0611e-10)/(base.mean()=8.9206e-11)
# y_rms_sub[ci]=9.3146e-06, y_nanmean[ci]=5.7042e-07, y_lower_bound[ci]=-0.00010385, y_upper_bound[ci]=5.9677e-05
# preds[:,ci].mean()=5.0383e-06, preds[:,ci].min()=3.4204e-07, preds[:,ci].max()=8.264e-06
# labels[:,ci].mean()=9.0049e-07, labels[:,ci].min()=-1.7729e-05, labels[:,ci].max()=2.0261e-05
#
# 【 ptend_t_15 】
# r2_score=-0.22456
# ri=295, ci=15
# preds[ri,ci]=6.5089e-06, labels[ri,ci]=-1.4958e-05
# mse[ri]=4.6082e-10, r2: 1-(mse.mean()=6.7912e-11)/(base.mean()=5.5459e-11)
# y_rms_sub[ci]=7.3681e-06, y_nanmean[ci]=9.3496e-07, y_lower_bound[ci]=-0.00044666, y_upper_bound[ci]=0.00020871
# preds[:,ci].mean()=4.3625e-06, preds[:,ci].min()=7.3451e-07, preds[:,ci].max()=7.0932e-06
# labels[:,ci].mean()=1.1657e-06, labels[:,ci].min()=-1.5568e-05, labels[:,ci].max()=1.5954e-05
#
# 【 ptend_t_16 】
# r2_score=-0.26161
# ri=204, ci=16
# preds[ri,ci]=4.9367e-06, labels[ri,ci]=-1.5182e-05
# mse[ri]=4.0475e-10, r2: 1-(mse.mean()=5.2921e-11)/(base.mean()=4.1947e-11)
# y_rms_sub[ci]=6.6934e-06, y_nanmean[ci]=1.722e-06, y_lower_bound[ci]=-0.0019379, y_upper_bound[ci]=0.00075266
# preds[:,ci].mean()=4.4717e-06, preds[:,ci].min()=1.5317e-06, preds[:,ci].max()=7.3417e-06
# labels[:,ci].mean()=1.759e-06, labels[:,ci].min()=-1.5182e-05, labels[:,ci].max()=1.5457e-05
#
# 【 ptend_t_17 】
# r2_score=-0.48177
# ri=144, ci=17
# preds[ri,ci]=4.4629e-06, labels[ri,ci]=-4.4804e-05
# mse[ri]=2.4272e-09, r2: 1-(mse.mean()=5.4378e-11)/(base.mean()=3.6698e-11)
# y_rms_sub[ci]=7.7825e-06, y_nanmean[ci]=1.6504e-06, y_lower_bound[ci]=-0.0016661, y_upper_bound[ci]=0.0025104
# preds[:,ci].mean()=4.5116e-06, preds[:,ci].min()=7.6563e-07, preds[:,ci].max()=8.339e-06
# labels[:,ci].mean()=1.0294e-06, labels[:,ci].min()=-4.4804e-05, labels[:,ci].max()=1.3965e-05
#
# 【 ptend_t_18 】
# r2_score=-0.2562
# ri=144, ci=18
# preds[ri,ci]=3.0262e-06, labels[ri,ci]=8.5492e-05
# mse[ri]=6.8006e-09, r2: 1-(mse.mean()=1.0204e-10)/(base.mean()=8.1225e-11)
# y_rms_sub[ci]=1.09e-05, y_nanmean[ci]=7.5952e-07, y_lower_bound[ci]=-0.0023312, y_upper_bound[ci]=0.00080048
# preds[:,ci].mean()=4.4374e-06, preds[:,ci].min()=-8.6036e-07, preds[:,ci].max()=9.7534e-06
# labels[:,ci].mean()=1.2748e-06, labels[:,ci].min()=-4.5129e-05, labels[:,ci].max()=8.5492e-05
#
# 【 ptend_t_19 】
# r2_score=-0.29242
# ri=95, ci=19
# preds[ri,ci]=-1.4121e-07, labels[ri,ci]=9.2579e-05
# mse[ri]=8.5971e-09, r2: 1-(mse.mean()=1.5964e-10)/(base.mean()=1.2352e-10)
# y_rms_sub[ci]=1.3746e-05, y_nanmean[ci]=-3.9152e-07, y_lower_bound[ci]=-0.0020896, y_upper_bound[ci]=0.0012417
# preds[:,ci].mean()=3.7582e-06, preds[:,ci].min()=-3.4703e-06, preds[:,ci].max()=1.0606e-05
# labels[:,ci].mean()=2.2875e-07, labels[:,ci].min()=-4.1762e-05, labels[:,ci].max()=9.2579e-05
#
# 【 ptend_t_20 】
# r2_score=-0.16494
# ri=95, ci=20
# preds[ri,ci]=-8.0909e-08, labels[ri,ci]=0.00016409
# mse[ri]=2.6953e-08, r2: 1-(mse.mean()=2.5686e-10)/(base.mean()=2.2049e-10)
# y_rms_sub[ci]=1.503e-05, y_nanmean[ci]=-3.5008e-07, y_lower_bound[ci]=-0.0015815, y_upper_bound[ci]=0.0019031
# preds[:,ci].mean()=3.6239e-06, preds[:,ci].min()=-4.4004e-06, preds[:,ci].max()=1.16e-05
# labels[:,ci].mean()=1.0095e-06, labels[:,ci].min()=-3.2721e-05, labels[:,ci].max()=0.00016409
#
# 【 ptend_t_21 】
# r2_score=-0.17863
# ri=95, ci=21
# preds[ri,ci]=-2.2822e-06, labels[ri,ci]=0.00013054
# mse[ri]=1.7642e-08, r2: 1-(mse.mean()=2.6324e-10)/(base.mean()=2.2335e-10)
# y_rms_sub[ci]=1.589e-05, y_nanmean[ci]=-2.383e-06, y_lower_bound[ci]=-0.0012649, y_upper_bound[ci]=0.0013608
# preds[:,ci].mean()=1.046e-06, preds[:,ci].min()=-7.7118e-06, preds[:,ci].max()=9.7589e-06
# labels[:,ci].mean()=-9.4428e-07, labels[:,ci].min()=-5.2089e-05, labels[:,ci].max()=0.00013054
#
# 【 ptend_t_22 】
# r2_score=-0.13522
# ri=93, ci=22
# preds[ri,ci]=-3.3023e-06, labels[ri,ci]=0.00012367
# mse[ri]=1.6122e-08, r2: 1-(mse.mean()=3.0361e-10)/(base.mean()=2.6745e-10)
# y_rms_sub[ci]=1.7665e-05, y_nanmean[ci]=-4.1224e-06, y_lower_bound[ci]=-0.0010937, y_upper_bound[ci]=0.0020494
# preds[:,ci].mean()=-8.1192e-07, preds[:,ci].min()=-1.0836e-05, preds[:,ci].max()=9.3083e-06
# labels[:,ci].mean()=-3.2369e-06, labels[:,ci].min()=-0.00012715, labels[:,ci].max()=0.00012367
#
# 【 ptend_t_23 】
# r2_score=-0.16902
# ri=147, ci=23
# preds[ri,ci]=-5.2913e-06, labels[ri,ci]=0.00013267
# mse[ri]=1.9034e-08, r2: 1-(mse.mean()=3.228e-10)/(base.mean()=2.7613e-10)
# y_rms_sub[ci]=2.0213e-05, y_nanmean[ci]=-5.6501e-06, y_lower_bound[ci]=-0.0011443, y_upper_bound[ci]=0.0018548
# preds[:,ci].mean()=-2.3504e-06, preds[:,ci].min()=-1.3182e-05, preds[:,ci].max()=9.3495e-06
# labels[:,ci].mean()=-5.5307e-06, labels[:,ci].min()=-8.6304e-05, labels[:,ci].max()=0.00013267
#
# 【 ptend_t_24 】
# r2_score=-0.18316
# ri=147, ci=24
# preds[ri,ci]=-5.6808e-06, labels[ri,ci]=0.00017995
# mse[ri]=3.4457e-08, r2: 1-(mse.mean()=4.4887e-10)/(base.mean()=3.7938e-10)
# y_rms_sub[ci]=2.324e-05, y_nanmean[ci]=-6.6162e-06, y_lower_bound[ci]=-0.00085186, y_upper_bound[ci]=0.00171
# preds[:,ci].mean()=-3.2403e-06, preds[:,ci].min()=-1.5653e-05, preds[:,ci].max()=1.1525e-05
# labels[:,ci].mean()=-6.6558e-06, labels[:,ci].min()=-6.4282e-05, labels[:,ci].max()=0.00017995
#
# 【 ptend_t_25 】
# r2_score=-0.17108
# ri=147, ci=25
# preds[ri,ci]=-5.2396e-06, labels[ri,ci]=0.0001853
# mse[ri]=3.6304e-08, r2: 1-(mse.mean()=5.8451e-10)/(base.mean()=4.9912e-10)
# y_rms_sub[ci]=2.7091e-05, y_nanmean[ci]=-6.6196e-06, y_lower_bound[ci]=-0.00094212, y_upper_bound[ci]=0.0019357
# preds[:,ci].mean()=-2.7287e-06, preds[:,ci].min()=-1.7329e-05, preds[:,ci].max()=1.5128e-05
# labels[:,ci].mean()=-6.3065e-06, labels[:,ci].min()=-5.4383e-05, labels[:,ci].max()=0.0001853
#
# 【 ptend_t_26 】
# r2_score=-0.21963
# ri=147, ci=26
# preds[ri,ci]=-3.7265e-06, labels[ri,ci]=0.00019669
# mse[ri]=4.0167e-08, r2: 1-(mse.mean()=7.8418e-10)/(base.mean()=6.4297e-10)
# y_rms_sub[ci]=3.1759e-05, y_nanmean[ci]=-5.8169e-06, y_lower_bound[ci]=-0.00083891, y_upper_bound[ci]=0.0014607
# preds[:,ci].mean()=-1.4822e-06, preds[:,ci].min()=-1.7935e-05, preds[:,ci].max()=1.9395e-05
# labels[:,ci].mean()=-6.2358e-06, labels[:,ci].min()=-4.6348e-05, labels[:,ci].max()=0.00019669
#
# 【 ptend_t_27 】
# r2_score=-0.22143
# ri=147, ci=27
# preds[ri,ci]=-1.6891e-06, labels[ri,ci]=0.00021903
# mse[ri]=4.8717e-08, r2: 1-(mse.mean()=1.031e-09)/(base.mean()=8.4405e-10)
# y_rms_sub[ci]=3.7177e-05, y_nanmean[ci]=-4.6825e-06, y_lower_bound[ci]=-0.0011528, y_upper_bound[ci]=0.0014775
# preds[:,ci].mean()=-2.6557e-09, preds[:,ci].min()=-1.9994e-05, preds[:,ci].max()=2.7254e-05
# labels[:,ci].mean()=-6.1233e-06, labels[:,ci].min()=-5.7569e-05, labels[:,ci].max()=0.00021903
#
# 【 ptend_t_28 】
# r2_score=-0.22282
# ri=147, ci=28
# preds[ri,ci]=-1.3434e-07, labels[ri,ci]=0.00024505
# mse[ri]=6.0117e-08, r2: 1-(mse.mean()=1.3339e-09)/(base.mean()=1.0909e-09)
# y_rms_sub[ci]=4.2888e-05, y_nanmean[ci]=-3.5742e-06, y_lower_bound[ci]=-0.00093447, y_upper_bound[ci]=0.0014986
# preds[:,ci].mean()=1.364e-06, preds[:,ci].min()=-2.0759e-05, preds[:,ci].max()=3.3838e-05
# labels[:,ci].mean()=-4.986e-06, labels[:,ci].min()=-6.3435e-05, labels[:,ci].max()=0.00024505
#
# 【 ptend_t_29 】
# r2_score=-0.18831
# ri=17, ci=29
# preds[ri,ci]=3.9305e-06, labels[ri,ci]=0.00027845
# mse[ri]=7.5358e-08, r2: 1-(mse.mean()=1.7711e-09)/(base.mean()=1.4905e-09)
# y_rms_sub[ci]=4.8876e-05, y_nanmean[ci]=-2.5693e-06, y_lower_bound[ci]=-0.00099352, y_upper_bound[ci]=0.0017182
# preds[:,ci].mean()=3.3506e-06, preds[:,ci].min()=-2.1219e-05, preds[:,ci].max()=4.2411e-05
# labels[:,ci].mean()=-4.4637e-06, labels[:,ci].min()=-5.1639e-05, labels[:,ci].max()=0.00027845
#
# 【 ptend_t_30 】
# r2_score=-0.19106
# ri=17, ci=30
# preds[ri,ci]=5.2019e-06, labels[ri,ci]=0.00029013
# mse[ri]=8.1185e-08, r2: 1-(mse.mean()=2.0022e-09)/(base.mean()=1.681e-09)
# y_rms_sub[ci]=5.439e-05, y_nanmean[ci]=-1.687e-06, y_lower_bound[ci]=-0.00072956, y_upper_bound[ci]=0.001801
# preds[:,ci].mean()=3.5673e-06, preds[:,ci].min()=-2.3634e-05, preds[:,ci].max()=4.6588e-05
# labels[:,ci].mean()=-5.1073e-06, labels[:,ci].min()=-6.7685e-05, labels[:,ci].max()=0.00029013
#
# 【 ptend_t_31 】
# r2_score=-0.1684
# ri=17, ci=31
# preds[ri,ci]=6.5264e-06, labels[ri,ci]=0.00031465
# mse[ri]=9.4941e-08, r2: 1-(mse.mean()=2.8978e-09)/(base.mean()=2.4801e-09)
# y_rms_sub[ci]=5.8441e-05, y_nanmean[ci]=-9.0353e-07, y_lower_bound[ci]=-0.0010698, y_upper_bound[ci]=0.0016455
# preds[:,ci].mean()=5.086e-06, preds[:,ci].min()=-2.518e-05, preds[:,ci].max()=5.109e-05
# labels[:,ci].mean()=-4.3255e-06, labels[:,ci].min()=-9.7723e-05, labels[:,ci].max()=0.00031465
#
# 【 ptend_t_32 】
# r2_score=-0.14175
# ri=17, ci=32
# preds[ri,ci]=7.5577e-06, labels[ri,ci]=0.00037294
# mse[ri]=1.335e-07, r2: 1-(mse.mean()=3.2127e-09)/(base.mean()=2.8139e-09)
# y_rms_sub[ci]=6.1208e-05, y_nanmean[ci]=-2.7668e-07, y_lower_bound[ci]=-0.0011938, y_upper_bound[ci]=0.001815
# preds[:,ci].mean()=5.3927e-06, preds[:,ci].min()=-2.8364e-05, preds[:,ci].max()=5.3769e-05
# labels[:,ci].mean()=-3.0501e-06, labels[:,ci].min()=-7.7679e-05, labels[:,ci].max()=0.00037294
#
# 【 ptend_t_33 】
# r2_score=-0.14373
# ri=17, ci=33
# preds[ri,ci]=8.9264e-06, labels[ri,ci]=0.00037928
# mse[ri]=1.3716e-07, r2: 1-(mse.mean()=3.3942e-09)/(base.mean()=2.9676e-09)
# y_rms_sub[ci]=6.3061e-05, y_nanmean[ci]=1.8943e-07, y_lower_bound[ci]=-0.0013442, y_upper_bound[ci]=0.0017571
# preds[:,ci].mean()=6.3761e-06, preds[:,ci].min()=-2.8037e-05, preds[:,ci].max()=5.2929e-05
# labels[:,ci].mean()=-1.8896e-06, labels[:,ci].min()=-0.00014823, labels[:,ci].max()=0.00037928
#
# 【 ptend_t_34 】
# r2_score=-0.11364
# ri=147, ci=34
# preds[ri,ci]=1.1889e-05, labels[ri,ci]=0.00045723
# mse[ri]=1.9832e-07, r2: 1-(mse.mean()=4.0692e-09)/(base.mean()=3.6539e-09)
# y_rms_sub[ci]=6.4181e-05, y_nanmean[ci]=4.8232e-07, y_lower_bound[ci]=-0.0012755, y_upper_bound[ci]=0.0015543
# preds[:,ci].mean()=7.0264e-06, preds[:,ci].min()=-2.7378e-05, preds[:,ci].max()=6.0924e-05
# labels[:,ci].mean()=-1.2133e-06, labels[:,ci].min()=-9.4999e-05, labels[:,ci].max()=0.00045723
#
# 【 ptend_t_35 】
# r2_score=-0.10867
# ri=17, ci=35
# preds[ri,ci]=8.2621e-06, labels[ri,ci]=0.00042674
# mse[ri]=1.7513e-07, r2: 1-(mse.mean()=4.1927e-09)/(base.mean()=3.7818e-09)
# y_rms_sub[ci]=6.4526e-05, y_nanmean[ci]=6.4682e-07, y_lower_bound[ci]=-0.0015754, y_upper_bound[ci]=0.0014463
# preds[:,ci].mean()=7.4059e-06, preds[:,ci].min()=-2.4739e-05, preds[:,ci].max()=5.8578e-05
# labels[:,ci].mean()=-1.1651e-06, labels[:,ci].min()=-9.1898e-05, labels[:,ci].max()=0.00042674
#
# 【 ptend_t_36 】
# r2_score=-0.082712
# ri=82, ci=36
# preds[ri,ci]=4.6695e-06, labels[ri,ci]=0.00036456
# mse[ri]=1.2952e-07, r2: 1-(mse.mean()=4.4177e-09)/(base.mean()=4.0802e-09)
# y_rms_sub[ci]=6.4052e-05, y_nanmean[ci]=6.9192e-07, y_lower_bound[ci]=-0.0016109, y_upper_bound[ci]=0.0013356
# preds[:,ci].mean()=8.3988e-06, preds[:,ci].min()=-2.2958e-05, preds[:,ci].max()=5.5694e-05
# labels[:,ci].mean()=-9.481e-07, labels[:,ci].min()=-0.00020604, labels[:,ci].max()=0.00036456
#
# 【 ptend_t_37 】
# r2_score=-0.062041
# ri=194, ci=37
# preds[ri,ci]=7.1929e-06, labels[ri,ci]=0.00044445
# mse[ri]=1.912e-07, r2: 1-(mse.mean()=4.5563e-09)/(base.mean()=4.2901e-09)
# y_rms_sub[ci]=6.33e-05, y_nanmean[ci]=6.9456e-07, y_lower_bound[ci]=-0.0013281, y_upper_bound[ci]=0.0013643
# preds[:,ci].mean()=9.5064e-06, preds[:,ci].min()=-2.1835e-05, preds[:,ci].max()=5.3822e-05
# labels[:,ci].mean()=-5.3352e-08, labels[:,ci].min()=-0.00011543, labels[:,ci].max()=0.00044445
#
# 【 ptend_t_38 】
# r2_score=-0.055046
# ri=82, ci=38
# preds[ri,ci]=1.3686e-05, labels[ri,ci]=0.00044092
# mse[ri]=1.8253e-07, r2: 1-(mse.mean()=4.2138e-09)/(base.mean()=3.994e-09)
# y_rms_sub[ci]=6.2601e-05, y_nanmean[ci]=6.8264e-07, y_lower_bound[ci]=-0.001051, y_upper_bound[ci]=0.0014974
# preds[:,ci].mean()=1.0746e-05, preds[:,ci].min()=-2.0333e-05, preds[:,ci].max()=5.2147e-05
# labels[:,ci].mean()=-2.4967e-07, labels[:,ci].min()=-0.00012317, labels[:,ci].max()=0.00044092
#
# 【 ptend_t_39 】
# r2_score=-0.066356
# ri=82, ci=39
# preds[ri,ci]=1.5603e-05, labels[ri,ci]=0.00051468
# mse[ri]=2.4907e-07, r2: 1-(mse.mean()=4.0377e-09)/(base.mean()=3.7865e-09)
# y_rms_sub[ci]=6.1995e-05, y_nanmean[ci]=6.0524e-07, y_lower_bound[ci]=-0.0010256, y_upper_bound[ci]=0.001396
# preds[:,ci].mean()=1.1782e-05, preds[:,ci].min()=-1.8847e-05, preds[:,ci].max()=5.058e-05
# labels[:,ci].mean()=-1.3569e-06, labels[:,ci].min()=-0.00016272, labels[:,ci].max()=0.00051468
#
# 【 ptend_t_40 】
# r2_score=-0.050739
# ri=82, ci=40
# preds[ri,ci]=1.6295e-05, labels[ri,ci]=0.00047204
# mse[ri]=2.0771e-07, r2: 1-(mse.mean()=3.5768e-09)/(base.mean()=3.4041e-09)
# y_rms_sub[ci]=6.1496e-05, y_nanmean[ci]=4.6188e-07, y_lower_bound[ci]=-0.00085972, y_upper_bound[ci]=0.0012175
# preds[:,ci].mean()=1.2358e-05, preds[:,ci].min()=-1.9478e-05, preds[:,ci].max()=5.2154e-05
# labels[:,ci].mean()=9.8978e-07, labels[:,ci].min()=-0.00015898, labels[:,ci].max()=0.00047204
#
# 【 ptend_t_41 】
# r2_score=-0.07423
# ri=147, ci=41
# preds[ri,ci]=2.7923e-05, labels[ri,ci]=0.00048829
# mse[ri]=2.1194e-07, r2: 1-(mse.mean()=3.5537e-09)/(base.mean()=3.3081e-09)
# y_rms_sub[ci]=6.108e-05, y_nanmean[ci]=2.5631e-07, y_lower_bound[ci]=-0.00093625, y_upper_bound[ci]=0.0012026
# preds[:,ci].mean()=1.2276e-05, preds[:,ci].min()=-1.9475e-05, preds[:,ci].max()=5.2127e-05
# labels[:,ci].mean()=1.3492e-06, labels[:,ci].min()=-0.00014328, labels[:,ci].max()=0.00048829
#
# 【 ptend_t_42 】
# r2_score=-0.055411
# ri=82, ci=42
# preds[ri,ci]=1.0499e-05, labels[ri,ci]=0.0005149
# mse[ri]=2.5442e-07, r2: 1-(mse.mean()=3.8243e-09)/(base.mean()=3.6235e-09)
# y_rms_sub[ci]=6.0987e-05, y_nanmean[ci]=-3.9707e-08, y_lower_bound[ci]=-0.00074911, y_upper_bound[ci]=0.0012147
# preds[:,ci].mean()=1.1575e-05, preds[:,ci].min()=-1.8142e-05, preds[:,ci].max()=4.6319e-05
# labels[:,ci].mean()=1.6708e-06, labels[:,ci].min()=-0.00014175, labels[:,ci].max()=0.0005149
#
# 【 ptend_t_43 】
# r2_score=-0.057277
# ri=82, ci=43
# preds[ri,ci]=1.1993e-05, labels[ri,ci]=0.00053669
# mse[ri]=2.7531e-07, r2: 1-(mse.mean()=3.7688e-09)/(base.mean()=3.5646e-09)
# y_rms_sub[ci]=6.1254e-05, y_nanmean[ci]=-3.9279e-07, y_lower_bound[ci]=-0.00069239, y_upper_bound[ci]=0.0012689
# preds[:,ci].mean()=1.0948e-05, preds[:,ci].min()=-1.7634e-05, preds[:,ci].max()=4.4228e-05
# labels[:,ci].mean()=-3.4798e-07, labels[:,ci].min()=-0.00020641, labels[:,ci].max()=0.00053669
#
# 【 ptend_t_44 】
# r2_score=-0.028492
# ri=82, ci=44
# preds[ri,ci]=1.3922e-05, labels[ri,ci]=0.00050797
# mse[ri]=2.4409e-07, r2: 1-(mse.mean()=3.8695e-09)/(base.mean()=3.7623e-09)
# y_rms_sub[ci]=6.1619e-05, y_nanmean[ci]=-7.0516e-07, y_lower_bound[ci]=-0.00060904, y_upper_bound[ci]=0.0012845
# preds[:,ci].mean()=1.0069e-05, preds[:,ci].min()=-1.6538e-05, preds[:,ci].max()=4.0141e-05
# labels[:,ci].mean()=-3.2832e-06, labels[:,ci].min()=-0.00022419, labels[:,ci].max()=0.00050797
#
# 【 ptend_t_45 】
# r2_score=-0.038581
# ri=82, ci=45
# preds[ri,ci]=1.8179e-05, labels[ri,ci]=0.00032396
# mse[ri]=9.3501e-08, r2: 1-(mse.mean()=3.3943e-09)/(base.mean()=3.2682e-09)
# y_rms_sub[ci]=6.176e-05, y_nanmean[ci]=-7.0207e-07, y_lower_bound[ci]=-0.00069593, y_upper_bound[ci]=0.0012294
# preds[:,ci].mean()=1.0005e-05, preds[:,ci].min()=-1.5359e-05, preds[:,ci].max()=4.2969e-05
# labels[:,ci].mean()=-2.3703e-06, labels[:,ci].min()=-0.0002753, labels[:,ci].max()=0.00032396
#
# 【 ptend_t_46 】
# r2_score=-0.050062
# ri=103, ci=46
# preds[ri,ci]=1.1013e-05, labels[ri,ci]=0.00034532
# mse[ri]=1.1176e-07, r2: 1-(mse.mean()=3.2566e-09)/(base.mean()=3.1013e-09)
# y_rms_sub[ci]=6.1195e-05, y_nanmean[ci]=-1.9406e-07, y_lower_bound[ci]=-0.00065184, y_upper_bound[ci]=0.0013678
# preds[:,ci].mean()=1.0503e-05, preds[:,ci].min()=-1.436e-05, preds[:,ci].max()=3.5012e-05
# labels[:,ci].mean()=-6.9177e-07, labels[:,ci].min()=-0.00018774, labels[:,ci].max()=0.00034532
#
# 【 ptend_t_47 】
# r2_score=-0.043917
# ri=103, ci=47
# preds[ri,ci]=1.1092e-05, labels[ri,ci]=0.00031733
# mse[ri]=9.3784e-08, r2: 1-(mse.mean()=3.6434e-09)/(base.mean()=3.4901e-09)
# y_rms_sub[ci]=6.0076e-05, y_nanmean[ci]=6.6915e-07, y_lower_bound[ci]=-0.00068137, y_upper_bound[ci]=0.0014417
# preds[:,ci].mean()=1.1806e-05, preds[:,ci].min()=-1.2978e-05, preds[:,ci].max()=3.5812e-05
# labels[:,ci].mean()=1.8367e-06, labels[:,ci].min()=-0.00020159, labels[:,ci].max()=0.00031733
#
# 【 ptend_t_48 】
# r2_score=-0.14799
# ri=71, ci=48
# preds[ri,ci]=3.6368e-05, labels[ri,ci]=0.00026883
# mse[ri]=5.4039e-08, r2: 1-(mse.mean()=2.6684e-09)/(base.mean()=2.3244e-09)
# y_rms_sub[ci]=5.8805e-05, y_nanmean[ci]=1.5757e-06, y_lower_bound[ci]=-0.00069584, y_upper_bound[ci]=0.0013452
# preds[:,ci].mean()=1.2854e-05, preds[:,ci].min()=-1.1322e-05, preds[:,ci].max()=3.9031e-05
# labels[:,ci].mean()=-5.2627e-07, labels[:,ci].min()=-0.0001611, labels[:,ci].max()=0.00026883
#
# 【 ptend_t_49 】
# r2_score=-0.1915
# ri=170, ci=49
# preds[ri,ci]=1.0078e-05, labels[ri,ci]=0.00022649
# mse[ri]=4.6833e-08, r2: 1-(mse.mean()=2.7922e-09)/(base.mean()=2.3435e-09)
# y_rms_sub[ci]=5.7371e-05, y_nanmean[ci]=2.3883e-06, y_lower_bound[ci]=-0.0008996, y_upper_bound[ci]=0.0012844
# preds[:,ci].mean()=1.3858e-05, preds[:,ci].min()=-8.3706e-06, preds[:,ci].max()=3.8687e-05
# labels[:,ci].mean()=-1.0257e-06, labels[:,ci].min()=-0.00019025, labels[:,ci].max()=0.00022649
#
# 【 ptend_t_50 】
# r2_score=-0.17929
# ri=220, ci=50
# preds[ri,ci]=2.001e-05, labels[ri,ci]=-0.00019369
# mse[ri]=4.5668e-08, r2: 1-(mse.mean()=2.7572e-09)/(base.mean()=2.338e-09)
# y_rms_sub[ci]=5.5843e-05, y_nanmean[ci]=3.0654e-06, y_lower_bound[ci]=-0.00086782, y_upper_bound[ci]=0.001328
# preds[:,ci].mean()=1.4878e-05, preds[:,ci].min()=-7.2346e-06, preds[:,ci].max()=3.6661e-05
# labels[:,ci].mean()=-5.6854e-07, labels[:,ci].min()=-0.00019369, labels[:,ci].max()=0.00016321
#
# 【 ptend_t_51 】
# r2_score=-0.17466
# ri=220, ci=51
# preds[ri,ci]=2.0593e-05, labels[ri,ci]=-0.00027601
# mse[ri]=8.7976e-08, r2: 1-(mse.mean()=3.078e-09)/(base.mean()=2.6203e-09)
# y_rms_sub[ci]=5.4255e-05, y_nanmean[ci]=3.6993e-06, y_lower_bound[ci]=-0.0011655, y_upper_bound[ci]=0.0013037
# preds[:,ci].mean()=1.5543e-05, preds[:,ci].min()=-5.5498e-06, preds[:,ci].max()=3.7037e-05
# labels[:,ci].mean()=-1.059e-06, labels[:,ci].min()=-0.00027601, labels[:,ci].max()=0.00020036
#
# 【 ptend_t_52 】
# r2_score=-0.17049
# ri=147, ci=52
# preds[ri,ci]=3.2491e-05, labels[ri,ci]=-0.00028955
# mse[ri]=1.0371e-07, r2: 1-(mse.mean()=3.0883e-09)/(base.mean()=2.6385e-09)
# y_rms_sub[ci]=5.2542e-05, y_nanmean[ci]=4.2736e-06, y_lower_bound[ci]=-0.001134, y_upper_bound[ci]=0.0014183
# preds[:,ci].mean()=1.6588e-05, preds[:,ci].min()=-4.1351e-06, preds[:,ci].max()=3.8324e-05
# labels[:,ci].mean()=9.9331e-07, labels[:,ci].min()=-0.00028955, labels[:,ci].max()=0.00017512
#
# 【 ptend_t_53 】
# r2_score=-0.16854
# ri=220, ci=53
# preds[ri,ci]=2.1247e-05, labels[ri,ci]=-0.00026814
# mse[ri]=8.3744e-08, r2: 1-(mse.mean()=2.845e-09)/(base.mean()=2.4346e-09)
# y_rms_sub[ci]=5.0758e-05, y_nanmean[ci]=4.4461e-06, y_lower_bound[ci]=-0.0012106, y_upper_bound[ci]=0.001334
# preds[:,ci].mean()=1.682e-05, preds[:,ci].min()=-3.4638e-06, preds[:,ci].max()=3.7099e-05
# labels[:,ci].mean()=1.2099e-06, labels[:,ci].min()=-0.00026814, labels[:,ci].max()=0.00015714
#
# 【 ptend_t_54 】
# r2_score=-0.17863
# ri=220, ci=54
# preds[ri,ci]=2.0184e-05, labels[ri,ci]=-0.00033966
# mse[ri]=1.2949e-07, r2: 1-(mse.mean()=2.5818e-09)/(base.mean()=2.1905e-09)
# y_rms_sub[ci]=4.9e-05, y_nanmean[ci]=3.905e-06, y_lower_bound[ci]=-0.0010222, y_upper_bound[ci]=0.0017133
# preds[:,ci].mean()=1.6504e-05, preds[:,ci].min()=-3.1112e-06, preds[:,ci].max()=3.676e-05
# labels[:,ci].mean()=-8.4544e-07, labels[:,ci].min()=-0.00033966, labels[:,ci].max()=0.00018476
#
# 【 ptend_t_55 】
# r2_score=-0.1846
# ri=220, ci=55
# preds[ri,ci]=2.2538e-05, labels[ri,ci]=-0.00029602
# mse[ri]=1.0148e-07, r2: 1-(mse.mean()=2.1485e-09)/(base.mean()=1.8137e-09)
# y_rms_sub[ci]=4.7694e-05, y_nanmean[ci]=2.1095e-06, y_lower_bound[ci]=-0.00099591, y_upper_bound[ci]=0.0014724
# preds[:,ci].mean()=1.5344e-05, preds[:,ci].min()=-4.6783e-06, preds[:,ci].max()=3.6517e-05
# labels[:,ci].mean()=-4.1691e-07, labels[:,ci].min()=-0.00029602, labels[:,ci].max()=0.00015087
#
# 【 ptend_t_56 】
# r2_score=-0.21923
# ri=82, ci=56
# preds[ri,ci]=2.5905e-05, labels[ri,ci]=-0.00026101
# mse[ri]=8.2319e-08, r2: 1-(mse.mean()=2.0053e-09)/(base.mean()=1.6447e-09)
# y_rms_sub[ci]=4.7182e-05, y_nanmean[ci]=-1.3361e-06, y_lower_bound[ci]=-0.0010859, y_upper_bound[ci]=0.0010916
# preds[:,ci].mean()=1.2641e-05, preds[:,ci].min()=-7.5018e-06, preds[:,ci].max()=3.1688e-05
# labels[:,ci].mean()=-3.2894e-06, labels[:,ci].min()=-0.00026101, labels[:,ci].max()=0.00014099
#
# 【 ptend_t_57 】
# r2_score=-0.15951
# ri=82, ci=57
# preds[ri,ci]=1.5381e-05, labels[ri,ci]=-0.0003524
# mse[ri]=1.3526e-07, r2: 1-(mse.mean()=2.5242e-09)/(base.mean()=2.1769e-09)
# y_rms_sub[ci]=4.7419e-05, y_nanmean[ci]=-8.6302e-06, y_lower_bound[ci]=-0.0013353, y_upper_bound[ci]=0.0010396
# preds[:,ci].mean()=6.421e-06, preds[:,ci].min()=-1.4999e-05, preds[:,ci].max()=2.3782e-05
# labels[:,ci].mean()=-9.1236e-06, labels[:,ci].min()=-0.0003524, labels[:,ci].max()=0.00014926
#
# 【 ptend_t_58 】
# r2_score=-0.17338
# ri=82, ci=58
# preds[ri,ci]=-1.6004e-06, labels[ri,ci]=-0.00039009
# mse[ri]=1.5093e-07, r2: 1-(mse.mean()=3.0154e-09)/(base.mean()=2.5698e-09)
# y_rms_sub[ci]=5.1446e-05, y_nanmean[ci]=-2.5211e-05, y_lower_bound[ci]=-0.0016582, y_upper_bound[ci]=0.0010167
# preds[:,ci].mean()=-8.2817e-06, preds[:,ci].min()=-3.2084e-05, preds[:,ci].max()=9.2556e-06
# labels[:,ci].mean()=-2.449e-05, labels[:,ci].min()=-0.00039009, labels[:,ci].max()=0.00011932
#
# 【 ptend_t_59 】
# r2_score=-0.14494
# ri=82, ci=59
# preds[ri,ci]=-2.5323e-05, labels[ri,ci]=-0.00061376
# mse[ri]=3.4626e-07, r2: 1-(mse.mean()=5.3462e-09)/(base.mean()=4.6694e-09)
# y_rms_sub[ci]=7.3111e-05, y_nanmean[ci]=-6.2107e-05, y_lower_bound[ci]=-0.0017827, y_upper_bound[ci]=0.00099505
# preds[:,ci].mean()=-3.6791e-05, preds[:,ci].min()=-7.1913e-05, preds[:,ci].max()=-1.0981e-05
# labels[:,ci].mean()=-5.7674e-05, labels[:,ci].min()=-0.00061376, labels[:,ci].max()=5.2549e-05
#
# 【 ptend_q0001_12 】
# r2_score=-0.97261
# ri=221, ci=72
# preds[ri,ci]=-2.9461e-14, labels[ri,ci]=4.6884e-13
# mse[ri]=2.483e-25, r2: 1-(mse.mean()=5.5331e-27)/(base.mean()=2.805e-27)
# y_rms_sub[ci]=1.1474e-12, y_nanmean[ci]=2.9608e-15, y_lower_bound[ci]=-1.0226e-10, y_upper_bound[ci]=5.2452e-11
# preds[:,ci].mean()=1.0777e-15, preds[:,ci].min()=-1.2628e-13, preds[:,ci].max()=2.1681e-13
# labels[:,ci].mean()=-5.8868e-15, labels[:,ci].min()=-3.3119e-13, labels[:,ci].max()=4.6884e-13
#
# 【 ptend_q0001_13 】
# r2_score=-0.30798
# ri=194, ci=73
# preds[ri,ci]=-6.7398e-14, labels[ri,ci]=-7.0514e-13
# mse[ri]=4.0672e-25, r2: 1-(mse.mean()=7.7231e-27)/(base.mean()=5.9046e-27)
# y_rms_sub[ci]=9.2317e-13, y_nanmean[ci]=7.5404e-15, y_lower_bound[ci]=-8.7756e-11, y_upper_bound[ci]=1.0376e-10
# preds[:,ci].mean()=-1.8862e-15, preds[:,ci].min()=-9.4513e-14, preds[:,ci].max()=1.6977e-13
# labels[:,ci].mean()=-2.1428e-15, labels[:,ci].min()=-7.0514e-13, labels[:,ci].max()=3.6174e-13
#
# 【 ptend_q0001_14 】
# r2_score=-8.1411
# ri=362, ci=74
# preds[ri,ci]=1.8732e-12, labels[ri,ci]=-2.8234e-24
# mse[ri]=3.5088e-24, r2: 1-(mse.mean()=2.6688e-25)/(base.mean()=2.9196e-26)
# y_rms_sub[ci]=6.8011e-12, y_nanmean[ci]=9.9102e-15, y_lower_bound[ci]=-6.5676e-10, y_upper_bound[ci]=1.1027e-08
# preds[:,ci].mean()=2.5245e-15, preds[:,ci].min()=-7.6002e-13, preds[:,ci].max()=1.8732e-12
# labels[:,ci].mean()=-2.643e-14, labels[:,ci].min()=-1.5485e-12, labels[:,ci].max()=3.7029e-13
#
# 【 ptend_q0001_15 】
# r2_score=-58.356
# ri=376, ci=75
# preds[ri,ci]=7.8272e-12, labels[ri,ci]=8.7117e-15
# mse[ri]=6.1129e-23, r2: 1-(mse.mean()=5.7364e-24)/(base.mean()=9.6644e-26)
# y_rms_sub[ci]=2.8125e-11, y_nanmean[ci]=4.8055e-14, y_lower_bound[ci]=-9.0666e-09, y_upper_bound[ci]=1.5902e-08
# preds[:,ci].mean()=5.7971e-13, preds[:,ci].min()=-2.7839e-12, preds[:,ci].max()=7.8272e-12
# labels[:,ci].mean()=-4.6097e-14, labels[:,ci].min()=-1.8605e-12, labels[:,ci].max()=1.4633e-12
#
# 【 ptend_q0001_16 】
# r2_score=-8.0615
# ri=382, ci=76
# preds[ri,ci]=8.3481e-12, labels[ri,ci]=-3.3596e-13
# mse[ri]=7.5414e-23, r2: 1-(mse.mean()=6.2886e-24)/(base.mean()=6.9399e-25)
# y_rms_sub[ci]=2.8447e-11, y_nanmean[ci]=3.3179e-14, y_lower_bound[ci]=-9.9392e-09, y_upper_bound[ci]=1.4868e-08
# preds[:,ci].mean()=7.3258e-13, preds[:,ci].min()=-2.7618e-12, preds[:,ci].max()=8.3481e-12
# labels[:,ci].mean()=-1.8438e-13, labels[:,ci].min()=-8.5615e-12, labels[:,ci].max()=3.006e-12
#
# 【 ptend_q0001_17 】
# r2_score=-0.39045
# ri=146, ci=77
# preds[ri,ci]=-1.5026e-12, labels[ri,ci]=1.7189e-11
# mse[ri]=3.4939e-22, r2: 1-(mse.mean()=1.292e-23)/(base.mean()=9.2922e-24)
# y_rms_sub[ci]=2.1698e-11, y_nanmean[ci]=-2.5586e-13, y_lower_bound[ci]=-1.2228e-08, y_upper_bound[ci]=1.772e-08
# preds[:,ci].mean()=5.1645e-13, preds[:,ci].min()=-2.7548e-12, preds[:,ci].max()=6.4335e-12
# labels[:,ci].mean()=-1.7384e-13, labels[:,ci].min()=-1.8859e-11, labels[:,ci].max()=1.7189e-11
#
# 【 ptend_q0001_18 】
# r2_score=-0.089238
# ri=95, ci=78
# preds[ri,ci]=1.0345e-12, labels[ri,ci]=-2.1522e-10
# mse[ri]=4.6768e-20, r2: 1-(mse.mean()=1.8346e-22)/(base.mean()=1.6843e-22)
# y_rms_sub[ci]=4.0503e-11, y_nanmean[ci]=-5.8646e-13, y_lower_bound[ci]=-1.2401e-08, y_upper_bound[ci]=3.7913e-08
# preds[:,ci].mean()=1.9126e-12, preds[:,ci].min()=-4.788e-12, preds[:,ci].max()=1.2379e-11
# labels[:,ci].mean()=-1.3955e-12, labels[:,ci].min()=-2.1522e-10, labels[:,ci].max()=3.5008e-11
#
# 【 ptend_q0001_19 】
# r2_score=-0.23597
# ri=131, ci=79
# preds[ri,ci]=9.8332e-12, labels[ri,ci]=-1.5781e-10
# mse[ri]=2.8104e-20, r2: 1-(mse.mean()=4.614e-22)/(base.mean()=3.7331e-22)
# y_rms_sub[ci]=8.8158e-11, y_nanmean[ci]=-2.5492e-12, y_lower_bound[ci]=-1.693e-08, y_upper_bound[ci]=3.2368e-08
# preds[:,ci].mean()=4.7327e-12, preds[:,ci].min()=-1.2653e-11, preds[:,ci].max()=2.5674e-11
# labels[:,ci].mean()=-2.5116e-12, labels[:,ci].min()=-1.5781e-10, labels[:,ci].max()=9.1689e-11
#
# 【 ptend_q0001_20 】
# r2_score=-0.10019
# ri=147, ci=80
# preds[ri,ci]=-1.2943e-11, labels[ri,ci]=-7.4384e-10
# mse[ri]=5.3421e-19, r2: 1-(mse.mean()=5.7761e-21)/(base.mean()=5.2501e-21)
# y_rms_sub[ci]=1.853e-10, y_nanmean[ci]=-9.4726e-12, y_lower_bound[ci]=-1.7148e-08, y_upper_bound[ci]=2.8628e-08
# preds[:,ci].mean()=8.6895e-12, preds[:,ci].min()=-3.1612e-11, preds[:,ci].max()=5.3396e-11
# labels[:,ci].mean()=-1.345e-11, labels[:,ci].min()=-7.4384e-10, labels[:,ci].max()=1.4716e-10
#
# 【 ptend_q0001_21 】
# r2_score=-0.046138
# ri=147, ci=81
# preds[ri,ci]=-4.1172e-11, labels[ri,ci]=-2.1526e-09
# mse[ri]=4.4582e-18, r2: 1-(mse.mean()=3.3887e-20)/(base.mean()=3.2392e-20)
# y_rms_sub[ci]=4.0827e-10, y_nanmean[ci]=-3.1134e-11, y_lower_bound[ci]=-3.7091e-08, y_upper_bound[ci]=3.9277e-08
# preds[:,ci].mean()=1.1305e-11, preds[:,ci].min()=-6.8448e-11, preds[:,ci].max()=1.232e-10
# labels[:,ci].mean()=-2.5577e-11, labels[:,ci].min()=-2.1526e-09, labels[:,ci].max()=4.9359e-10
#
# 【 ptend_q0001_22 】
# r2_score=-0.0094625
# ri=147, ci=82
# preds[ri,ci]=-1.3996e-10, labels[ri,ci]=-5.9563e-09
# mse[ri]=3.383e-17, r2: 1-(mse.mean()=2.6061e-19)/(base.mean()=2.5816e-19)
# y_rms_sub[ci]=8.8322e-10, y_nanmean[ci]=-8.9123e-11, y_lower_bound[ci]=-5.9763e-08, y_upper_bound[ci]=5.8638e-08
# preds[:,ci].mean()=-5.6826e-12, preds[:,ci].min()=-1.8979e-10, preds[:,ci].max()=2.5383e-10
# labels[:,ci].mean()=-6.6997e-11, labels[:,ci].min()=-5.9563e-09, labels[:,ci].max()=2.1817e-09
#
# 【 ptend_q0001_32 】
# r2_score=0.004401
# ri=82, ci=92
# preds[ri,ci]=-8.6915e-09, labels[ri,ci]=1.7951e-07
# mse[ri]=3.542e-14, r2: 1-(mse.mean()=3.3183e-16)/(base.mean()=3.333e-16)
# y_rms_sub[ci]=1.8876e-08, y_nanmean[ci]=-2.9827e-09, y_lower_bound[ci]=-5.2679e-07, y_upper_bound[ci]=5.0128e-07
# preds[:,ci].mean()=-3.9177e-09, preds[:,ci].min()=-1.3923e-08, preds[:,ci].max()=5.8834e-09
# labels[:,ci].mean()=-2.392e-09, labels[:,ci].min()=-1.1005e-07, labels[:,ci].max()=1.7951e-07
#
# 【 ptend_q0001_33 】
# r2_score=0.0024416
# ri=82, ci=93
# preds[ri,ci]=-1.0032e-08, labels[ri,ci]=1.7463e-07
# mse[ri]=3.4102e-14, r2: 1-(mse.mean()=3.4599e-16)/(base.mean()=3.4683e-16)
# y_rms_sub[ci]=2.014e-08, y_nanmean[ci]=-2.9461e-09, y_lower_bound[ci]=-5.335e-07, y_upper_bound[ci]=5.7642e-07
# preds[:,ci].mean()=-4.6031e-09, preds[:,ci].min()=-1.4454e-08, preds[:,ci].max()=6.5859e-09
# labels[:,ci].mean()=-2.8552e-09, labels[:,ci].min()=-1.3512e-07, labels[:,ci].max()=1.7463e-07
#
# 【 ptend_q0001_34 】
# r2_score=-0.013412
# ri=17, ci=94
# preds[ri,ci]=-1.02e-08, labels[ri,ci]=-1.2276e-07
# mse[ri]=1.267e-14, r2: 1-(mse.mean()=3.3532e-16)/(base.mean()=3.3088e-16)
# y_rms_sub[ci]=2.1485e-08, y_nanmean[ci]=-2.8255e-09, y_lower_bound[ci]=-5.5964e-07, y_upper_bound[ci]=4.8333e-07
# preds[:,ci].mean()=-5.088e-09, preds[:,ci].min()=-1.5084e-08, preds[:,ci].max()=7.5482e-09
# labels[:,ci].mean()=-2.8731e-09, labels[:,ci].min()=-1.2276e-07, labels[:,ci].max()=8.9059e-08
#
# 【 ptend_q0001_35 】
# r2_score=-0.10345
# ri=17, ci=95
# preds[ri,ci]=-1.1602e-08, labels[ri,ci]=-1.4686e-07
# mse[ri]=1.8294e-14, r2: 1-(mse.mean()=4.0144e-16)/(base.mean()=3.6381e-16)
# y_rms_sub[ci]=2.3166e-08, y_nanmean[ci]=-2.6786e-09, y_lower_bound[ci]=-6.6163e-07, y_upper_bound[ci]=5.6411e-07
# preds[:,ci].mean()=-5.7737e-09, preds[:,ci].min()=-1.6053e-08, preds[:,ci].max()=8.6003e-09
# labels[:,ci].mean()=-1.9812e-09, labels[:,ci].min()=-1.4686e-07, labels[:,ci].max()=7.159e-08
#
# 【 ptend_q0001_36 】
# r2_score=-0.051578
# ri=194, ci=96
# preds[ri,ci]=-1.3204e-08, labels[ri,ci]=-1.7617e-07
# mse[ri]=2.6559e-14, r2: 1-(mse.mean()=5.354e-16)/(base.mean()=5.0914e-16)
# y_rms_sub[ci]=2.5173e-08, y_nanmean[ci]=-2.5211e-09, y_lower_bound[ci]=-7.6651e-07, y_upper_bound[ci]=6.3436e-07
# preds[:,ci].mean()=-6.0176e-09, preds[:,ci].min()=-1.7141e-08, preds[:,ci].max()=9.3363e-09
# labels[:,ci].mean()=-3.4817e-09, labels[:,ci].min()=-1.7617e-07, labels[:,ci].max()=1.231e-07
#
# 【 ptend_q0001_37 】
# r2_score=-0.036238
# ri=82, ci=97
# preds[ri,ci]=-1.2907e-08, labels[ri,ci]=-2.5789e-07
# mse[ri]=6.0019e-14, r2: 1-(mse.mean()=6.5151e-16)/(base.mean()=6.2873e-16)
# y_rms_sub[ci]=2.7535e-08, y_nanmean[ci]=-2.3596e-09, y_lower_bound[ci]=-7.6925e-07, y_upper_bound[ci]=8.8967e-07
# preds[:,ci].mean()=-6.6539e-09, preds[:,ci].min()=-1.8204e-08, preds[:,ci].max()=1.0244e-08
# labels[:,ci].mean()=-3.3825e-09, labels[:,ci].min()=-2.5789e-07, labels[:,ci].max()=8.1877e-08
#
# 【 ptend_q0001_38 】
# r2_score=-0.065417
# ri=82, ci=98
# preds[ri,ci]=-7.9762e-09, labels[ri,ci]=-2.3099e-07
# mse[ri]=4.9737e-14, r2: 1-(mse.mean()=7.4353e-16)/(base.mean()=6.9788e-16)
# y_rms_sub[ci]=3.025e-08, y_nanmean[ci]=-2.1801e-09, y_lower_bound[ci]=-7.2448e-07, y_upper_bound[ci]=8.4434e-07
# preds[:,ci].mean()=-6.5744e-09, preds[:,ci].min()=-1.9953e-08, preds[:,ci].max()=1.1435e-08
# labels[:,ci].mean()=-2.7354e-09, labels[:,ci].min()=-2.3099e-07, labels[:,ci].max()=1.8856e-07
#
# 【 ptend_q0001_39 】
# r2_score=-0.061439
# ri=82, ci=99
# preds[ri,ci]=-3.9448e-09, labels[ri,ci]=-2.8349e-07
# mse[ri]=7.8146e-14, r2: 1-(mse.mean()=9.4141e-16)/(base.mean()=8.8692e-16)
# y_rms_sub[ci]=3.3479e-08, y_nanmean[ci]=-1.9747e-09, y_lower_bound[ci]=-9.9134e-07, y_upper_bound[ci]=1.0146e-06
# preds[:,ci].mean()=-6.5214e-09, preds[:,ci].min()=-2.1431e-08, preds[:,ci].max()=1.2504e-08
# labels[:,ci].mean()=-1.4563e-09, labels[:,ci].min()=-2.8349e-07, labels[:,ci].max()=2.2414e-07
#
# 【 ptend_q0001_40 】
# r2_score=-0.11252
# ri=103, ci=100
# preds[ri,ci]=-1.5124e-08, labels[ri,ci]=2.3079e-07
# mse[ri]=6.0476e-14, r2: 1-(mse.mean()=8.286e-16)/(base.mean()=7.4479e-16)
# y_rms_sub[ci]=3.7061e-08, y_nanmean[ci]=-1.7037e-09, y_lower_bound[ci]=-9.3931e-07, y_upper_bound[ci]=9.5089e-07
# preds[:,ci].mean()=-6.4755e-09, preds[:,ci].min()=-2.2905e-08, preds[:,ci].max()=1.5359e-08
# labels[:,ci].mean()=-2.1072e-09, labels[:,ci].min()=-1.4775e-07, labels[:,ci].max()=2.3079e-07
#
# 【 ptend_q0001_41 】
# r2_score=-0.082023
# ri=81, ci=101
# preds[ri,ci]=-1.0345e-08, labels[ri,ci]=1.9272e-07
# mse[ri]=4.1236e-14, r2: 1-(mse.mean()=9.6915e-16)/(base.mean()=8.9569e-16)
# y_rms_sub[ci]=4.0956e-08, y_nanmean[ci]=-1.3449e-09, y_lower_bound[ci]=-8.7615e-07, y_upper_bound[ci]=8.9419e-07
# preds[:,ci].mean()=-6.8391e-09, preds[:,ci].min()=-2.4598e-08, preds[:,ci].max()=1.6927e-08
# labels[:,ci].mean()=-2.1357e-09, labels[:,ci].min()=-1.9039e-07, labels[:,ci].max()=1.9272e-07
#
# 【 ptend_q0001_42 】
# r2_score=-0.071858
# ri=167, ci=102
# preds[ri,ci]=5.7609e-11, labels[ri,ci]=2.5387e-07
# mse[ri]=6.4422e-14, r2: 1-(mse.mean()=1.3087e-15)/(base.mean()=1.2209e-15)
# y_rms_sub[ci]=4.4896e-08, y_nanmean[ci]=-8.726e-10, y_lower_bound[ci]=-9.603e-07, y_upper_bound[ci]=9.9325e-07
# preds[:,ci].mean()=-7.0998e-09, preds[:,ci].min()=-2.6604e-08, preds[:,ci].max()=1.8843e-08
# labels[:,ci].mean()=-2.5686e-09, labels[:,ci].min()=-2.4723e-07, labels[:,ci].max()=2.5387e-07
#
# 【 ptend_q0001_43 】
# r2_score=-0.071074
# ri=167, ci=103
# preds[ri,ci]=7.6029e-09, labels[ri,ci]=3.7916e-07
# mse[ri]=1.3806e-13, r2: 1-(mse.mean()=2.1984e-15)/(base.mean()=2.0526e-15)
# y_rms_sub[ci]=4.8654e-08, y_nanmean[ci]=-2.2778e-10, y_lower_bound[ci]=-9.0712e-07, y_upper_bound[ci]=1.0398e-06
# preds[:,ci].mean()=-7.172e-09, preds[:,ci].min()=-2.8006e-08, preds[:,ci].max()=2.1838e-08
# labels[:,ci].mean()=-1.4112e-09, labels[:,ci].min()=-3.0065e-07, labels[:,ci].max()=3.7916e-07
#
# 【 ptend_q0001_44 】
# r2_score=-0.11278
# ri=82, ci=104
# preds[ri,ci]=-3.4956e-09, labels[ri,ci]=-3.1519e-07
# mse[ri]=9.7155e-14, r2: 1-(mse.mean()=2.1188e-15)/(base.mean()=1.9041e-15)
# y_rms_sub[ci]=5.2039e-08, y_nanmean[ci]=4.7601e-10, y_lower_bound[ci]=-9.7192e-07, y_upper_bound[ci]=1.0122e-06
# preds[:,ci].mean()=-7.4802e-09, preds[:,ci].min()=-2.9474e-08, preds[:,ci].max()=2.4461e-08
# labels[:,ci].mean()=5.7802e-10, labels[:,ci].min()=-3.1519e-07, labels[:,ci].max()=2.657e-07
#
# 【 ptend_q0001_45 】
# r2_score=-0.08908
# ri=82, ci=105
# preds[ri,ci]=-5.4325e-09, labels[ri,ci]=-3.004e-07
# mse[ri]=8.7005e-14, r2: 1-(mse.mean()=2.2885e-15)/(base.mean()=2.1014e-15)
# y_rms_sub[ci]=5.5043e-08, y_nanmean[ci]=1.0514e-09, y_lower_bound[ci]=-8.972e-07, y_upper_bound[ci]=9.589e-07
# preds[:,ci].mean()=-7.1333e-09, preds[:,ci].min()=-3.02e-08, preds[:,ci].max()=2.7095e-08
# labels[:,ci].mean()=1.3846e-09, labels[:,ci].min()=-3.004e-07, labels[:,ci].max()=1.8135e-07
#
# 【 ptend_q0001_46 】
# r2_score=-0.10054
# ri=103, ci=106
# preds[ri,ci]=-1.1481e-08, labels[ri,ci]=-4.1062e-07
# mse[ri]=1.5931e-13, r2: 1-(mse.mean()=2.2931e-15)/(base.mean()=2.0836e-15)
# y_rms_sub[ci]=5.7137e-08, y_nanmean[ci]=1.2363e-09, y_lower_bound[ci]=-1.0587e-06, y_upper_bound[ci]=9.1807e-07
# preds[:,ci].mean()=-7.4358e-09, preds[:,ci].min()=-3.1502e-08, preds[:,ci].max()=2.9259e-08
# labels[:,ci].mean()=-9.0801e-10, labels[:,ci].min()=-4.1062e-07, labels[:,ci].max()=1.5438e-07
#
# 【 ptend_q0001_47 】
# r2_score=-0.073726
# ri=103, ci=107
# preds[ri,ci]=-1.3739e-08, labels[ri,ci]=-4.3811e-07
# mse[ri]=1.8009e-13, r2: 1-(mse.mean()=2.9348e-15)/(base.mean()=2.7333e-15)
# y_rms_sub[ci]=5.8241e-08, y_nanmean[ci]=9.2195e-10, y_lower_bound[ci]=-1.0514e-06, y_upper_bound[ci]=9.0348e-07
# preds[:,ci].mean()=-7.2293e-09, preds[:,ci].min()=-3.1889e-08, preds[:,ci].max()=3.0564e-08
# labels[:,ci].mean()=-3.0792e-09, labels[:,ci].min()=-4.3811e-07, labels[:,ci].max()=1.4717e-07
#
# 【 ptend_q0001_48 】
# r2_score=-0.11435
# ri=230, ci=108
# preds[ri,ci]=-1.5995e-09, labels[ri,ci]=2.1748e-07
# mse[ri]=4.7997e-14, r2: 1-(mse.mean()=2.3692e-15)/(base.mean()=2.1261e-15)
# y_rms_sub[ci]=5.8805e-08, y_nanmean[ci]=2.9053e-10, y_lower_bound[ci]=-1.0252e-06, y_upper_bound[ci]=8.3972e-07
# preds[:,ci].mean()=-7.6128e-09, preds[:,ci].min()=-3.2216e-08, preds[:,ci].max()=2.8858e-08
# labels[:,ci].mean()=1.6762e-09, labels[:,ci].min()=-2.0368e-07, labels[:,ci].max()=2.1748e-07
#
# 【 ptend_q0001_49 】
# r2_score=-0.090918
# ri=160, ci=109
# preds[ri,ci]=-1.1038e-08, labels[ri,ci]=2.5413e-07
# mse[ri]=7.0313e-14, r2: 1-(mse.mean()=2.8643e-15)/(base.mean()=2.6256e-15)
# y_rms_sub[ci]=5.8829e-08, y_nanmean[ci]=-6.6154e-10, y_lower_bound[ci]=-9.4239e-07, y_upper_bound[ci]=8.9551e-07
# preds[:,ci].mean()=-7.8998e-09, preds[:,ci].min()=-3.3157e-08, preds[:,ci].max()=3.0002e-08
# labels[:,ci].mean()=3.3939e-09, labels[:,ci].min()=-2.4577e-07, labels[:,ci].max()=2.5413e-07
#
# 【 ptend_q0001_50 】
# r2_score=-0.04554
# ri=97, ci=110
# preds[ri,ci]=-7.2917e-09, labels[ri,ci]=2.8734e-07
# mse[ri]=8.6806e-14, r2: 1-(mse.mean()=3.3612e-15)/(base.mean()=3.2148e-15)
# y_rms_sub[ci]=5.8538e-08, y_nanmean[ci]=-2.0496e-09, y_lower_bound[ci]=-8.7095e-07, y_upper_bound[ci]=8.4133e-07
# preds[:,ci].mean()=-9.1388e-09, preds[:,ci].min()=-3.4112e-08, preds[:,ci].max()=2.9393e-08
# labels[:,ci].mean()=1.4027e-09, labels[:,ci].min()=-2.6873e-07, labels[:,ci].max()=2.8734e-07
#
# 【 ptend_q0001_51 】
# r2_score=-0.025951
# ri=199, ci=111
# preds[ri,ci]=-3.6729e-09, labels[ri,ci]=2.8855e-07
# mse[ri]=8.5395e-14, r2: 1-(mse.mean()=2.915e-15)/(base.mean()=2.8412e-15)
# y_rms_sub[ci]=5.8045e-08, y_nanmean[ci]=-4.2078e-09, y_lower_bound[ci]=-9.0819e-07, y_upper_bound[ci]=7.3955e-07
# preds[:,ci].mean()=-1.0783e-08, preds[:,ci].min()=-3.6626e-08, preds[:,ci].max()=2.7927e-08
# labels[:,ci].mean()=-3.6773e-09, labels[:,ci].min()=-2.4088e-07, labels[:,ci].max()=2.8855e-07
#
# 【 ptend_q0001_52 】
# r2_score=-0.039374
# ri=168, ci=112
# preds[ri,ci]=-8.1903e-09, labels[ri,ci]=2.7796e-07
# mse[ri]=8.188e-14, r2: 1-(mse.mean()=3.0789e-15)/(base.mean()=2.9623e-15)
# y_rms_sub[ci]=5.732e-08, y_nanmean[ci]=-7.438e-09, y_lower_bound[ci]=-8.7412e-07, y_upper_bound[ci]=7.6979e-07
# preds[:,ci].mean()=-1.3005e-08, preds[:,ci].min()=-3.9473e-08, preds[:,ci].max()=2.293e-08
# labels[:,ci].mean()=-6.1258e-09, labels[:,ci].min()=-2.5964e-07, labels[:,ci].max()=2.7796e-07
#
# 【 ptend_q0001_53 】
# r2_score=-0.07298
# ri=166, ci=113
# preds[ri,ci]=-1.7919e-08, labels[ri,ci]=3.8548e-07
# mse[ri]=1.6273e-13, r2: 1-(mse.mean()=3.4517e-15)/(base.mean()=3.2169e-15)
# y_rms_sub[ci]=5.6315e-08, y_nanmean[ci]=-1.1539e-08, y_lower_bound[ci]=-8.6636e-07, y_upper_bound[ci]=6.3594e-07
# preds[:,ci].mean()=-1.6216e-08, preds[:,ci].min()=-4.2239e-08, preds[:,ci].max()=1.707e-08
# labels[:,ci].mean()=-6.2416e-09, labels[:,ci].min()=-2.4488e-07, labels[:,ci].max()=3.8548e-07
#
# 【 ptend_q0001_54 】
# r2_score=-0.082416
# ri=238, ci=114
# preds[ri,ci]=-4.6177e-09, labels[ri,ci]=-3.2969e-07
# mse[ri]=1.0567e-13, r2: 1-(mse.mean()=3.0989e-15)/(base.mean()=2.863e-15)
# y_rms_sub[ci]=5.4508e-08, y_nanmean[ci]=-1.6028e-08, y_lower_bound[ci]=-8.2817e-07, y_upper_bound[ci]=5.9998e-07
# preds[:,ci].mean()=-1.9483e-08, preds[:,ci].min()=-4.4954e-08, preds[:,ci].max()=1.2475e-08
# labels[:,ci].mean()=-1.0733e-08, labels[:,ci].min()=-3.2969e-07, labels[:,ci].max()=2.6846e-07
#
# 【 ptend_q0001_55 】
# r2_score=-0.1586
# ri=166, ci=115
# preds[ri,ci]=-6.1991e-09, labels[ri,ci]=-2.2381e-07
# mse[ri]=4.7355e-14, r2: 1-(mse.mean()=2.156e-15)/(base.mean()=1.8608e-15)
# y_rms_sub[ci]=5.1545e-08, y_nanmean[ci]=-1.9473e-08, y_lower_bound[ci]=-9.0803e-07, y_upper_bound[ci]=5.6541e-07
# preds[:,ci].mean()=-2.1281e-08, preds[:,ci].min()=-4.7116e-08, preds[:,ci].max()=6.1608e-09
# labels[:,ci].mean()=-1.939e-08, labels[:,ci].min()=-2.2381e-07, labels[:,ci].max()=1.6662e-07
#
# 【 ptend_q0001_56 】
# r2_score=-0.167
# ri=157, ci=116
# preds[ri,ci]=-5.895e-09, labels[ri,ci]=-1.9062e-07
# mse[ri]=3.4123e-14, r2: 1-(mse.mean()=2.1755e-15)/(base.mean()=1.8642e-15)
# y_rms_sub[ci]=4.8764e-08, y_nanmean[ci]=-2.127e-08, y_lower_bound[ci]=-1.0378e-06, y_upper_bound[ci]=5.039e-07
# preds[:,ci].mean()=-2.123e-08, preds[:,ci].min()=-4.8788e-08, preds[:,ci].max()=2.8211e-09
# labels[:,ci].mean()=-2.0446e-08, labels[:,ci].min()=-2.0761e-07, labels[:,ci].max()=9.8807e-08
#
# 【 ptend_q0001_57 】
# r2_score=-0.18911
# ri=95, ci=117
# preds[ri,ci]=-2.2487e-08, labels[ri,ci]=-2.0341e-07
# mse[ri]=3.2732e-14, r2: 1-(mse.mean()=1.8668e-15)/(base.mean()=1.5699e-15)
# y_rms_sub[ci]=4.4504e-08, y_nanmean[ci]=-1.9714e-08, y_lower_bound[ci]=-1.041e-06, y_upper_bound[ci]=4.8182e-07
# preds[:,ci].mean()=-1.7813e-08, preds[:,ci].min()=-4.4425e-08, preds[:,ci].max()=2.4982e-09
# labels[:,ci].mean()=-1.7015e-08, labels[:,ci].min()=-2.0341e-07, labels[:,ci].max()=1.1328e-07
#
# 【 ptend_q0001_58 】
# r2_score=-0.23361
# ri=83, ci=118
# preds[ri,ci]=-1.2041e-08, labels[ri,ci]=-2.0634e-07
# mse[ri]=3.775e-14, r2: 1-(mse.mean()=1.747e-15)/(base.mean()=1.4162e-15)
# y_rms_sub[ci]=4.2677e-08, y_nanmean[ci]=-1.8091e-08, y_lower_bound[ci]=-9.3117e-07, y_upper_bound[ci]=5.6156e-07
# preds[:,ci].mean()=-1.5275e-08, preds[:,ci].min()=-4.1205e-08, preds[:,ci].max()=2.4393e-09
# labels[:,ci].mean()=-1.6099e-08, labels[:,ci].min()=-2.0634e-07, labels[:,ci].max()=1.1058e-07
#
# 【 ptend_q0001_59 】
# r2_score=-0.36634
# ri=103, ci=119
# preds[ri,ci]=-1.3163e-10, labels[ri,ci]=-1.9714e-07
# mse[ri]=3.8811e-14, r2: 1-(mse.mean()=1.6975e-15)/(base.mean()=1.2424e-15)
# y_rms_sub[ci]=3.8162e-08, y_nanmean[ci]=-1.441e-08, y_lower_bound[ci]=-9.8815e-07, y_upper_bound[ci]=6.6994e-07
# preds[:,ci].mean()=-1.0564e-08, preds[:,ci].min()=-3.4507e-08, preds[:,ci].max()=3.5961e-09
# labels[:,ci].mean()=-1.3436e-08, labels[:,ci].min()=-1.9714e-07, labels[:,ci].max()=1.1855e-07
#
# 【 ptend_q0002_29 】
# r2_score=-0.19501
# ri=147, ci=149
# preds[ri,ci]=3.1887e-12, labels[ri,ci]=-1.3675e-09
# mse[ri]=1.8788e-18, r2: 1-(mse.mean()=1.2202e-20)/(base.mean()=1.0211e-20)
# y_rms_sub[ci]=3.3313e-10, y_nanmean[ci]=-3.1629e-11, y_lower_bound[ci]=-3.9761e-08, y_upper_bound[ci]=2.315e-08
# preds[:,ci].mean()=1.0006e-11, preds[:,ci].min()=-1.4041e-10, preds[:,ci].max()=1.9764e-10
# labels[:,ci].mean()=-1.3421e-11, labels[:,ci].min()=-1.3675e-09, labels[:,ci].max()=0
#
# 【 ptend_q0002_30 】
# r2_score=-0.063704
# ri=147, ci=150
# preds[ri,ci]=-4.2191e-11, labels[ri,ci]=-4.696e-09
# mse[ri]=2.1658e-17, r2: 1-(mse.mean()=1.7961e-19)/(base.mean()=1.6885e-19)
# y_rms_sub[ci]=6.9795e-10, y_nanmean[ci]=-8.075e-11, y_lower_bound[ci]=-6.0293e-08, y_upper_bound[ci]=4.2678e-08
# preds[:,ci].mean()=3.0878e-11, preds[:,ci].min()=-3.5612e-10, preds[:,ci].max()=3.6386e-10
# labels[:,ci].mean()=-6.8472e-11, labels[:,ci].min()=-4.696e-09, labels[:,ci].max()=9.7829e-10
#
# 【 ptend_q0002_31 】
# r2_score=-0.056584
# ri=82, ci=151
# preds[ri,ci]=-2.0201e-10, labels[ri,ci]=6.266e-09
# mse[ri]=4.1835e-17, r2: 1-(mse.mean()=4.5805e-19)/(base.mean()=4.3352e-19)
# y_rms_sub[ci]=1.1305e-09, y_nanmean[ci]=-9.6265e-11, y_lower_bound[ci]=-6.5981e-08, y_upper_bound[ci]=6.6197e-08
# ...
# y_rms_sub[ci]=7.0901e-06, y_nanmean[ci]=3.303e-08, y_lower_bound[ci]=-0.00045441, y_upper_bound[ci]=0.00043063
# preds[:,ci].mean()=-3.6201e-07, preds[:,ci].min()=-3.2412e-06, preds[:,ci].max()=3.2338e-06
# labels[:,ci].mean()=2.0209e-07, labels[:,ci].min()=-4.8216e-05, labels[:,ci].max()=6.2858e-05
#
# 【 ptend_v_34 】
# r2_score=-0.12734
# ri=219, ci=334
# preds[ri,ci]=-2.7729e-06, labels[ri,ci]=4.6167e-05
# mse[ri]=2.3952e-09, r2: 1-(mse.mean()=3.0364e-11)/(base.mean()=2.6934e-11)
# y_rms_sub[ci]=6.8327e-06, y_nanmean[ci]=2.9465e-08, y_lower_bound[ci]=-0.00062345, y_upper_bound[ci]=0.00043808
# preds[:,ci].mean()=-4.079e-07, preds[:,ci].min()=-3.3593e-06, preds[:,ci].max()=2.6243e-06
# labels[:,ci].mean()=2.0877e-07, labels[:,ci].min()=-2.6223e-05, labels[:,ci].max()=4.6167e-05
#
# 【 ptend_v_35 】
# r2_score=-0.05128
# ri=220, ci=335
# preds[ri,ci]=-1.6875e-06, labels[ri,ci]=-6.3182e-05
# mse[ri]=3.7816e-09, r2: 1-(mse.mean()=4.3419e-11)/(base.mean()=4.1301e-11)
# y_rms_sub[ci]=6.8515e-06, y_nanmean[ci]=4.2831e-09, y_lower_bound[ci]=-0.00057385, y_upper_bound[ci]=0.00042941
# preds[:,ci].mean()=-6.0382e-07, preds[:,ci].min()=-3.2944e-06, preds[:,ci].max()=2.8015e-06
# labels[:,ci].mean()=-1.9736e-07, labels[:,ci].min()=-6.3182e-05, labels[:,ci].max()=4.3095e-05
#
# 【 ptend_v_36 】
# r2_score=-0.1052
# ri=82, ci=336
# preds[ri,ci]=-1.5793e-06, labels[ri,ci]=-5.3384e-05
# mse[ri]=2.6837e-09, r2: 1-(mse.mean()=2.6998e-11)/(base.mean()=2.4429e-11)
# y_rms_sub[ci]=7.1686e-06, y_nanmean[ci]=-6.574e-08, y_lower_bound[ci]=-0.0006454, y_upper_bound[ci]=0.00055903
# preds[:,ci].mean()=-7.6582e-07, preds[:,ci].min()=-3.5601e-06, preds[:,ci].max()=2.8158e-06
# labels[:,ci].mean()=-1.9005e-07, labels[:,ci].min()=-5.3384e-05, labels[:,ci].max()=2.1006e-05
#
# 【 ptend_v_37 】
# r2_score=-0.060375
# ri=82, ci=337
# preds[ri,ci]=-1.8772e-06, labels[ri,ci]=-6.7282e-05
# mse[ri]=4.2778e-09, r2: 1-(mse.mean()=3.3481e-11)/(base.mean()=3.1574e-11)
# y_rms_sub[ci]=7.7816e-06, y_nanmean[ci]=-1.6071e-07, y_lower_bound[ci]=-0.00056502, y_upper_bound[ci]=0.00052773
# preds[:,ci].mean()=-1.0426e-06, preds[:,ci].min()=-4.0326e-06, preds[:,ci].max()=2.9067e-06
# labels[:,ci].mean()=-4.7347e-07, labels[:,ci].min()=-6.7282e-05, labels[:,ci].max()=1.7031e-05
#
# 【 ptend_v_38 】
# r2_score=-0.082665
# ri=82, ci=338
# preds[ri,ci]=-1.4135e-06, labels[ri,ci]=-6.2198e-05
# mse[ri]=3.6947e-09, r2: 1-(mse.mean()=4.1542e-11)/(base.mean()=3.837e-11)
# y_rms_sub[ci]=8.5715e-06, y_nanmean[ci]=-2.4989e-07, y_lower_bound[ci]=-0.00052173, y_upper_bound[ci]=0.00053076
# preds[:,ci].mean()=-1.1828e-06, preds[:,ci].min()=-4.3035e-06, preds[:,ci].max()=3.165e-06
# labels[:,ci].mean()=-5.6622e-07, labels[:,ci].min()=-6.2198e-05, labels[:,ci].max()=2.3098e-05
#
# 【 ptend_v_39 】
# r2_score=-0.11047
# ri=82, ci=339
# preds[ri,ci]=-1.2018e-06, labels[ri,ci]=-8.166e-05
# mse[ri]=6.4735e-09, r2: 1-(mse.mean()=4.9075e-11)/(base.mean()=4.4193e-11)
# y_rms_sub[ci]=9.3059e-06, y_nanmean[ci]=-3.0568e-07, y_lower_bound[ci]=-0.00055067, y_upper_bound[ci]=0.00047858
# preds[:,ci].mean()=-1.3842e-06, preds[:,ci].min()=-5.0173e-06, preds[:,ci].max()=3.7687e-06
# labels[:,ci].mean()=-6.7341e-07, labels[:,ci].min()=-8.166e-05, labels[:,ci].max()=1.6543e-05
#
# 【 ptend_v_40 】
# r2_score=-0.096619
# ri=82, ci=340
# preds[ri,ci]=-9.8472e-07, labels[ri,ci]=-0.00010617
# mse[ri]=1.1065e-08, r2: 1-(mse.mean()=6.9305e-11)/(base.mean()=6.3198e-11)
# y_rms_sub[ci]=9.9741e-06, y_nanmean[ci]=-3.0786e-07, y_lower_bound[ci]=-0.0005536, y_upper_bound[ci]=0.00043664
# preds[:,ci].mean()=-1.5395e-06, preds[:,ci].min()=-5.1902e-06, preds[:,ci].max()=3.6976e-06
# labels[:,ci].mean()=-8.8488e-07, labels[:,ci].min()=-0.00010617, labels[:,ci].max()=1.5165e-05
#
# 【 ptend_v_41 】
# r2_score=-0.088582
# ri=82, ci=341
# preds[ri,ci]=-9.1399e-07, labels[ri,ci]=-0.00012316
# mse[ri]=1.4944e-08, r2: 1-(mse.mean()=8.7458e-11)/(base.mean()=8.0341e-11)
# y_rms_sub[ci]=1.0626e-05, y_nanmean[ci]=-2.303e-07, y_lower_bound[ci]=-0.00053878, y_upper_bound[ci]=0.00051859
# preds[:,ci].mean()=-1.6207e-06, preds[:,ci].min()=-5.6321e-06, preds[:,ci].max()=3.4537e-06
# labels[:,ci].mean()=-1.1383e-06, labels[:,ci].min()=-0.00012316, labels[:,ci].max()=2.7765e-05
#
# 【 ptend_v_42 】
# r2_score=-0.074371
# ri=82, ci=342
# preds[ri,ci]=-8.4851e-07, labels[ri,ci]=-0.00010856
# mse[ri]=1.1601e-08, r2: 1-(mse.mean()=1.3846e-10)/(base.mean()=1.2888e-10)
# y_rms_sub[ci]=1.1307e-05, y_nanmean[ci]=-8.6547e-08, y_lower_bound[ci]=-0.00061905, y_upper_bound[ci]=0.00061273
# preds[:,ci].mean()=-1.6192e-06, preds[:,ci].min()=-5.7145e-06, preds[:,ci].max()=3.974e-06
# labels[:,ci].mean()=-1.5595e-06, labels[:,ci].min()=-0.00010856, labels[:,ci].max()=5.7267e-05
#
# 【 ptend_v_43 】
# r2_score=-0.08172
# ri=379, ci=343
# preds[ri,ci]=1.5386e-06, labels[ri,ci]=-0.00012075
# mse[ri]=1.4956e-08, r2: 1-(mse.mean()=1.2274e-10)/(base.mean()=1.1347e-10)
# y_rms_sub[ci]=1.2087e-05, y_nanmean[ci]=1.0501e-07, y_lower_bound[ci]=-0.00050406, y_upper_bound[ci]=0.00063053
# preds[:,ci].mean()=-1.6349e-06, preds[:,ci].min()=-5.5551e-06, preds[:,ci].max()=4.3426e-06
# labels[:,ci].mean()=-1.2659e-06, labels[:,ci].min()=-0.00012075, labels[:,ci].max()=3.2007e-05
#
# 【 ptend_v_44 】
# r2_score=-0.087756
# ri=379, ci=344
# preds[ri,ci]=8.0909e-07, labels[ri,ci]=-8.0071e-05
# mse[ri]=6.5415e-09, r2: 1-(mse.mean()=1.0916e-10)/(base.mean()=1.0036e-10)
# y_rms_sub[ci]=1.2977e-05, y_nanmean[ci]=3.0829e-07, y_lower_bound[ci]=-0.00057223, y_upper_bound[ci]=0.00075516
# preds[:,ci].mean()=-1.8238e-06, preds[:,ci].min()=-6.1038e-06, preds[:,ci].max()=3.78e-06
# labels[:,ci].mean()=-1.4676e-06, labels[:,ci].min()=-8.0071e-05, labels[:,ci].max()=3.6178e-05
#
# 【 ptend_v_45 】
# r2_score=-0.053987
# ri=223, ci=345
# preds[ri,ci]=-3.5776e-06, labels[ri,ci]=7.2536e-05
# mse[ri]=5.7933e-09, r2: 1-(mse.mean()=1.2172e-10)/(base.mean()=1.1548e-10)
# y_rms_sub[ci]=1.4019e-05, y_nanmean[ci]=4.772e-07, y_lower_bound[ci]=-0.00055846, y_upper_bound[ci]=0.00055678
# preds[:,ci].mean()=-1.7066e-06, preds[:,ci].min()=-5.803e-06, preds[:,ci].max()=4.6772e-06
# labels[:,ci].mean()=-1.2492e-06, labels[:,ci].min()=-7.3935e-05, labels[:,ci].max()=7.2536e-05
#
# 【 ptend_v_46 】
# r2_score=-0.034561
# ri=99, ci=346
# preds[ri,ci]=-1.278e-06, labels[ri,ci]=-7.7581e-05
# mse[ri]=5.8222e-09, r2: 1-(mse.mean()=1.2069e-10)/(base.mean()=1.1666e-10)
# y_rms_sub[ci]=1.5152e-05, y_nanmean[ci]=5.9757e-07, y_lower_bound[ci]=-0.0004354, y_upper_bound[ci]=0.00074633
# preds[:,ci].mean()=-1.9142e-06, preds[:,ci].min()=-6.3217e-06, preds[:,ci].max()=5.2667e-06
# labels[:,ci].mean()=-1.4461e-06, labels[:,ci].min()=-7.7581e-05, labels[:,ci].max()=5.3763e-05
#
# 【 ptend_v_47 】
# r2_score=0.0014166
# ri=379, ci=347
# preds[ri,ci]=8.2548e-07, labels[ri,ci]=0.00010265
# mse[ri]=1.0368e-08, r2: 1-(mse.mean()=1.8034e-10)/(base.mean()=1.8059e-10)
# y_rms_sub[ci]=1.6181e-05, y_nanmean[ci]=6.1516e-07, y_lower_bound[ci]=-0.00045268, y_upper_bound[ci]=0.00062893
# preds[:,ci].mean()=-1.9459e-06, preds[:,ci].min()=-6.722e-06, preds[:,ci].max()=5.5988e-06
# labels[:,ci].mean()=-1.1942e-06, labels[:,ci].min()=-8.0027e-05, labels[:,ci].max()=0.00010265
#
# 【 ptend_v_48 】
# r2_score=-0.011815
# ri=82, ci=348
# preds[ri,ci]=-3.8011e-06, labels[ri,ci]=7.0916e-05
# mse[ri]=5.5826e-09, r2: 1-(mse.mean()=1.7903e-10)/(base.mean()=1.7694e-10)
# y_rms_sub[ci]=1.7171e-05, y_nanmean[ci]=5.2246e-07, y_lower_bound[ci]=-0.00045699, y_upper_bound[ci]=0.00067173
# preds[:,ci].mean()=-2.161e-06, preds[:,ci].min()=-7.8716e-06, preds[:,ci].max()=6.5995e-06
# labels[:,ci].mean()=-1.6752e-06, labels[:,ci].min()=-6.4954e-05, labels[:,ci].max()=7.0916e-05
#
# 【 ptend_v_49 】
# r2_score=-0.010441
# ri=379, ci=349
# preds[ri,ci]=-1.4117e-06, labels[ri,ci]=0.00013813
# mse[ri]=1.9473e-08, r2: 1-(mse.mean()=3.178e-10)/(base.mean()=3.1452e-10)
# y_rms_sub[ci]=1.8276e-05, y_nanmean[ci]=3.3562e-07, y_lower_bound[ci]=-0.00051215, y_upper_bound[ci]=0.000759
# preds[:,ci].mean()=-2.4331e-06, preds[:,ci].min()=-8.7936e-06, preds[:,ci].max()=7.043e-06
# labels[:,ci].mean()=-7.3413e-07, labels[:,ci].min()=-9.5387e-05, labels[:,ci].max()=0.00013813
#
# 【 ptend_v_50 】
# r2_score=-0.039909
# ri=379, ci=350
# preds[ri,ci]=-3.1861e-06, labels[ri,ci]=0.0001411
# mse[ri]=2.0818e-08, r2: 1-(mse.mean()=4.0383e-10)/(base.mean()=3.8833e-10)
# y_rms_sub[ci]=1.9675e-05, y_nanmean[ci]=9.3188e-08, y_lower_bound[ci]=-0.00054517, y_upper_bound[ci]=0.00066386
# preds[:,ci].mean()=-2.9484e-06, preds[:,ci].min()=-9.4403e-06, preds[:,ci].max()=6.0952e-06
# labels[:,ci].mean()=3.7353e-08, labels[:,ci].min()=-0.00013349, labels[:,ci].max()=0.0001411
#
# 【 ptend_v_51 】
# r2_score=-0.14302
# ri=110, ci=351
# preds[ri,ci]=-1.0246e-05, labels[ri,ci]=0.00012164
# mse[ri]=1.7393e-08, r2: 1-(mse.mean()=4.3299e-10)/(base.mean()=3.7881e-10)
# y_rms_sub[ci]=2.1711e-05, y_nanmean[ci]=-2.0639e-07, y_lower_bound[ci]=-0.00075076, y_upper_bound[ci]=0.00075921
# preds[:,ci].mean()=-3.394e-06, preds[:,ci].min()=-1.0907e-05, preds[:,ci].max()=6.142e-06
# labels[:,ci].mean()=1.3713e-06, labels[:,ci].min()=-0.00012136, labels[:,ci].max()=0.00012164
#
# 【 ptend_v_52 】
# r2_score=-0.28627
# ri=111, ci=352
# preds[ri,ci]=-1.0184e-05, labels[ri,ci]=0.00012228
# mse[ri]=1.7547e-08, r2: 1-(mse.mean()=4.9287e-10)/(base.mean()=3.8318e-10)
# y_rms_sub[ci]=2.4546e-05, y_nanmean[ci]=-6.3433e-07, y_lower_bound[ci]=-0.00094299, y_upper_bound[ci]=0.00050847
# preds[:,ci].mean()=-4.2485e-06, preds[:,ci].min()=-1.2528e-05, preds[:,ci].max()=6.5778e-06
# labels[:,ci].mean()=3.8478e-06, labels[:,ci].min()=-5.8655e-05, labels[:,ci].max()=0.00012228
#
# 【 ptend_v_53 】
# r2_score=-0.35246
# ri=372, ci=353
# preds[ri,ci]=-6.4927e-06, labels[ri,ci]=0.00011684
# mse[ri]=1.5212e-08, r2: 1-(mse.mean()=5.9105e-10)/(base.mean()=4.3702e-10)
# y_rms_sub[ci]=2.7521e-05, y_nanmean[ci]=-9.8461e-07, y_lower_bound[ci]=-0.0011096, y_upper_bound[ci]=0.00066651
# preds[:,ci].mean()=-4.8725e-06, preds[:,ci].min()=-1.4752e-05, preds[:,ci].max()=7.0006e-06
# labels[:,ci].mean()=5.0258e-06, labels[:,ci].min()=-7.82e-05, labels[:,ci].max()=0.00011684
#
# 【 ptend_v_54 】
# r2_score=-0.31707
# ri=238, ci=354
# preds[ri,ci]=-4.9258e-06, labels[ri,ci]=0.00013483
# mse[ri]=1.9531e-08, r2: 1-(mse.mean()=6.8456e-10)/(base.mean()=5.1976e-10)
# y_rms_sub[ci]=2.9428e-05, y_nanmean[ci]=-1.0975e-06, y_lower_bound[ci]=-0.001148, y_upper_bound[ci]=0.00060749
# preds[:,ci].mean()=-4.9382e-06, preds[:,ci].min()=-1.7213e-05, preds[:,ci].max()=7.8973e-06
# labels[:,ci].mean()=5.3723e-06, labels[:,ci].min()=-8.4645e-05, labels[:,ci].max()=0.00013483
#
# 【 ptend_v_55 】
# r2_score=-0.28389
# ri=332, ci=355
# preds[ri,ci]=-1.2145e-05, labels[ri,ci]=0.00015413
# mse[ri]=2.7647e-08, r2: 1-(mse.mean()=6.5228e-10)/(base.mean()=5.0805e-10)
# y_rms_sub[ci]=2.9771e-05, y_nanmean[ci]=-9.9422e-07, y_lower_bound[ci]=-0.00067954, y_upper_bound[ci]=0.0006142
# preds[:,ci].mean()=-4.6115e-06, preds[:,ci].min()=-1.6755e-05, preds[:,ci].max()=7.0375e-06
# labels[:,ci].mean()=4.4225e-06, labels[:,ci].min()=-9.1767e-05, labels[:,ci].max()=0.00015413
#
# 【 ptend_v_56 】
# r2_score=-0.14457
# ri=114, ci=356
# preds[ri,ci]=1.1594e-06, labels[ri,ci]=-0.0001222
# mse[ri]=1.5218e-08, r2: 1-(mse.mean()=5.6218e-10)/(base.mean()=4.9118e-10)
# y_rms_sub[ci]=2.9421e-05, y_nanmean[ci]=-5.0803e-07, y_lower_bound[ci]=-0.00058765, y_upper_bound[ci]=0.00057799
# preds[:,ci].mean()=-3.6721e-06, preds[:,ci].min()=-1.5711e-05, preds[:,ci].max()=7.2713e-06
# labels[:,ci].mean()=1.246e-06, labels[:,ci].min()=-0.0001222, labels[:,ci].max()=0.00010089
#
# 【 ptend_v_57 】
# r2_score=-0.085241
# ri=338, ci=357
# preds[ri,ci]=3.3992e-07, labels[ri,ci]=0.00010133
# mse[ri]=1.02e-08, r2: 1-(mse.mean()=5.2624e-10)/(base.mean()=4.849e-10)
# y_rms_sub[ci]=2.7569e-05, y_nanmean[ci]=6.2312e-07, y_lower_bound[ci]=-0.00048601, y_upper_bound[ci]=0.0004859
# preds[:,ci].mean()=-1.9066e-06, preds[:,ci].min()=-1.2697e-05, preds[:,ci].max()=8.1583e-06
# labels[:,ci].mean()=1.1116e-06, labels[:,ci].min()=-9.8601e-05, labels[:,ci].max()=0.00010133
#
# 【 ptend_v_58 】
# r2_score=-0.079871
# ri=109, ci=358
# preds[ri,ci]=-1.4691e-06, labels[ri,ci]=-0.00013658
# mse[ri]=1.8256e-08, r2: 1-(mse.mean()=5.0312e-10)/(base.mean()=4.6591e-10)
# y_rms_sub[ci]=2.4282e-05, y_nanmean[ci]=1.3958e-06, y_lower_bound[ci]=-0.00055084, y_upper_bound[ci]=0.00050151
# preds[:,ci].mean()=-4.6076e-07, preds[:,ci].min()=-9.3873e-06, preds[:,ci].max()=8.0747e-06
# labels[:,ci].mean()=2.7176e-07, labels[:,ci].min()=-0.00013658, labels[:,ci].max()=8.6003e-05
#
# 【 ptend_v_59 】
# r2_score=0.0038366
# ri=223, ci=359
# preds[ri,ci]=3.8321e-06, labels[ri,ci]=-0.00017631
# mse[ri]=3.245e-08, r2: 1-(mse.mean()=1.0201e-09)/(base.mean()=1.024e-09)
# y_rms_sub[ci]=3.4253e-05, y_nanmean[ci]=6.2858e-07, y_lower_bound[ci]=-0.00077093, y_upper_bound[ci]=0.00073063
# preds[:,ci].mean()=-1.2057e-06, preds[:,ci].min()=-1.6163e-05, preds[:,ci].max()=1.0138e-05
# labels[:,ci].mean()=-1.8412e-06, labels[:,ci].min()=-0.00017631, labels[:,ci].max()=0.0001401
#
# 【 cam_out_NETSW 】
# r2_score=-0.00046325
# ri=132, ci=360
# preds[ri,ci]=157.82, labels[ri,ci]=881.22
# mse[ri]=5.233e+05, r2: 1-(mse.mean()=63354)/(base.mean()=63325)
# y_rms_sub[ci]=246.69, y_nanmean[ci]=158.3, y_lower_bound[ci]=0, y_upper_bound[ci]=1106.7
# preds[:,ci].mean()=157.82, preds[:,ci].min()=157.82, preds[:,ci].max()=157.83
# labels[:,ci].mean()=163.24, labels[:,ci].min()=0, labels[:,ci].max()=881.22
#
# 【 cam_out_FLWDS 】
# r2_score=-0.026932
# ri=361, ci=361
# preds[ri,ci]=351.64, labels[ri,ci]=103.2
# mse[ri]=61724, r2: 1-(mse.mean()=6437.2)/(base.mean()=6268.4)
# y_rms_sub[ci]=72.034, y_nanmean[ci]=351.2, y_lower_bound[ci]=57.218, y_upper_bound[ci]=528.1
# preds[:,ci].mean()=351.64, preds[:,ci].min()=351.64, preds[:,ci].max()=351.64
# labels[:,ci].mean()=338.65, labels[:,ci].min()=103.2, labels[:,ci].max()=446.29
#
# 【 cam_out_PRECSC 】
# r2_score=-0.0066496
# ri=326, ci=362
# preds[ri,ci]=2.6418e-09, labels[ri,ci]=6.3311e-08
# mse[ri]=3.6808e-15, r2: 1-(mse.mean()=6.4091e-17)/(base.mean()=6.3668e-17)
# y_rms_sub[ci]=7.4003e-09, y_nanmean[ci]=2.7387e-09, y_lower_bound[ci]=0, y_upper_bound[ci]=2.9351e-07
# preds[:,ci].mean()=2.6418e-09, preds[:,ci].min()=2.6417e-09, preds[:,ci].max()=2.6419e-09
# labels[:,ci].mean()=3.2925e-09, labels[:,ci].min()=0, labels[:,ci].max()=6.3311e-08
#
# 【 cam_out_PRECC 】
# r2_score=-0.0062553
# ri=147, ci=363
# preds[ri,ci]=3.0124e-08, labels[ri,ci]=4.5577e-07
# mse[ri]=1.8117e-13, r2: 1-(mse.mean()=4.3179e-15)/(base.mean()=4.2911e-15)
# y_rms_sub[ci]=8.1835e-08, y_nanmean[ci]=2.9191e-08, y_lower_bound[ci]=0, y_upper_bound[ci]=2.2007e-06
# preds[:,ci].mean()=3.0124e-08, preds[:,ci].min()=3.0123e-08, preds[:,ci].max()=3.0125e-08
# labels[:,ci].mean()=2.4942e-08, labels[:,ci].min()=0, labels[:,ci].max()=4.5577e-07
#
# 【 cam_out_SOLS 】
# r2_score=-3.5019e-05
# ri=149, ci=364
# preds[ri,ci]=61.731, labels[ri,ci]=418.87
# mse[ri]=1.2754e+05, r2: 1-(mse.mean()=11388)/(base.mean()=11388)
# y_rms_sub[ci]=110.25, y_nanmean[ci]=61.79, y_lower_bound[ci]=0, y_upper_bound[ci]=518.9
# preds[:,ci].mean()=61.731, preds[:,ci].min()=61.73, preds[:,ci].max()=61.733
# labels[:,ci].mean()=61.096, labels[:,ci].min()=0, labels[:,ci].max()=418.87
#
# 【 cam_out_SOLL 】
# r2_score=-8.0895e-05
# ri=132, ci=365
# preds[ri,ci]=69.582, labels[ri,ci]=441.81
# mse[ri]=1.3856e+05, r2: 1-(mse.mean()=13255)/(base.mean()=13254)
# y_rms_sub[ci]=116.42, y_nanmean[ci]=67.31, y_lower_bound[ci]=0, y_upper_bound[ci]=575.26
# preds[:,ci].mean()=69.582, preds[:,ci].min()=69.58, preds[:,ci].max()=69.584
# labels[:,ci].mean()=68.553, labels[:,ci].min()=0, labels[:,ci].max()=441.81
#
# 【 cam_out_SOLSD 】
# r2_score=-0.0002176
# ri=148, ci=366
# preds[ri,ci]=34.266, labels[ri,ci]=203.18
# mse[ri]=28532, r2: 1-(mse.mean()=2163.8)/(base.mean()=2163.4)
# y_rms_sub[ci]=46.432, y_nanmean[ci]=33.474, y_lower_bound[ci]=0, y_upper_bound[ci]=425.18
# preds[:,ci].mean()=34.266, preds[:,ci].min()=34.265, preds[:,ci].max()=34.266
# labels[:,ci].mean()=34.951, labels[:,ci].min()=0, labels[:,ci].max()=203.18
#
# 【 cam_out_SOLLD 】
# r2_score=-1.1634e-05
# ri=133, ci=367
# preds[ri,ci]=17.949, labels[ri,ci]=140.61
# mse[ri]=15046, r2: 1-(mse.mean()=811.81)/(base.mean()=811.8)
# y_rms_sub[ci]=29.733, y_nanmean[ci]=17.693, y_lower_bound[ci]=0, y_upper_bound[ci]=271.07
# preds[:,ci].mean()=17.949, preds[:,ci].min()=17.948, preds[:,ci].max()=17.949
# labels[:,ci].mean()=18.052, labels[:,ci].min()=0, labels[:,ci].max()=140.61

# %% [markdown]
# ## 値が大きくないやつ

# %%
preds = predict_df[:, 1:].to_numpy()
labels = label_df[:, 1:].to_numpy()

scale_dir = ""
y_nanmean = np.load(Path(cfg.exp.scale_dir) / "y_nanmean.npy")
y_rms_sub = np.load(Path(cfg.exp.scale_dir) / "y_rms_sub.npy")
y_lower_bound = np.load(Path(cfg.exp.scale_dir) / "y_nanmin.npy")
y_upper_bound = np.load(Path(cfg.exp.scale_dir) / "y_nanmax.npy")


for ci, col in enumerate(target_columns):
    r2_score = r2_score_dict[col]
    if r2_score > 0.5:
        continue

    print("【", col, "】")
    print(f"{r2_score=:.5g}")

    mse = (preds[:, ci] - labels[:, ci]) ** 2
    base = (labels[:, ci] - labels[:, ci].mean()) ** 2
    ri = np.nonzero(mse == np.max(mse))[0][0]
    print(f"{ri=}, {ci=}")
    print(f"{preds[ri,ci]=:.5g}, {labels[ri,ci]=:.5g}")
    print(f"{mse[ri]=:.5g}, r2: 1-({mse.mean()=:.5g})/({base.mean()=:.5g})")

    print(
        f"{y_rms_sub[ci]=:.5g}, {y_nanmean[ci]=:.5g}, {y_lower_bound[ci]=:.5g}, {y_upper_bound[ci]=:.5g}"
    )
    print(
        f"{preds[:,ci].mean()=:.5g}, {preds[:,ci].min()=:.5g}, {preds[:,ci].max()=:.5g}"
    )
    print(
        f"{labels[:,ci].mean()=:.5g}, {labels[:,ci].min()=:.5g}, {labels[:,ci].max()=:.5g}"
    )
    print()
# Out:
# 【 ptend_t_0 】
# r2_score=-0.020982
# ri=80, ci=0
# preds[ri,ci]=3.0149e-05, labels[ri,ci]=-2.9155e-05
# mse[ri]=3.517e-09, r2: 1-(mse.mean()=6.9864e-10)/(base.mean()=6.8428e-10)
# y_rms_sub[ci]=3.2278e-05, y_nanmean[ci]=1.0293e-05, y_lower_bound[ci]=-0.0020301, y_upper_bound[ci]=0.00794
# preds[:,ci].mean()=1.5914e-05, preds[:,ci].min()=5.9916e-07, preds[:,ci].max()=3.1056e-05
# labels[:,ci].mean()=1.119e-05, labels[:,ci].min()=-4.3717e-05, labels[:,ci].max()=5.9823e-05
#
# 【 ptend_t_1 】
# r2_score=-0.097995
# ri=353, ci=1
# preds[ri,ci]=9.0533e-07, labels[ri,ci]=-0.00013155
# mse[ri]=1.7544e-08, r2: 1-(mse.mean()=2.4005e-09)/(base.mean()=2.1862e-09)
# y_rms_sub[ci]=4.444e-05, y_nanmean[ci]=-7.0281e-06, y_lower_bound[ci]=-0.0037861, y_upper_bound[ci]=0.021563
# preds[:,ci].mean()=5.4132e-06, preds[:,ci].min()=-1.8455e-05, preds[:,ci].max()=2.4775e-05
# labels[:,ci].mean()=-1.2631e-05, labels[:,ci].min()=-0.00013155, labels[:,ci].max()=7.682e-05
#
# 【 ptend_t_2 】
# r2_score=0.0048213
# ri=348, ci=2
# preds[ri,ci]=-8.5951e-07, labels[ri,ci]=-0.00014766
# mse[ri]=2.1551e-08, r2: 1-(mse.mean()=3.2787e-09)/(base.mean()=3.2946e-09)
# y_rms_sub[ci]=5.2926e-05, y_nanmean[ci]=-3.1783e-06, y_lower_bound[ci]=-0.006704, y_upper_bound[ci]=0.0035969
# preds[:,ci].mean()=1.3565e-05, preds[:,ci].min()=-1.5602e-05, preds[:,ci].max()=3.7187e-05
# labels[:,ci].mean()=-6.0102e-06, labels[:,ci].min()=-0.00014766, labels[:,ci].max()=8.4963e-05
#
# 【 ptend_t_3 】
# r2_score=-0.02784
# ri=343, ci=3
# preds[ri,ci]=5.0322e-05, labels[ri,ci]=-0.00010035
# mse[ri]=2.2703e-08, r2: 1-(mse.mean()=5.105e-09)/(base.mean()=4.9668e-09)
# y_rms_sub[ci]=6.8898e-05, y_nanmean[ci]=-3.1923e-06, y_lower_bound[ci]=-0.0043876, y_upper_bound[ci]=0.00019506
# preds[:,ci].mean()=2.1023e-05, preds[:,ci].min()=-1.9218e-05, preds[:,ci].max()=5.3333e-05
# labels[:,ci].mean()=-3.6777e-06, labels[:,ci].min()=-0.00012878, labels[:,ci].max()=0.00010731
#
# 【 ptend_t_4 】
# r2_score=-0.066879
# ri=99, ci=4
# preds[ri,ci]=5.4757e-05, labels[ri,ci]=-9.4657e-05
# mse[ri]=2.2325e-08, r2: 1-(mse.mean()=8.8339e-09)/(base.mean()=8.2801e-09)
# y_rms_sub[ci]=9.1371e-05, y_nanmean[ci]=-3.6305e-06, y_lower_bound[ci]=-0.00034036, y_upper_bound[ci]=0.00019247
# preds[:,ci].mean()=3.0973e-05, preds[:,ci].min()=-2.4018e-05, preds[:,ci].max()=7.354e-05
# labels[:,ci].mean()=-2.584e-06, labels[:,ci].min()=-0.00010922, labels[:,ci].max()=0.00013952
#
# 【 ptend_t_5 】
# r2_score=-0.08691
# ri=102, ci=5
# preds[ri,ci]=7.1369e-05, labels[ri,ci]=-0.00011268
# mse[ri]=3.3874e-08, r2: 1-(mse.mean()=1.3784e-08)/(base.mean()=1.2681e-08)
# y_rms_sub[ci]=0.00011031, y_nanmean[ci]=-2.223e-06, y_lower_bound[ci]=-0.00028664, y_upper_bound[ci]=0.00025084
# preds[:,ci].mean()=4.1866e-05, preds[:,ci].min()=-2.2175e-05, preds[:,ci].max()=7.9668e-05
# labels[:,ci].mean()=-1.7908e-07, labels[:,ci].min()=-0.00012817, labels[:,ci].max()=0.00020203
#
# 【 ptend_t_6 】
# r2_score=-0.12494
# ri=155, ci=6
# preds[ri,ci]=5.1265e-05, labels[ri,ci]=0.0002236
# mse[ri]=2.9698e-08, r2: 1-(mse.mean()=1.2707e-08)/(base.mean()=1.1295e-08)
# y_rms_sub[ci]=0.00010348, y_nanmean[ci]=-3.1574e-07, y_lower_bound[ci]=-0.00021098, y_upper_bound[ci]=0.00027464
# preds[:,ci].mean()=4.4199e-05, preds[:,ci].min()=-1.3406e-05, preds[:,ci].max()=8.6819e-05
# labels[:,ci].mean()=7.4104e-07, labels[:,ci].min()=-0.00012188, labels[:,ci].max()=0.0002236
#
# 【 ptend_t_7 】
# r2_score=-0.14945
# ri=155, ci=7
# preds[ri,ci]=3.8964e-05, labels[ri,ci]=0.00018809
# mse[ri]=2.2238e-08, r2: 1-(mse.mean()=7.6693e-09)/(base.mean()=6.6722e-09)
# y_rms_sub[ci]=7.8811e-05, y_nanmean[ci]=3.9614e-07, y_lower_bound[ci]=-0.00020027, y_upper_bound[ci]=0.00023456
# preds[:,ci].mean()=3.58e-05, preds[:,ci].min()=-9.7225e-06, preds[:,ci].max()=6.5144e-05
# labels[:,ci].mean()=6.3943e-07, labels[:,ci].min()=-9.4221e-05, labels[:,ci].max()=0.00018809
#
# 【 ptend_t_8 】
# r2_score=-0.14944
# ri=155, ci=8
# preds[ri,ci]=2.5795e-05, labels[ri,ci]=0.00013791
# mse[ri]=1.2571e-08, r2: 1-(mse.mean()=3.2723e-09)/(base.mean()=2.8468e-09)
# y_rms_sub[ci]=5.0276e-05, y_nanmean[ci]=1.835e-07, y_lower_bound[ci]=-0.00012703, y_upper_bound[ci]=0.00015887
# preds[:,ci].mean()=2.3462e-05, preds[:,ci].min()=-5.6552e-06, preds[:,ci].max()=3.719e-05
# labels[:,ci].mean()=2.2718e-07, labels[:,ci].min()=-6.053e-05, labels[:,ci].max()=0.00013791
#
# 【 ptend_t_9 】
# r2_score=-0.18785
# ri=155, ci=9
# preds[ri,ci]=2.2087e-05, labels[ri,ci]=0.0001135
# mse[ri]=8.3559e-09, r2: 1-(mse.mean()=2.0308e-09)/(base.mean()=1.7097e-09)
# y_rms_sub[ci]=3.8713e-05, y_nanmean[ci]=-1.5025e-08, y_lower_bound[ci]=-9.4898e-05, y_upper_bound[ci]=0.00013054
# preds[:,ci].mean()=1.962e-05, preds[:,ci].min()=-3.9993e-06, preds[:,ci].max()=2.8318e-05
# labels[:,ci].mean()=1.4343e-07, labels[:,ci].min()=-4.809e-05, labels[:,ci].max()=0.0001135
#
# 【 ptend_t_10 】
# r2_score=-0.23166
# ri=155, ci=10
# preds[ri,ci]=1.914e-05, labels[ri,ci]=8.1467e-05
# mse[ri]=3.8847e-09, r2: 1-(mse.mean()=1.2097e-09)/(base.mean()=9.8213e-10)
# y_rms_sub[ci]=2.9507e-05, y_nanmean[ci]=1.414e-07, y_lower_bound[ci]=-7.5106e-05, y_upper_bound[ci]=9.9978e-05
# preds[:,ci].mean()=1.6039e-05, preds[:,ci].min()=-2.7682e-06, preds[:,ci].max()=2.1959e-05
# labels[:,ci].mean()=3.5348e-07, labels[:,ci].min()=-4.1485e-05, labels[:,ci].max()=8.1467e-05
#
# 【 ptend_t_11 】
# r2_score=-0.22433
# ri=147, ci=11
# preds[ri,ci]=1.3096e-05, labels[ri,ci]=5.8872e-05
# mse[ri]=2.0954e-09, r2: 1-(mse.mean()=6.8429e-10)/(base.mean()=5.5891e-10)
# y_rms_sub[ci]=2.2664e-05, y_nanmean[ci]=1.8991e-07, y_lower_bound[ci]=-5.857e-05, y_upper_bound[ci]=7.5129e-05
# preds[:,ci].mean()=1.2208e-05, preds[:,ci].min()=-1.7056e-06, preds[:,ci].max()=1.5649e-05
# labels[:,ci].mean()=4.5217e-07, labels[:,ci].min()=-2.9763e-05, labels[:,ci].max()=5.8872e-05
#
# 【 ptend_t_12 】
# r2_score=-0.19946
# ri=309, ci=12
# preds[ri,ci]=1.0676e-05, labels[ri,ci]=-2.298e-05
# mse[ri]=1.1328e-09, r2: 1-(mse.mean()=3.5126e-10)/(base.mean()=2.9285e-10)
# y_rms_sub[ci]=1.6719e-05, y_nanmean[ci]=2.9911e-07, y_lower_bound[ci]=-4.351e-05, y_upper_bound[ci]=5.6758e-05
# preds[:,ci].mean()=8.77e-06, preds[:,ci].min()=-8.4344e-07, preds[:,ci].max()=1.1199e-05
# labels[:,ci].mean()=6.5065e-07, labels[:,ci].min()=-2.3704e-05, labels[:,ci].max()=4.3794e-05
#
# 【 ptend_t_13 】
# r2_score=-0.18599
# ri=309, ci=13
# preds[ri,ci]=8.2216e-06, labels[ri,ci]=-1.9419e-05
# mse[ri]=7.6399e-10, r2: 1-(mse.mean()=1.8984e-10)/(base.mean()=1.6007e-10)
# y_rms_sub[ci]=1.2589e-05, y_nanmean[ci]=3.7836e-07, y_lower_bound[ci]=-3.7031e-05, y_upper_bound[ci]=4.0806e-05
# preds[:,ci].mean()=6.5928e-06, preds[:,ci].min()=-2.3182e-07, preds[:,ci].max()=8.5486e-06
# labels[:,ci].mean()=7.2329e-07, labels[:,ci].min()=-2.0247e-05, labels[:,ci].max()=3.0413e-05
#
# 【 ptend_t_14 】
# r2_score=-0.18953
# ri=295, ci=14
# preds[ri,ci]=7.6148e-06, labels[ri,ci]=-1.7193e-05
# mse[ri]=6.1545e-10, r2: 1-(mse.mean()=1.0611e-10)/(base.mean()=8.9206e-11)
# y_rms_sub[ci]=9.3146e-06, y_nanmean[ci]=5.7042e-07, y_lower_bound[ci]=-0.00010385, y_upper_bound[ci]=5.9677e-05
# preds[:,ci].mean()=5.0383e-06, preds[:,ci].min()=3.4204e-07, preds[:,ci].max()=8.264e-06
# labels[:,ci].mean()=9.0049e-07, labels[:,ci].min()=-1.7729e-05, labels[:,ci].max()=2.0261e-05
#
# 【 ptend_t_15 】
# r2_score=-0.22456
# ri=295, ci=15
# preds[ri,ci]=6.5089e-06, labels[ri,ci]=-1.4958e-05
# mse[ri]=4.6082e-10, r2: 1-(mse.mean()=6.7912e-11)/(base.mean()=5.5459e-11)
# y_rms_sub[ci]=7.3681e-06, y_nanmean[ci]=9.3496e-07, y_lower_bound[ci]=-0.00044666, y_upper_bound[ci]=0.00020871
# preds[:,ci].mean()=4.3625e-06, preds[:,ci].min()=7.3451e-07, preds[:,ci].max()=7.0932e-06
# labels[:,ci].mean()=1.1657e-06, labels[:,ci].min()=-1.5568e-05, labels[:,ci].max()=1.5954e-05
#
# 【 ptend_t_16 】
# r2_score=-0.26161
# ri=204, ci=16
# preds[ri,ci]=4.9367e-06, labels[ri,ci]=-1.5182e-05
# mse[ri]=4.0475e-10, r2: 1-(mse.mean()=5.2921e-11)/(base.mean()=4.1947e-11)
# y_rms_sub[ci]=6.6934e-06, y_nanmean[ci]=1.722e-06, y_lower_bound[ci]=-0.0019379, y_upper_bound[ci]=0.00075266
# preds[:,ci].mean()=4.4717e-06, preds[:,ci].min()=1.5317e-06, preds[:,ci].max()=7.3417e-06
# labels[:,ci].mean()=1.759e-06, labels[:,ci].min()=-1.5182e-05, labels[:,ci].max()=1.5457e-05
#
# 【 ptend_t_17 】
# r2_score=-0.48177
# ri=144, ci=17
# preds[ri,ci]=4.4629e-06, labels[ri,ci]=-4.4804e-05
# mse[ri]=2.4272e-09, r2: 1-(mse.mean()=5.4378e-11)/(base.mean()=3.6698e-11)
# y_rms_sub[ci]=7.7825e-06, y_nanmean[ci]=1.6504e-06, y_lower_bound[ci]=-0.0016661, y_upper_bound[ci]=0.0025104
# preds[:,ci].mean()=4.5116e-06, preds[:,ci].min()=7.6563e-07, preds[:,ci].max()=8.339e-06
# labels[:,ci].mean()=1.0294e-06, labels[:,ci].min()=-4.4804e-05, labels[:,ci].max()=1.3965e-05
#
# 【 ptend_t_18 】
# r2_score=-0.2562
# ri=144, ci=18
# preds[ri,ci]=3.0262e-06, labels[ri,ci]=8.5492e-05
# mse[ri]=6.8006e-09, r2: 1-(mse.mean()=1.0204e-10)/(base.mean()=8.1225e-11)
# y_rms_sub[ci]=1.09e-05, y_nanmean[ci]=7.5952e-07, y_lower_bound[ci]=-0.0023312, y_upper_bound[ci]=0.00080048
# preds[:,ci].mean()=4.4374e-06, preds[:,ci].min()=-8.6036e-07, preds[:,ci].max()=9.7534e-06
# labels[:,ci].mean()=1.2748e-06, labels[:,ci].min()=-4.5129e-05, labels[:,ci].max()=8.5492e-05
#
# 【 ptend_t_19 】
# r2_score=-0.29242
# ri=95, ci=19
# preds[ri,ci]=-1.4121e-07, labels[ri,ci]=9.2579e-05
# mse[ri]=8.5971e-09, r2: 1-(mse.mean()=1.5964e-10)/(base.mean()=1.2352e-10)
# y_rms_sub[ci]=1.3746e-05, y_nanmean[ci]=-3.9152e-07, y_lower_bound[ci]=-0.0020896, y_upper_bound[ci]=0.0012417
# preds[:,ci].mean()=3.7582e-06, preds[:,ci].min()=-3.4703e-06, preds[:,ci].max()=1.0606e-05
# labels[:,ci].mean()=2.2875e-07, labels[:,ci].min()=-4.1762e-05, labels[:,ci].max()=9.2579e-05
#
# 【 ptend_t_20 】
# r2_score=-0.16494
# ri=95, ci=20
# preds[ri,ci]=-8.0909e-08, labels[ri,ci]=0.00016409
# mse[ri]=2.6953e-08, r2: 1-(mse.mean()=2.5686e-10)/(base.mean()=2.2049e-10)
# y_rms_sub[ci]=1.503e-05, y_nanmean[ci]=-3.5008e-07, y_lower_bound[ci]=-0.0015815, y_upper_bound[ci]=0.0019031
# preds[:,ci].mean()=3.6239e-06, preds[:,ci].min()=-4.4004e-06, preds[:,ci].max()=1.16e-05
# labels[:,ci].mean()=1.0095e-06, labels[:,ci].min()=-3.2721e-05, labels[:,ci].max()=0.00016409
#
# 【 ptend_t_21 】
# r2_score=-0.17863
# ri=95, ci=21
# preds[ri,ci]=-2.2822e-06, labels[ri,ci]=0.00013054
# mse[ri]=1.7642e-08, r2: 1-(mse.mean()=2.6324e-10)/(base.mean()=2.2335e-10)
# y_rms_sub[ci]=1.589e-05, y_nanmean[ci]=-2.383e-06, y_lower_bound[ci]=-0.0012649, y_upper_bound[ci]=0.0013608
# preds[:,ci].mean()=1.046e-06, preds[:,ci].min()=-7.7118e-06, preds[:,ci].max()=9.7589e-06
# labels[:,ci].mean()=-9.4428e-07, labels[:,ci].min()=-5.2089e-05, labels[:,ci].max()=0.00013054
#
# 【 ptend_t_22 】
# r2_score=-0.13522
# ri=93, ci=22
# preds[ri,ci]=-3.3023e-06, labels[ri,ci]=0.00012367
# mse[ri]=1.6122e-08, r2: 1-(mse.mean()=3.0361e-10)/(base.mean()=2.6745e-10)
# y_rms_sub[ci]=1.7665e-05, y_nanmean[ci]=-4.1224e-06, y_lower_bound[ci]=-0.0010937, y_upper_bound[ci]=0.0020494
# preds[:,ci].mean()=-8.1192e-07, preds[:,ci].min()=-1.0836e-05, preds[:,ci].max()=9.3083e-06
# labels[:,ci].mean()=-3.2369e-06, labels[:,ci].min()=-0.00012715, labels[:,ci].max()=0.00012367
#
# 【 ptend_t_23 】
# r2_score=-0.16902
# ri=147, ci=23
# preds[ri,ci]=-5.2913e-06, labels[ri,ci]=0.00013267
# mse[ri]=1.9034e-08, r2: 1-(mse.mean()=3.228e-10)/(base.mean()=2.7613e-10)
# y_rms_sub[ci]=2.0213e-05, y_nanmean[ci]=-5.6501e-06, y_lower_bound[ci]=-0.0011443, y_upper_bound[ci]=0.0018548
# preds[:,ci].mean()=-2.3504e-06, preds[:,ci].min()=-1.3182e-05, preds[:,ci].max()=9.3495e-06
# labels[:,ci].mean()=-5.5307e-06, labels[:,ci].min()=-8.6304e-05, labels[:,ci].max()=0.00013267
#
# 【 ptend_t_24 】
# r2_score=-0.18316
# ri=147, ci=24
# preds[ri,ci]=-5.6808e-06, labels[ri,ci]=0.00017995
# mse[ri]=3.4457e-08, r2: 1-(mse.mean()=4.4887e-10)/(base.mean()=3.7938e-10)
# y_rms_sub[ci]=2.324e-05, y_nanmean[ci]=-6.6162e-06, y_lower_bound[ci]=-0.00085186, y_upper_bound[ci]=0.00171
# preds[:,ci].mean()=-3.2403e-06, preds[:,ci].min()=-1.5653e-05, preds[:,ci].max()=1.1525e-05
# labels[:,ci].mean()=-6.6558e-06, labels[:,ci].min()=-6.4282e-05, labels[:,ci].max()=0.00017995
#
# 【 ptend_t_25 】
# r2_score=-0.17108
# ri=147, ci=25
# preds[ri,ci]=-5.2396e-06, labels[ri,ci]=0.0001853
# mse[ri]=3.6304e-08, r2: 1-(mse.mean()=5.8451e-10)/(base.mean()=4.9912e-10)
# y_rms_sub[ci]=2.7091e-05, y_nanmean[ci]=-6.6196e-06, y_lower_bound[ci]=-0.00094212, y_upper_bound[ci]=0.0019357
# preds[:,ci].mean()=-2.7287e-06, preds[:,ci].min()=-1.7329e-05, preds[:,ci].max()=1.5128e-05
# labels[:,ci].mean()=-6.3065e-06, labels[:,ci].min()=-5.4383e-05, labels[:,ci].max()=0.0001853
#
# 【 ptend_t_26 】
# r2_score=-0.21963
# ri=147, ci=26
# preds[ri,ci]=-3.7265e-06, labels[ri,ci]=0.00019669
# mse[ri]=4.0167e-08, r2: 1-(mse.mean()=7.8418e-10)/(base.mean()=6.4297e-10)
# y_rms_sub[ci]=3.1759e-05, y_nanmean[ci]=-5.8169e-06, y_lower_bound[ci]=-0.00083891, y_upper_bound[ci]=0.0014607
# preds[:,ci].mean()=-1.4822e-06, preds[:,ci].min()=-1.7935e-05, preds[:,ci].max()=1.9395e-05
# labels[:,ci].mean()=-6.2358e-06, labels[:,ci].min()=-4.6348e-05, labels[:,ci].max()=0.00019669
#
# 【 ptend_t_27 】
# r2_score=-0.22143
# ri=147, ci=27
# preds[ri,ci]=-1.6891e-06, labels[ri,ci]=0.00021903
# mse[ri]=4.8717e-08, r2: 1-(mse.mean()=1.031e-09)/(base.mean()=8.4405e-10)
# y_rms_sub[ci]=3.7177e-05, y_nanmean[ci]=-4.6825e-06, y_lower_bound[ci]=-0.0011528, y_upper_bound[ci]=0.0014775
# preds[:,ci].mean()=-2.6557e-09, preds[:,ci].min()=-1.9994e-05, preds[:,ci].max()=2.7254e-05
# labels[:,ci].mean()=-6.1233e-06, labels[:,ci].min()=-5.7569e-05, labels[:,ci].max()=0.00021903
#
# 【 ptend_t_28 】
# r2_score=-0.22282
# ri=147, ci=28
# preds[ri,ci]=-1.3434e-07, labels[ri,ci]=0.00024505
# mse[ri]=6.0117e-08, r2: 1-(mse.mean()=1.3339e-09)/(base.mean()=1.0909e-09)
# y_rms_sub[ci]=4.2888e-05, y_nanmean[ci]=-3.5742e-06, y_lower_bound[ci]=-0.00093447, y_upper_bound[ci]=0.0014986
# preds[:,ci].mean()=1.364e-06, preds[:,ci].min()=-2.0759e-05, preds[:,ci].max()=3.3838e-05
# labels[:,ci].mean()=-4.986e-06, labels[:,ci].min()=-6.3435e-05, labels[:,ci].max()=0.00024505
#
# 【 ptend_t_29 】
# r2_score=-0.18831
# ri=17, ci=29
# preds[ri,ci]=3.9305e-06, labels[ri,ci]=0.00027845
# mse[ri]=7.5358e-08, r2: 1-(mse.mean()=1.7711e-09)/(base.mean()=1.4905e-09)
# y_rms_sub[ci]=4.8876e-05, y_nanmean[ci]=-2.5693e-06, y_lower_bound[ci]=-0.00099352, y_upper_bound[ci]=0.0017182
# preds[:,ci].mean()=3.3506e-06, preds[:,ci].min()=-2.1219e-05, preds[:,ci].max()=4.2411e-05
# labels[:,ci].mean()=-4.4637e-06, labels[:,ci].min()=-5.1639e-05, labels[:,ci].max()=0.00027845
#
# 【 ptend_t_30 】
# r2_score=-0.19106
# ri=17, ci=30
# preds[ri,ci]=5.2019e-06, labels[ri,ci]=0.00029013
# mse[ri]=8.1185e-08, r2: 1-(mse.mean()=2.0022e-09)/(base.mean()=1.681e-09)
# y_rms_sub[ci]=5.439e-05, y_nanmean[ci]=-1.687e-06, y_lower_bound[ci]=-0.00072956, y_upper_bound[ci]=0.001801
# preds[:,ci].mean()=3.5673e-06, preds[:,ci].min()=-2.3634e-05, preds[:,ci].max()=4.6588e-05
# labels[:,ci].mean()=-5.1073e-06, labels[:,ci].min()=-6.7685e-05, labels[:,ci].max()=0.00029013
#
# 【 ptend_t_31 】
# r2_score=-0.1684
# ri=17, ci=31
# preds[ri,ci]=6.5264e-06, labels[ri,ci]=0.00031465
# mse[ri]=9.4941e-08, r2: 1-(mse.mean()=2.8978e-09)/(base.mean()=2.4801e-09)
# y_rms_sub[ci]=5.8441e-05, y_nanmean[ci]=-9.0353e-07, y_lower_bound[ci]=-0.0010698, y_upper_bound[ci]=0.0016455
# preds[:,ci].mean()=5.086e-06, preds[:,ci].min()=-2.518e-05, preds[:,ci].max()=5.109e-05
# labels[:,ci].mean()=-4.3255e-06, labels[:,ci].min()=-9.7723e-05, labels[:,ci].max()=0.00031465
#
# 【 ptend_t_32 】
# r2_score=-0.14175
# ri=17, ci=32
# preds[ri,ci]=7.5577e-06, labels[ri,ci]=0.00037294
# mse[ri]=1.335e-07, r2: 1-(mse.mean()=3.2127e-09)/(base.mean()=2.8139e-09)
# y_rms_sub[ci]=6.1208e-05, y_nanmean[ci]=-2.7668e-07, y_lower_bound[ci]=-0.0011938, y_upper_bound[ci]=0.001815
# preds[:,ci].mean()=5.3927e-06, preds[:,ci].min()=-2.8364e-05, preds[:,ci].max()=5.3769e-05
# labels[:,ci].mean()=-3.0501e-06, labels[:,ci].min()=-7.7679e-05, labels[:,ci].max()=0.00037294
#
# 【 ptend_t_33 】
# r2_score=-0.14373
# ri=17, ci=33
# preds[ri,ci]=8.9264e-06, labels[ri,ci]=0.00037928
# mse[ri]=1.3716e-07, r2: 1-(mse.mean()=3.3942e-09)/(base.mean()=2.9676e-09)
# y_rms_sub[ci]=6.3061e-05, y_nanmean[ci]=1.8943e-07, y_lower_bound[ci]=-0.0013442, y_upper_bound[ci]=0.0017571
# preds[:,ci].mean()=6.3761e-06, preds[:,ci].min()=-2.8037e-05, preds[:,ci].max()=5.2929e-05
# labels[:,ci].mean()=-1.8896e-06, labels[:,ci].min()=-0.00014823, labels[:,ci].max()=0.00037928
#
# 【 ptend_t_34 】
# r2_score=-0.11364
# ri=147, ci=34
# preds[ri,ci]=1.1889e-05, labels[ri,ci]=0.00045723
# mse[ri]=1.9832e-07, r2: 1-(mse.mean()=4.0692e-09)/(base.mean()=3.6539e-09)
# y_rms_sub[ci]=6.4181e-05, y_nanmean[ci]=4.8232e-07, y_lower_bound[ci]=-0.0012755, y_upper_bound[ci]=0.0015543
# preds[:,ci].mean()=7.0264e-06, preds[:,ci].min()=-2.7378e-05, preds[:,ci].max()=6.0924e-05
# labels[:,ci].mean()=-1.2133e-06, labels[:,ci].min()=-9.4999e-05, labels[:,ci].max()=0.00045723
#
# 【 ptend_t_35 】
# r2_score=-0.10867
# ri=17, ci=35
# preds[ri,ci]=8.2621e-06, labels[ri,ci]=0.00042674
# mse[ri]=1.7513e-07, r2: 1-(mse.mean()=4.1927e-09)/(base.mean()=3.7818e-09)
# y_rms_sub[ci]=6.4526e-05, y_nanmean[ci]=6.4682e-07, y_lower_bound[ci]=-0.0015754, y_upper_bound[ci]=0.0014463
# preds[:,ci].mean()=7.4059e-06, preds[:,ci].min()=-2.4739e-05, preds[:,ci].max()=5.8578e-05
# labels[:,ci].mean()=-1.1651e-06, labels[:,ci].min()=-9.1898e-05, labels[:,ci].max()=0.00042674
#
# 【 ptend_t_36 】
# r2_score=-0.082712
# ri=82, ci=36
# preds[ri,ci]=4.6695e-06, labels[ri,ci]=0.00036456
# mse[ri]=1.2952e-07, r2: 1-(mse.mean()=4.4177e-09)/(base.mean()=4.0802e-09)
# y_rms_sub[ci]=6.4052e-05, y_nanmean[ci]=6.9192e-07, y_lower_bound[ci]=-0.0016109, y_upper_bound[ci]=0.0013356
# preds[:,ci].mean()=8.3988e-06, preds[:,ci].min()=-2.2958e-05, preds[:,ci].max()=5.5694e-05
# labels[:,ci].mean()=-9.481e-07, labels[:,ci].min()=-0.00020604, labels[:,ci].max()=0.00036456
#
# 【 ptend_t_37 】
# r2_score=-0.062041
# ri=194, ci=37
# preds[ri,ci]=7.1929e-06, labels[ri,ci]=0.00044445
# mse[ri]=1.912e-07, r2: 1-(mse.mean()=4.5563e-09)/(base.mean()=4.2901e-09)
# y_rms_sub[ci]=6.33e-05, y_nanmean[ci]=6.9456e-07, y_lower_bound[ci]=-0.0013281, y_upper_bound[ci]=0.0013643
# preds[:,ci].mean()=9.5064e-06, preds[:,ci].min()=-2.1835e-05, preds[:,ci].max()=5.3822e-05
# labels[:,ci].mean()=-5.3352e-08, labels[:,ci].min()=-0.00011543, labels[:,ci].max()=0.00044445
#
# 【 ptend_t_38 】
# r2_score=-0.055046
# ri=82, ci=38
# preds[ri,ci]=1.3686e-05, labels[ri,ci]=0.00044092
# mse[ri]=1.8253e-07, r2: 1-(mse.mean()=4.2138e-09)/(base.mean()=3.994e-09)
# y_rms_sub[ci]=6.2601e-05, y_nanmean[ci]=6.8264e-07, y_lower_bound[ci]=-0.001051, y_upper_bound[ci]=0.0014974
# preds[:,ci].mean()=1.0746e-05, preds[:,ci].min()=-2.0333e-05, preds[:,ci].max()=5.2147e-05
# labels[:,ci].mean()=-2.4967e-07, labels[:,ci].min()=-0.00012317, labels[:,ci].max()=0.00044092
#
# 【 ptend_t_39 】
# r2_score=-0.066356
# ri=82, ci=39
# preds[ri,ci]=1.5603e-05, labels[ri,ci]=0.00051468
# mse[ri]=2.4907e-07, r2: 1-(mse.mean()=4.0377e-09)/(base.mean()=3.7865e-09)
# y_rms_sub[ci]=6.1995e-05, y_nanmean[ci]=6.0524e-07, y_lower_bound[ci]=-0.0010256, y_upper_bound[ci]=0.001396
# preds[:,ci].mean()=1.1782e-05, preds[:,ci].min()=-1.8847e-05, preds[:,ci].max()=5.058e-05
# labels[:,ci].mean()=-1.3569e-06, labels[:,ci].min()=-0.00016272, labels[:,ci].max()=0.00051468
#
# 【 ptend_t_40 】
# r2_score=-0.050739
# ri=82, ci=40
# preds[ri,ci]=1.6295e-05, labels[ri,ci]=0.00047204
# mse[ri]=2.0771e-07, r2: 1-(mse.mean()=3.5768e-09)/(base.mean()=3.4041e-09)
# y_rms_sub[ci]=6.1496e-05, y_nanmean[ci]=4.6188e-07, y_lower_bound[ci]=-0.00085972, y_upper_bound[ci]=0.0012175
# preds[:,ci].mean()=1.2358e-05, preds[:,ci].min()=-1.9478e-05, preds[:,ci].max()=5.2154e-05
# labels[:,ci].mean()=9.8978e-07, labels[:,ci].min()=-0.00015898, labels[:,ci].max()=0.00047204
#
# 【 ptend_t_41 】
# r2_score=-0.07423
# ri=147, ci=41
# preds[ri,ci]=2.7923e-05, labels[ri,ci]=0.00048829
# mse[ri]=2.1194e-07, r2: 1-(mse.mean()=3.5537e-09)/(base.mean()=3.3081e-09)
# y_rms_sub[ci]=6.108e-05, y_nanmean[ci]=2.5631e-07, y_lower_bound[ci]=-0.00093625, y_upper_bound[ci]=0.0012026
# preds[:,ci].mean()=1.2276e-05, preds[:,ci].min()=-1.9475e-05, preds[:,ci].max()=5.2127e-05
# labels[:,ci].mean()=1.3492e-06, labels[:,ci].min()=-0.00014328, labels[:,ci].max()=0.00048829
#
# 【 ptend_t_42 】
# r2_score=-0.055411
# ri=82, ci=42
# preds[ri,ci]=1.0499e-05, labels[ri,ci]=0.0005149
# mse[ri]=2.5442e-07, r2: 1-(mse.mean()=3.8243e-09)/(base.mean()=3.6235e-09)
# y_rms_sub[ci]=6.0987e-05, y_nanmean[ci]=-3.9707e-08, y_lower_bound[ci]=-0.00074911, y_upper_bound[ci]=0.0012147
# preds[:,ci].mean()=1.1575e-05, preds[:,ci].min()=-1.8142e-05, preds[:,ci].max()=4.6319e-05
# labels[:,ci].mean()=1.6708e-06, labels[:,ci].min()=-0.00014175, labels[:,ci].max()=0.0005149
#
# 【 ptend_t_43 】
# r2_score=-0.057277
# ri=82, ci=43
# preds[ri,ci]=1.1993e-05, labels[ri,ci]=0.00053669
# mse[ri]=2.7531e-07, r2: 1-(mse.mean()=3.7688e-09)/(base.mean()=3.5646e-09)
# y_rms_sub[ci]=6.1254e-05, y_nanmean[ci]=-3.9279e-07, y_lower_bound[ci]=-0.00069239, y_upper_bound[ci]=0.0012689
# preds[:,ci].mean()=1.0948e-05, preds[:,ci].min()=-1.7634e-05, preds[:,ci].max()=4.4228e-05
# labels[:,ci].mean()=-3.4798e-07, labels[:,ci].min()=-0.00020641, labels[:,ci].max()=0.00053669
#
# 【 ptend_t_44 】
# r2_score=-0.028492
# ri=82, ci=44
# preds[ri,ci]=1.3922e-05, labels[ri,ci]=0.00050797
# mse[ri]=2.4409e-07, r2: 1-(mse.mean()=3.8695e-09)/(base.mean()=3.7623e-09)
# y_rms_sub[ci]=6.1619e-05, y_nanmean[ci]=-7.0516e-07, y_lower_bound[ci]=-0.00060904, y_upper_bound[ci]=0.0012845
# preds[:,ci].mean()=1.0069e-05, preds[:,ci].min()=-1.6538e-05, preds[:,ci].max()=4.0141e-05
# labels[:,ci].mean()=-3.2832e-06, labels[:,ci].min()=-0.00022419, labels[:,ci].max()=0.00050797
#
# 【 ptend_t_45 】
# r2_score=-0.038581
# ri=82, ci=45
# preds[ri,ci]=1.8179e-05, labels[ri,ci]=0.00032396
# mse[ri]=9.3501e-08, r2: 1-(mse.mean()=3.3943e-09)/(base.mean()=3.2682e-09)
# y_rms_sub[ci]=6.176e-05, y_nanmean[ci]=-7.0207e-07, y_lower_bound[ci]=-0.00069593, y_upper_bound[ci]=0.0012294
# preds[:,ci].mean()=1.0005e-05, preds[:,ci].min()=-1.5359e-05, preds[:,ci].max()=4.2969e-05
# labels[:,ci].mean()=-2.3703e-06, labels[:,ci].min()=-0.0002753, labels[:,ci].max()=0.00032396
#
# 【 ptend_t_46 】
# r2_score=-0.050062
# ri=103, ci=46
# preds[ri,ci]=1.1013e-05, labels[ri,ci]=0.00034532
# mse[ri]=1.1176e-07, r2: 1-(mse.mean()=3.2566e-09)/(base.mean()=3.1013e-09)
# y_rms_sub[ci]=6.1195e-05, y_nanmean[ci]=-1.9406e-07, y_lower_bound[ci]=-0.00065184, y_upper_bound[ci]=0.0013678
# preds[:,ci].mean()=1.0503e-05, preds[:,ci].min()=-1.436e-05, preds[:,ci].max()=3.5012e-05
# labels[:,ci].mean()=-6.9177e-07, labels[:,ci].min()=-0.00018774, labels[:,ci].max()=0.00034532
#
# 【 ptend_t_47 】
# r2_score=-0.043917
# ri=103, ci=47
# preds[ri,ci]=1.1092e-05, labels[ri,ci]=0.00031733
# mse[ri]=9.3784e-08, r2: 1-(mse.mean()=3.6434e-09)/(base.mean()=3.4901e-09)
# y_rms_sub[ci]=6.0076e-05, y_nanmean[ci]=6.6915e-07, y_lower_bound[ci]=-0.00068137, y_upper_bound[ci]=0.0014417
# preds[:,ci].mean()=1.1806e-05, preds[:,ci].min()=-1.2978e-05, preds[:,ci].max()=3.5812e-05
# labels[:,ci].mean()=1.8367e-06, labels[:,ci].min()=-0.00020159, labels[:,ci].max()=0.00031733
#
# 【 ptend_t_48 】
# r2_score=-0.14799
# ri=71, ci=48
# preds[ri,ci]=3.6368e-05, labels[ri,ci]=0.00026883
# mse[ri]=5.4039e-08, r2: 1-(mse.mean()=2.6684e-09)/(base.mean()=2.3244e-09)
# y_rms_sub[ci]=5.8805e-05, y_nanmean[ci]=1.5757e-06, y_lower_bound[ci]=-0.00069584, y_upper_bound[ci]=0.0013452
# preds[:,ci].mean()=1.2854e-05, preds[:,ci].min()=-1.1322e-05, preds[:,ci].max()=3.9031e-05
# labels[:,ci].mean()=-5.2627e-07, labels[:,ci].min()=-0.0001611, labels[:,ci].max()=0.00026883
#
# 【 ptend_t_49 】
# r2_score=-0.1915
# ri=170, ci=49
# preds[ri,ci]=1.0078e-05, labels[ri,ci]=0.00022649
# mse[ri]=4.6833e-08, r2: 1-(mse.mean()=2.7922e-09)/(base.mean()=2.3435e-09)
# y_rms_sub[ci]=5.7371e-05, y_nanmean[ci]=2.3883e-06, y_lower_bound[ci]=-0.0008996, y_upper_bound[ci]=0.0012844
# preds[:,ci].mean()=1.3858e-05, preds[:,ci].min()=-8.3706e-06, preds[:,ci].max()=3.8687e-05
# labels[:,ci].mean()=-1.0257e-06, labels[:,ci].min()=-0.00019025, labels[:,ci].max()=0.00022649
#
# 【 ptend_t_50 】
# r2_score=-0.17929
# ri=220, ci=50
# preds[ri,ci]=2.001e-05, labels[ri,ci]=-0.00019369
# mse[ri]=4.5668e-08, r2: 1-(mse.mean()=2.7572e-09)/(base.mean()=2.338e-09)
# y_rms_sub[ci]=5.5843e-05, y_nanmean[ci]=3.0654e-06, y_lower_bound[ci]=-0.00086782, y_upper_bound[ci]=0.001328
# preds[:,ci].mean()=1.4878e-05, preds[:,ci].min()=-7.2346e-06, preds[:,ci].max()=3.6661e-05
# labels[:,ci].mean()=-5.6854e-07, labels[:,ci].min()=-0.00019369, labels[:,ci].max()=0.00016321
#
# 【 ptend_t_51 】
# r2_score=-0.17466
# ri=220, ci=51
# preds[ri,ci]=2.0593e-05, labels[ri,ci]=-0.00027601
# mse[ri]=8.7976e-08, r2: 1-(mse.mean()=3.078e-09)/(base.mean()=2.6203e-09)
# y_rms_sub[ci]=5.4255e-05, y_nanmean[ci]=3.6993e-06, y_lower_bound[ci]=-0.0011655, y_upper_bound[ci]=0.0013037
# preds[:,ci].mean()=1.5543e-05, preds[:,ci].min()=-5.5498e-06, preds[:,ci].max()=3.7037e-05
# labels[:,ci].mean()=-1.059e-06, labels[:,ci].min()=-0.00027601, labels[:,ci].max()=0.00020036
#
# 【 ptend_t_52 】
# r2_score=-0.17049
# ri=147, ci=52
# preds[ri,ci]=3.2491e-05, labels[ri,ci]=-0.00028955
# mse[ri]=1.0371e-07, r2: 1-(mse.mean()=3.0883e-09)/(base.mean()=2.6385e-09)
# y_rms_sub[ci]=5.2542e-05, y_nanmean[ci]=4.2736e-06, y_lower_bound[ci]=-0.001134, y_upper_bound[ci]=0.0014183
# preds[:,ci].mean()=1.6588e-05, preds[:,ci].min()=-4.1351e-06, preds[:,ci].max()=3.8324e-05
# labels[:,ci].mean()=9.9331e-07, labels[:,ci].min()=-0.00028955, labels[:,ci].max()=0.00017512
#
# 【 ptend_t_53 】
# r2_score=-0.16854
# ri=220, ci=53
# preds[ri,ci]=2.1247e-05, labels[ri,ci]=-0.00026814
# mse[ri]=8.3744e-08, r2: 1-(mse.mean()=2.845e-09)/(base.mean()=2.4346e-09)
# y_rms_sub[ci]=5.0758e-05, y_nanmean[ci]=4.4461e-06, y_lower_bound[ci]=-0.0012106, y_upper_bound[ci]=0.001334
# preds[:,ci].mean()=1.682e-05, preds[:,ci].min()=-3.4638e-06, preds[:,ci].max()=3.7099e-05
# labels[:,ci].mean()=1.2099e-06, labels[:,ci].min()=-0.00026814, labels[:,ci].max()=0.00015714
#
# 【 ptend_t_54 】
# r2_score=-0.17863
# ri=220, ci=54
# preds[ri,ci]=2.0184e-05, labels[ri,ci]=-0.00033966
# mse[ri]=1.2949e-07, r2: 1-(mse.mean()=2.5818e-09)/(base.mean()=2.1905e-09)
# y_rms_sub[ci]=4.9e-05, y_nanmean[ci]=3.905e-06, y_lower_bound[ci]=-0.0010222, y_upper_bound[ci]=0.0017133
# preds[:,ci].mean()=1.6504e-05, preds[:,ci].min()=-3.1112e-06, preds[:,ci].max()=3.676e-05
# labels[:,ci].mean()=-8.4544e-07, labels[:,ci].min()=-0.00033966, labels[:,ci].max()=0.00018476
#
# 【 ptend_t_55 】
# r2_score=-0.1846
# ri=220, ci=55
# preds[ri,ci]=2.2538e-05, labels[ri,ci]=-0.00029602
# mse[ri]=1.0148e-07, r2: 1-(mse.mean()=2.1485e-09)/(base.mean()=1.8137e-09)
# y_rms_sub[ci]=4.7694e-05, y_nanmean[ci]=2.1095e-06, y_lower_bound[ci]=-0.00099591, y_upper_bound[ci]=0.0014724
# preds[:,ci].mean()=1.5344e-05, preds[:,ci].min()=-4.6783e-06, preds[:,ci].max()=3.6517e-05
# labels[:,ci].mean()=-4.1691e-07, labels[:,ci].min()=-0.00029602, labels[:,ci].max()=0.00015087
#
# 【 ptend_t_56 】
# r2_score=-0.21923
# ri=82, ci=56
# preds[ri,ci]=2.5905e-05, labels[ri,ci]=-0.00026101
# mse[ri]=8.2319e-08, r2: 1-(mse.mean()=2.0053e-09)/(base.mean()=1.6447e-09)
# y_rms_sub[ci]=4.7182e-05, y_nanmean[ci]=-1.3361e-06, y_lower_bound[ci]=-0.0010859, y_upper_bound[ci]=0.0010916
# preds[:,ci].mean()=1.2641e-05, preds[:,ci].min()=-7.5018e-06, preds[:,ci].max()=3.1688e-05
# labels[:,ci].mean()=-3.2894e-06, labels[:,ci].min()=-0.00026101, labels[:,ci].max()=0.00014099
#
# 【 ptend_t_57 】
# r2_score=-0.15951
# ri=82, ci=57
# preds[ri,ci]=1.5381e-05, labels[ri,ci]=-0.0003524
# mse[ri]=1.3526e-07, r2: 1-(mse.mean()=2.5242e-09)/(base.mean()=2.1769e-09)
# y_rms_sub[ci]=4.7419e-05, y_nanmean[ci]=-8.6302e-06, y_lower_bound[ci]=-0.0013353, y_upper_bound[ci]=0.0010396
# preds[:,ci].mean()=6.421e-06, preds[:,ci].min()=-1.4999e-05, preds[:,ci].max()=2.3782e-05
# labels[:,ci].mean()=-9.1236e-06, labels[:,ci].min()=-0.0003524, labels[:,ci].max()=0.00014926
#
# 【 ptend_t_58 】
# r2_score=-0.17338
# ri=82, ci=58
# preds[ri,ci]=-1.6004e-06, labels[ri,ci]=-0.00039009
# mse[ri]=1.5093e-07, r2: 1-(mse.mean()=3.0154e-09)/(base.mean()=2.5698e-09)
# y_rms_sub[ci]=5.1446e-05, y_nanmean[ci]=-2.5211e-05, y_lower_bound[ci]=-0.0016582, y_upper_bound[ci]=0.0010167
# preds[:,ci].mean()=-8.2817e-06, preds[:,ci].min()=-3.2084e-05, preds[:,ci].max()=9.2556e-06
# labels[:,ci].mean()=-2.449e-05, labels[:,ci].min()=-0.00039009, labels[:,ci].max()=0.00011932
#
# 【 ptend_t_59 】
# r2_score=-0.14494
# ri=82, ci=59
# preds[ri,ci]=-2.5323e-05, labels[ri,ci]=-0.00061376
# mse[ri]=3.4626e-07, r2: 1-(mse.mean()=5.3462e-09)/(base.mean()=4.6694e-09)
# y_rms_sub[ci]=7.3111e-05, y_nanmean[ci]=-6.2107e-05, y_lower_bound[ci]=-0.0017827, y_upper_bound[ci]=0.00099505
# preds[:,ci].mean()=-3.6791e-05, preds[:,ci].min()=-7.1913e-05, preds[:,ci].max()=-1.0981e-05
# labels[:,ci].mean()=-5.7674e-05, labels[:,ci].min()=-0.00061376, labels[:,ci].max()=5.2549e-05
#
# 【 ptend_q0001_12 】
# r2_score=-0.97261
# ri=221, ci=72
# preds[ri,ci]=-2.9461e-14, labels[ri,ci]=4.6884e-13
# mse[ri]=2.483e-25, r2: 1-(mse.mean()=5.5331e-27)/(base.mean()=2.805e-27)
# y_rms_sub[ci]=1.1474e-12, y_nanmean[ci]=2.9608e-15, y_lower_bound[ci]=-1.0226e-10, y_upper_bound[ci]=5.2452e-11
# preds[:,ci].mean()=1.0777e-15, preds[:,ci].min()=-1.2628e-13, preds[:,ci].max()=2.1681e-13
# labels[:,ci].mean()=-5.8868e-15, labels[:,ci].min()=-3.3119e-13, labels[:,ci].max()=4.6884e-13
#
# 【 ptend_q0001_13 】
# r2_score=-0.30798
# ri=194, ci=73
# preds[ri,ci]=-6.7398e-14, labels[ri,ci]=-7.0514e-13
# mse[ri]=4.0672e-25, r2: 1-(mse.mean()=7.7231e-27)/(base.mean()=5.9046e-27)
# y_rms_sub[ci]=9.2317e-13, y_nanmean[ci]=7.5404e-15, y_lower_bound[ci]=-8.7756e-11, y_upper_bound[ci]=1.0376e-10
# preds[:,ci].mean()=-1.8862e-15, preds[:,ci].min()=-9.4513e-14, preds[:,ci].max()=1.6977e-13
# labels[:,ci].mean()=-2.1428e-15, labels[:,ci].min()=-7.0514e-13, labels[:,ci].max()=3.6174e-13
#
# 【 ptend_q0001_14 】
# r2_score=-8.1411
# ri=362, ci=74
# preds[ri,ci]=1.8732e-12, labels[ri,ci]=-2.8234e-24
# mse[ri]=3.5088e-24, r2: 1-(mse.mean()=2.6688e-25)/(base.mean()=2.9196e-26)
# y_rms_sub[ci]=6.8011e-12, y_nanmean[ci]=9.9102e-15, y_lower_bound[ci]=-6.5676e-10, y_upper_bound[ci]=1.1027e-08
# preds[:,ci].mean()=2.5245e-15, preds[:,ci].min()=-7.6002e-13, preds[:,ci].max()=1.8732e-12
# labels[:,ci].mean()=-2.643e-14, labels[:,ci].min()=-1.5485e-12, labels[:,ci].max()=3.7029e-13
#
# 【 ptend_q0001_15 】
# r2_score=-58.356
# ri=376, ci=75
# preds[ri,ci]=7.8272e-12, labels[ri,ci]=8.7117e-15
# mse[ri]=6.1129e-23, r2: 1-(mse.mean()=5.7364e-24)/(base.mean()=9.6644e-26)
# y_rms_sub[ci]=2.8125e-11, y_nanmean[ci]=4.8055e-14, y_lower_bound[ci]=-9.0666e-09, y_upper_bound[ci]=1.5902e-08
# preds[:,ci].mean()=5.7971e-13, preds[:,ci].min()=-2.7839e-12, preds[:,ci].max()=7.8272e-12
# labels[:,ci].mean()=-4.6097e-14, labels[:,ci].min()=-1.8605e-12, labels[:,ci].max()=1.4633e-12
#
# 【 ptend_q0001_16 】
# r2_score=-8.0615
# ri=382, ci=76
# preds[ri,ci]=8.3481e-12, labels[ri,ci]=-3.3596e-13
# mse[ri]=7.5414e-23, r2: 1-(mse.mean()=6.2886e-24)/(base.mean()=6.9399e-25)
# y_rms_sub[ci]=2.8447e-11, y_nanmean[ci]=3.3179e-14, y_lower_bound[ci]=-9.9392e-09, y_upper_bound[ci]=1.4868e-08
# preds[:,ci].mean()=7.3258e-13, preds[:,ci].min()=-2.7618e-12, preds[:,ci].max()=8.3481e-12
# labels[:,ci].mean()=-1.8438e-13, labels[:,ci].min()=-8.5615e-12, labels[:,ci].max()=3.006e-12
#
# 【 ptend_q0001_17 】
# r2_score=-0.39045
# ri=146, ci=77
# preds[ri,ci]=-1.5026e-12, labels[ri,ci]=1.7189e-11
# mse[ri]=3.4939e-22, r2: 1-(mse.mean()=1.292e-23)/(base.mean()=9.2922e-24)
# y_rms_sub[ci]=2.1698e-11, y_nanmean[ci]=-2.5586e-13, y_lower_bound[ci]=-1.2228e-08, y_upper_bound[ci]=1.772e-08
# preds[:,ci].mean()=5.1645e-13, preds[:,ci].min()=-2.7548e-12, preds[:,ci].max()=6.4335e-12
# labels[:,ci].mean()=-1.7384e-13, labels[:,ci].min()=-1.8859e-11, labels[:,ci].max()=1.7189e-11
#
# 【 ptend_q0001_18 】
# r2_score=-0.089238
# ri=95, ci=78
# preds[ri,ci]=1.0345e-12, labels[ri,ci]=-2.1522e-10
# mse[ri]=4.6768e-20, r2: 1-(mse.mean()=1.8346e-22)/(base.mean()=1.6843e-22)
# y_rms_sub[ci]=4.0503e-11, y_nanmean[ci]=-5.8646e-13, y_lower_bound[ci]=-1.2401e-08, y_upper_bound[ci]=3.7913e-08
# preds[:,ci].mean()=1.9126e-12, preds[:,ci].min()=-4.788e-12, preds[:,ci].max()=1.2379e-11
# labels[:,ci].mean()=-1.3955e-12, labels[:,ci].min()=-2.1522e-10, labels[:,ci].max()=3.5008e-11
#
# 【 ptend_q0001_19 】
# r2_score=-0.23597
# ri=131, ci=79
# preds[ri,ci]=9.8332e-12, labels[ri,ci]=-1.5781e-10
# mse[ri]=2.8104e-20, r2: 1-(mse.mean()=4.614e-22)/(base.mean()=3.7331e-22)
# y_rms_sub[ci]=8.8158e-11, y_nanmean[ci]=-2.5492e-12, y_lower_bound[ci]=-1.693e-08, y_upper_bound[ci]=3.2368e-08
# preds[:,ci].mean()=4.7327e-12, preds[:,ci].min()=-1.2653e-11, preds[:,ci].max()=2.5674e-11
# labels[:,ci].mean()=-2.5116e-12, labels[:,ci].min()=-1.5781e-10, labels[:,ci].max()=9.1689e-11
#
# 【 ptend_q0001_20 】
# r2_score=-0.10019
# ri=147, ci=80
# preds[ri,ci]=-1.2943e-11, labels[ri,ci]=-7.4384e-10
# mse[ri]=5.3421e-19, r2: 1-(mse.mean()=5.7761e-21)/(base.mean()=5.2501e-21)
# y_rms_sub[ci]=1.853e-10, y_nanmean[ci]=-9.4726e-12, y_lower_bound[ci]=-1.7148e-08, y_upper_bound[ci]=2.8628e-08
# preds[:,ci].mean()=8.6895e-12, preds[:,ci].min()=-3.1612e-11, preds[:,ci].max()=5.3396e-11
# labels[:,ci].mean()=-1.345e-11, labels[:,ci].min()=-7.4384e-10, labels[:,ci].max()=1.4716e-10
#
# 【 ptend_q0001_21 】
# r2_score=-0.046138
# ri=147, ci=81
# preds[ri,ci]=-4.1172e-11, labels[ri,ci]=-2.1526e-09
# mse[ri]=4.4582e-18, r2: 1-(mse.mean()=3.3887e-20)/(base.mean()=3.2392e-20)
# y_rms_sub[ci]=4.0827e-10, y_nanmean[ci]=-3.1134e-11, y_lower_bound[ci]=-3.7091e-08, y_upper_bound[ci]=3.9277e-08
# preds[:,ci].mean()=1.1305e-11, preds[:,ci].min()=-6.8448e-11, preds[:,ci].max()=1.232e-10
# labels[:,ci].mean()=-2.5577e-11, labels[:,ci].min()=-2.1526e-09, labels[:,ci].max()=4.9359e-10
#
# 【 ptend_q0001_22 】
# r2_score=-0.0094625
# ri=147, ci=82
# preds[ri,ci]=-1.3996e-10, labels[ri,ci]=-5.9563e-09
# mse[ri]=3.383e-17, r2: 1-(mse.mean()=2.6061e-19)/(base.mean()=2.5816e-19)
# y_rms_sub[ci]=8.8322e-10, y_nanmean[ci]=-8.9123e-11, y_lower_bound[ci]=-5.9763e-08, y_upper_bound[ci]=5.8638e-08
# preds[:,ci].mean()=-5.6826e-12, preds[:,ci].min()=-1.8979e-10, preds[:,ci].max()=2.5383e-10
# labels[:,ci].mean()=-6.6997e-11, labels[:,ci].min()=-5.9563e-09, labels[:,ci].max()=2.1817e-09
#
# 【 ptend_q0001_23 】
# r2_score=0.011599
# ri=147, ci=83
# preds[ri,ci]=-3.5846e-10, labels[ri,ci]=-1.2078e-08
# mse[ri]=1.3734e-16, r2: 1-(mse.mean()=1.2819e-18)/(base.mean()=1.2969e-18)
# y_rms_sub[ci]=1.7255e-09, y_nanmean[ci]=-2.1081e-10, y_lower_bound[ci]=-9.4596e-08, y_upper_bound[ci]=1.0145e-07
# preds[:,ci].mean()=-4.9499e-11, preds[:,ci].min()=-4.4016e-10, preds[:,ci].max()=4.7272e-10
# labels[:,ci].mean()=-1.4008e-10, labels[:,ci].min()=-1.2078e-08, labels[:,ci].max()=5.3275e-09
#
# 【 ptend_q0001_24 】
# r2_score=0.022958
# ri=147, ci=84
# preds[ri,ci]=-7.2849e-10, labels[ri,ci]=-1.9846e-08
# mse[ri]=3.655e-16, r2: 1-(mse.mean()=4.3767e-18)/(base.mean()=4.4795e-18)
# y_rms_sub[ci]=3.0283e-09, y_nanmean[ci]=-4.2915e-10, y_lower_bound[ci]=-1.1287e-07, y_upper_bound[ci]=1.3921e-07
# preds[:,ci].mean()=-1.7277e-10, preds[:,ci].min()=-8.5048e-10, preds[:,ci].max()=8.7782e-10
# labels[:,ci].mean()=-3.7927e-10, labels[:,ci].min()=-1.9846e-08, labels[:,ci].max()=7.6315e-09
#
# 【 ptend_q0001_25 】
# r2_score=0.028879
# ri=17, ci=85
# preds[ri,ci]=-1.2251e-09, labels[ri,ci]=-3.4337e-08
# mse[ri]=1.0964e-15, r2: 1-(mse.mean()=1.2011e-17)/(base.mean()=1.2368e-17)
# y_rms_sub[ci]=4.8166e-09, y_nanmean[ci]=-7.6005e-10, y_lower_bound[ci]=-1.8781e-07, y_upper_bound[ci]=1.7563e-07
# preds[:,ci].mean()=-3.2528e-10, preds[:,ci].min()=-1.4265e-09, preds[:,ci].max()=1.4656e-09
# labels[:,ci].mean()=-6.4194e-10, labels[:,ci].min()=-3.4337e-08, labels[:,ci].max()=3.2132e-09
#
# 【 ptend_q0001_26 】
# r2_score=0.029567
# ri=17, ci=86
# preds[ri,ci]=-1.6788e-09, labels[ri,ci]=-4.8606e-08
# mse[ri]=2.2022e-15, r2: 1-(mse.mean()=2.6006e-17)/(base.mean()=2.6798e-17)
# y_rms_sub[ci]=6.9166e-09, y_nanmean[ci]=-1.167e-09, y_lower_bound[ci]=-2.7088e-07, y_upper_bound[ci]=2.3e-07
# preds[:,ci].mean()=-5.6803e-10, preds[:,ci].min()=-2.1086e-09, preds[:,ci].max()=1.8523e-09
# labels[:,ci].mean()=-1.0467e-09, labels[:,ci].min()=-4.8606e-08, labels[:,ci].max()=8.9153e-09
#
# 【 ptend_q0001_27 】
# r2_score=0.040658
# ri=17, ci=87
# preds[ri,ci]=-1.9996e-09, labels[ri,ci]=-5.828e-08
# mse[ri]=3.1674e-15, r2: 1-(mse.mean()=4.0274e-17)/(base.mean()=4.1981e-17)
# y_rms_sub[ci]=9.0964e-09, y_nanmean[ci]=-1.5839e-09, y_lower_bound[ci]=-3.2559e-07, y_upper_bound[ci]=2.2724e-07
# preds[:,ci].mean()=-7.9467e-10, preds[:,ci].min()=-2.6464e-09, preds[:,ci].max()=2.4134e-09
# labels[:,ci].mean()=-1.302e-09, labels[:,ci].min()=-5.828e-08, labels[:,ci].max()=9.6277e-09
#
# 【 ptend_q0001_28 】
# r2_score=0.043811
# ri=17, ci=88
# preds[ri,ci]=-2.6013e-09, labels[ri,ci]=-8.1704e-08
# mse[ri]=6.2573e-15, r2: 1-(mse.mean()=7.6059e-17)/(base.mean()=7.9544e-17)
# y_rms_sub[ci]=1.1273e-08, y_nanmean[ci]=-1.9651e-09, y_lower_bound[ci]=-3.4603e-07, y_upper_bound[ci]=2.6607e-07
# preds[:,ci].mean()=-9.5905e-10, preds[:,ci].min()=-3.4136e-09, preds[:,ci].max()=2.9684e-09
# labels[:,ci].mean()=-1.5634e-09, labels[:,ci].min()=-8.1704e-08, labels[:,ci].max()=2.6897e-08
#
# 【 ptend_q0001_29 】
# r2_score=0.1197
# ri=17, ci=89
# preds[ri,ci]=-5.9011e-09, labels[ri,ci]=-9.2355e-08
# mse[ri]=7.4743e-15, r2: 1-(mse.mean()=9.2758e-17)/(base.mean()=1.0537e-16)
# y_rms_sub[ci]=1.3547e-08, y_nanmean[ci]=-2.3255e-09, y_lower_bound[ci]=-4.0701e-07, y_upper_bound[ci]=2.938e-07
# preds[:,ci].mean()=-1.2132e-09, preds[:,ci].min()=-7.9541e-09, preds[:,ci].max()=3.7369e-09
# labels[:,ci].mean()=-1.7947e-09, labels[:,ci].min()=-9.2355e-08, labels[:,ci].max()=5.2318e-08
#
# 【 ptend_q0001_30 】
# r2_score=0.095119
# ri=17, ci=90
# preds[ri,ci]=-7.7215e-09, labels[ri,ci]=-9.9644e-08
# mse[ri]=8.4498e-15, r2: 1-(mse.mean()=1.137e-16)/(base.mean()=1.2565e-16)
# y_rms_sub[ci]=1.5719e-08, y_nanmean[ci]=-2.663e-09, y_lower_bound[ci]=-4.0844e-07, y_upper_bound[ci]=3.1104e-07
# preds[:,ci].mean()=-2.1744e-09, preds[:,ci].min()=-1.151e-08, preds[:,ci].max()=4.5408e-09
# labels[:,ci].mean()=-1.9807e-09, labels[:,ci].min()=-9.9644e-08, labels[:,ci].max()=1.9616e-08
#
# 【 ptend_q0001_31 】
# r2_score=0.03297
# ri=82, ci=91
# preds[ri,ci]=-6.4477e-09, labels[ri,ci]=9.725e-08
# mse[ri]=1.0753e-14, r2: 1-(mse.mean()=2.1181e-16)/(base.mean()=2.1903e-16)
# y_rms_sub[ci]=1.7467e-08, y_nanmean[ci]=-2.891e-09, y_lower_bound[ci]=-4.443e-07, y_upper_bound[ci]=3.6882e-07
# preds[:,ci].mean()=-3.0722e-09, preds[:,ci].min()=-1.2816e-08, preds[:,ci].max()=5.2643e-09
# labels[:,ci].mean()=-2.2699e-09, labels[:,ci].min()=-1.0783e-07, labels[:,ci].max()=9.725e-08
#
# 【 ptend_q0001_32 】
# r2_score=0.004401
# ri=82, ci=92
# preds[ri,ci]=-8.6915e-09, labels[ri,ci]=1.7951e-07
# mse[ri]=3.542e-14, r2: 1-(mse.mean()=3.3183e-16)/(base.mean()=3.333e-16)
# y_rms_sub[ci]=1.8876e-08, y_nanmean[ci]=-2.9827e-09, y_lower_bound[ci]=-5.2679e-07, y_upper_bound[ci]=5.0128e-07
# preds[:,ci].mean()=-3.9177e-09, preds[:,ci].min()=-1.3923e-08, preds[:,ci].max()=5.8834e-09
# labels[:,ci].mean()=-2.392e-09, labels[:,ci].min()=-1.1005e-07, labels[:,ci].max()=1.7951e-07
#
# 【 ptend_q0001_33 】
# r2_score=0.0024416
# ri=82, ci=93
# preds[ri,ci]=-1.0032e-08, labels[ri,ci]=1.7463e-07
# mse[ri]=3.4102e-14, r2: 1-(mse.mean()=3.4599e-16)/(base.mean()=3.4683e-16)
# y_rms_sub[ci]=2.014e-08, y_nanmean[ci]=-2.9461e-09, y_lower_bound[ci]=-5.335e-07, y_upper_bound[ci]=5.7642e-07
# preds[:,ci].mean()=-4.6031e-09, preds[:,ci].min()=-1.4454e-08, preds[:,ci].max()=6.5859e-09
# labels[:,ci].mean()=-2.8552e-09, labels[:,ci].min()=-1.3512e-07, labels[:,ci].max()=1.7463e-07
#
# 【 ptend_q0001_34 】
# r2_score=-0.013412
# ri=17, ci=94
# preds[ri,ci]=-1.02e-08, labels[ri,ci]=-1.2276e-07
# mse[ri]=1.267e-14, r2: 1-(mse.mean()=3.3532e-16)/(base.mean()=3.3088e-16)
# y_rms_sub[ci]=2.1485e-08, y_nanmean[ci]=-2.8255e-09, y_lower_bound[ci]=-5.5964e-07, y_upper_bound[ci]=4.8333e-07
# preds[:,ci].mean()=-5.088e-09, preds[:,ci].min()=-1.5084e-08, preds[:,ci].max()=7.5482e-09
# labels[:,ci].mean()=-2.8731e-09, labels[:,ci].min()=-1.2276e-07, labels[:,ci].max()=8.9059e-08
#
# 【 ptend_q0001_35 】
# r2_score=-0.10345
# ri=17, ci=95
# preds[ri,ci]=-1.1602e-08, labels[ri,ci]=-1.4686e-07
# mse[ri]=1.8294e-14, r2: 1-(mse.mean()=4.0144e-16)/(base.mean()=3.6381e-16)
# y_rms_sub[ci]=2.3166e-08, y_nanmean[ci]=-2.6786e-09, y_lower_bound[ci]=-6.6163e-07, y_upper_bound[ci]=5.6411e-07
# preds[:,ci].mean()=-5.7737e-09, preds[:,ci].min()=-1.6053e-08, preds[:,ci].max()=8.6003e-09
# labels[:,ci].mean()=-1.9812e-09, labels[:,ci].min()=-1.4686e-07, labels[:,ci].max()=7.159e-08
#
# 【 ptend_q0001_36 】
# r2_score=-0.051578
# ri=194, ci=96
# preds[ri,ci]=-1.3204e-08, labels[ri,ci]=-1.7617e-07
# mse[ri]=2.6559e-14, r2: 1-(mse.mean()=5.354e-16)/(base.mean()=5.0914e-16)
# y_rms_sub[ci]=2.5173e-08, y_nanmean[ci]=-2.5211e-09, y_lower_bound[ci]=-7.6651e-07, y_upper_bound[ci]=6.3436e-07
# preds[:,ci].mean()=-6.0176e-09, preds[:,ci].min()=-1.7141e-08, preds[:,ci].max()=9.3363e-09
# labels[:,ci].mean()=-3.4817e-09, labels[:,ci].min()=-1.7617e-07, labels[:,ci].max()=1.231e-07
#
# 【 ptend_q0001_37 】
# r2_score=-0.036238
# ri=82, ci=97
# preds[ri,ci]=-1.2907e-08, labels[ri,ci]=-2.5789e-07
# mse[ri]=6.0019e-14, r2: 1-(mse.mean()=6.5151e-16)/(base.mean()=6.2873e-16)
# y_rms_sub[ci]=2.7535e-08, y_nanmean[ci]=-2.3596e-09, y_lower_bound[ci]=-7.6925e-07, y_upper_bound[ci]=8.8967e-07
# preds[:,ci].mean()=-6.6539e-09, preds[:,ci].min()=-1.8204e-08, preds[:,ci].max()=1.0244e-08
# labels[:,ci].mean()=-3.3825e-09, labels[:,ci].min()=-2.5789e-07, labels[:,ci].max()=8.1877e-08
#
# 【 ptend_q0001_38 】
# r2_score=-0.065417
# ri=82, ci=98
# preds[ri,ci]=-7.9762e-09, labels[ri,ci]=-2.3099e-07
# mse[ri]=4.9737e-14, r2: 1-(mse.mean()=7.4353e-16)/(base.mean()=6.9788e-16)
# y_rms_sub[ci]=3.025e-08, y_nanmean[ci]=-2.1801e-09, y_lower_bound[ci]=-7.2448e-07, y_upper_bound[ci]=8.4434e-07
# preds[:,ci].mean()=-6.5744e-09, preds[:,ci].min()=-1.9953e-08, preds[:,ci].max()=1.1435e-08
# labels[:,ci].mean()=-2.7354e-09, labels[:,ci].min()=-2.3099e-07, labels[:,ci].max()=1.8856e-07
#
# 【 ptend_q0001_39 】
# r2_score=-0.061439
# ri=82, ci=99
# preds[ri,ci]=-3.9448e-09, labels[ri,ci]=-2.8349e-07
# mse[ri]=7.8146e-14, r2: 1-(mse.mean()=9.4141e-16)/(base.mean()=8.8692e-16)
# y_rms_sub[ci]=3.3479e-08, y_nanmean[ci]=-1.9747e-09, y_lower_bound[ci]=-9.9134e-07, y_upper_bound[ci]=1.0146e-06
# preds[:,ci].mean()=-6.5214e-09, preds[:,ci].min()=-2.1431e-08, preds[:,ci].max()=1.2504e-08
# labels[:,ci].mean()=-1.4563e-09, labels[:,ci].min()=-2.8349e-07, labels[:,ci].max()=2.2414e-07
#
# 【 ptend_q0001_40 】
# r2_score=-0.11252
# ri=103, ci=100
# preds[ri,ci]=-1.5124e-08, labels[ri,ci]=2.3079e-07
# mse[ri]=6.0476e-14, r2: 1-(mse.mean()=8.286e-16)/(base.mean()=7.4479e-16)
# y_rms_sub[ci]=3.7061e-08, y_nanmean[ci]=-1.7037e-09, y_lower_bound[ci]=-9.3931e-07, y_upper_bound[ci]=9.5089e-07
# preds[:,ci].mean()=-6.4755e-09, preds[:,ci].min()=-2.2905e-08, preds[:,ci].max()=1.5359e-08
# labels[:,ci].mean()=-2.1072e-09, labels[:,ci].min()=-1.4775e-07, labels[:,ci].max()=2.3079e-07
#
# 【 ptend_q0001_41 】
# r2_score=-0.082023
# ri=81, ci=101
# preds[ri,ci]=-1.0345e-08, labels[ri,ci]=1.9272e-07
# mse[ri]=4.1236e-14, r2: 1-(mse.mean()=9.6915e-16)/(base.mean()=8.9569e-16)
# y_rms_sub[ci]=4.0956e-08, y_nanmean[ci]=-1.3449e-09, y_lower_bound[ci]=-8.7615e-07, y_upper_bound[ci]=8.9419e-07
# preds[:,ci].mean()=-6.8391e-09, preds[:,ci].min()=-2.4598e-08, preds[:,ci].max()=1.6927e-08
# labels[:,ci].mean()=-2.1357e-09, labels[:,ci].min()=-1.9039e-07, labels[:,ci].max()=1.9272e-07
#
# 【 ptend_q0001_42 】
# r2_score=-0.071858
# ri=167, ci=102
# preds[ri,ci]=5.7609e-11, labels[ri,ci]=2.5387e-07
# mse[ri]=6.4422e-14, r2: 1-(mse.mean()=1.3087e-15)/(base.mean()=1.2209e-15)
# y_rms_sub[ci]=4.4896e-08, y_nanmean[ci]=-8.726e-10, y_lower_bound[ci]=-9.603e-07, y_upper_bound[ci]=9.9325e-07
# preds[:,ci].mean()=-7.0998e-09, preds[:,ci].min()=-2.6604e-08, preds[:,ci].max()=1.8843e-08
# labels[:,ci].mean()=-2.5686e-09, labels[:,ci].min()=-2.4723e-07, labels[:,ci].max()=2.5387e-07
#
# 【 ptend_q0001_43 】
# r2_score=-0.071074
# ri=167, ci=103
# preds[ri,ci]=7.6029e-09, labels[ri,ci]=3.7916e-07
# mse[ri]=1.3806e-13, r2: 1-(mse.mean()=2.1984e-15)/(base.mean()=2.0526e-15)
# y_rms_sub[ci]=4.8654e-08, y_nanmean[ci]=-2.2778e-10, y_lower_bound[ci]=-9.0712e-07, y_upper_bound[ci]=1.0398e-06
# preds[:,ci].mean()=-7.172e-09, preds[:,ci].min()=-2.8006e-08, preds[:,ci].max()=2.1838e-08
# labels[:,ci].mean()=-1.4112e-09, labels[:,ci].min()=-3.0065e-07, labels[:,ci].max()=3.7916e-07
#
# 【 ptend_q0001_44 】
# r2_score=-0.11278
# ri=82, ci=104
# preds[ri,ci]=-3.4956e-09, labels[ri,ci]=-3.1519e-07
# mse[ri]=9.7155e-14, r2: 1-(mse.mean()=2.1188e-15)/(base.mean()=1.9041e-15)
# y_rms_sub[ci]=5.2039e-08, y_nanmean[ci]=4.7601e-10, y_lower_bound[ci]=-9.7192e-07, y_upper_bound[ci]=1.0122e-06
# preds[:,ci].mean()=-7.4802e-09, preds[:,ci].min()=-2.9474e-08, preds[:,ci].max()=2.4461e-08
# labels[:,ci].mean()=5.7802e-10, labels[:,ci].min()=-3.1519e-07, labels[:,ci].max()=2.657e-07
#
# 【 ptend_q0001_45 】
# r2_score=-0.08908
# ri=82, ci=105
# preds[ri,ci]=-5.4325e-09, labels[ri,ci]=-3.004e-07
# mse[ri]=8.7005e-14, r2: 1-(mse.mean()=2.2885e-15)/(base.mean()=2.1014e-15)
# y_rms_sub[ci]=5.5043e-08, y_nanmean[ci]=1.0514e-09, y_lower_bound[ci]=-8.972e-07, y_upper_bound[ci]=9.589e-07
# preds[:,ci].mean()=-7.1333e-09, preds[:,ci].min()=-3.02e-08, preds[:,ci].max()=2.7095e-08
# labels[:,ci].mean()=1.3846e-09, labels[:,ci].min()=-3.004e-07, labels[:,ci].max()=1.8135e-07
#
# 【 ptend_q0001_46 】
# r2_score=-0.10054
# ri=103, ci=106
# preds[ri,ci]=-1.1481e-08, labels[ri,ci]=-4.1062e-07
# mse[ri]=1.5931e-13, r2: 1-(mse.mean()=2.2931e-15)/(base.mean()=2.0836e-15)
# y_rms_sub[ci]=5.7137e-08, y_nanmean[ci]=1.2363e-09, y_lower_bound[ci]=-1.0587e-06, y_upper_bound[ci]=9.1807e-07
# preds[:,ci].mean()=-7.4358e-09, preds[:,ci].min()=-3.1502e-08, preds[:,ci].max()=2.9259e-08
# labels[:,ci].mean()=-9.0801e-10, labels[:,ci].min()=-4.1062e-07, labels[:,ci].max()=1.5438e-07
#
# 【 ptend_q0001_47 】
# r2_score=-0.073726
# ri=103, ci=107
# preds[ri,ci]=-1.3739e-08, labels[ri,ci]=-4.3811e-07
# mse[ri]=1.8009e-13, r2: 1-(mse.mean()=2.9348e-15)/(base.mean()=2.7333e-15)
# y_rms_sub[ci]=5.8241e-08, y_nanmean[ci]=9.2195e-10, y_lower_bound[ci]=-1.0514e-06, y_upper_bound[ci]=9.0348e-07
# preds[:,ci].mean()=-7.2293e-09, preds[:,ci].min()=-3.1889e-08, preds[:,ci].max()=3.0564e-08
# labels[:,ci].mean()=-3.0792e-09, labels[:,ci].min()=-4.3811e-07, labels[:,ci].max()=1.4717e-07
#
# 【 ptend_q0001_48 】
# r2_score=-0.11435
# ri=230, ci=108
# preds[ri,ci]=-1.5995e-09, labels[ri,ci]=2.1748e-07
# mse[ri]=4.7997e-14, r2: 1-(mse.mean()=2.3692e-15)/(base.mean()=2.1261e-15)
# y_rms_sub[ci]=5.8805e-08, y_nanmean[ci]=2.9053e-10, y_lower_bound[ci]=-1.0252e-06, y_upper_bound[ci]=8.3972e-07
# preds[:,ci].mean()=-7.6128e-09, preds[:,ci].min()=-3.2216e-08, preds[:,ci].max()=2.8858e-08
# labels[:,ci].mean()=1.6762e-09, labels[:,ci].min()=-2.0368e-07, labels[:,ci].max()=2.1748e-07
#
# 【 ptend_q0001_49 】
# r2_score=-0.090918
# ri=160, ci=109
# preds[ri,ci]=-1.1038e-08, labels[ri,ci]=2.5413e-07
# mse[ri]=7.0313e-14, r2: 1-(mse.mean()=2.8643e-15)/(base.mean()=2.6256e-15)
# y_rms_sub[ci]=5.8829e-08, y_nanmean[ci]=-6.6154e-10, y_lower_bound[ci]=-9.4239e-07, y_upper_bound[ci]=8.9551e-07
# preds[:,ci].mean()=-7.8998e-09, preds[:,ci].min()=-3.3157e-08, preds[:,ci].max()=3.0002e-08
# labels[:,ci].mean()=3.3939e-09, labels[:,ci].min()=-2.4577e-07, labels[:,ci].max()=2.5413e-07
#
# 【 ptend_q0001_50 】
# r2_score=-0.04554
# ri=97, ci=110
# preds[ri,ci]=-7.2917e-09, labels[ri,ci]=2.8734e-07
# mse[ri]=8.6806e-14, r2: 1-(mse.mean()=3.3612e-15)/(base.mean()=3.2148e-15)
# y_rms_sub[ci]=5.8538e-08, y_nanmean[ci]=-2.0496e-09, y_lower_bound[ci]=-8.7095e-07, y_upper_bound[ci]=8.4133e-07
# preds[:,ci].mean()=-9.1388e-09, preds[:,ci].min()=-3.4112e-08, preds[:,ci].max()=2.9393e-08
# labels[:,ci].mean()=1.4027e-09, labels[:,ci].min()=-2.6873e-07, labels[:,ci].max()=2.8734e-07
#
# 【 ptend_q0001_51 】
# r2_score=-0.025951
# ri=199, ci=111
# preds[ri,ci]=-3.6729e-09, labels[ri,ci]=2.8855e-07
# mse[ri]=8.5395e-14, r2: 1-(mse.mean()=2.915e-15)/(base.mean()=2.8412e-15)
# y_rms_sub[ci]=5.8045e-08, y_nanmean[ci]=-4.2078e-09, y_lower_bound[ci]=-9.0819e-07, y_upper_bound[ci]=7.3955e-07
# preds[:,ci].mean()=-1.0783e-08, preds[:,ci].min()=-3.6626e-08, preds[:,ci].max()=2.7927e-08
# labels[:,ci].mean()=-3.6773e-09, labels[:,ci].min()=-2.4088e-07, labels[:,ci].max()=2.8855e-07
#
# 【 ptend_q0001_52 】
# r2_score=-0.039374
# ri=168, ci=112
# preds[ri,ci]=-8.1903e-09, labels[ri,ci]=2.7796e-07
# mse[ri]=8.188e-14, r2: 1-(mse.mean()=3.0789e-15)/(base.mean()=2.9623e-15)
# y_rms_sub[ci]=5.732e-08, y_nanmean[ci]=-7.438e-09, y_lower_bound[ci]=-8.7412e-07, y_upper_bound[ci]=7.6979e-07
# preds[:,ci].mean()=-1.3005e-08, preds[:,ci].min()=-3.9473e-08, preds[:,ci].max()=2.293e-08
# labels[:,ci].mean()=-6.1258e-09, labels[:,ci].min()=-2.5964e-07, labels[:,ci].max()=2.7796e-07
#
# 【 ptend_q0001_53 】
# r2_score=-0.07298
# ri=166, ci=113
# preds[ri,ci]=-1.7919e-08, labels[ri,ci]=3.8548e-07
# mse[ri]=1.6273e-13, r2: 1-(mse.mean()=3.4517e-15)/(base.mean()=3.2169e-15)
# y_rms_sub[ci]=5.6315e-08, y_nanmean[ci]=-1.1539e-08, y_lower_bound[ci]=-8.6636e-07, y_upper_bound[ci]=6.3594e-07
# ...
# y_rms_sub[ci]=7.0901e-06, y_nanmean[ci]=3.303e-08, y_lower_bound[ci]=-0.00045441, y_upper_bound[ci]=0.00043063
# preds[:,ci].mean()=-3.6201e-07, preds[:,ci].min()=-3.2412e-06, preds[:,ci].max()=3.2338e-06
# labels[:,ci].mean()=2.0209e-07, labels[:,ci].min()=-4.8216e-05, labels[:,ci].max()=6.2858e-05
#
# 【 ptend_v_34 】
# r2_score=-0.12734
# ri=219, ci=334
# preds[ri,ci]=-2.7729e-06, labels[ri,ci]=4.6167e-05
# mse[ri]=2.3952e-09, r2: 1-(mse.mean()=3.0364e-11)/(base.mean()=2.6934e-11)
# y_rms_sub[ci]=6.8327e-06, y_nanmean[ci]=2.9465e-08, y_lower_bound[ci]=-0.00062345, y_upper_bound[ci]=0.00043808
# preds[:,ci].mean()=-4.079e-07, preds[:,ci].min()=-3.3593e-06, preds[:,ci].max()=2.6243e-06
# labels[:,ci].mean()=2.0877e-07, labels[:,ci].min()=-2.6223e-05, labels[:,ci].max()=4.6167e-05
#
# 【 ptend_v_35 】
# r2_score=-0.05128
# ri=220, ci=335
# preds[ri,ci]=-1.6875e-06, labels[ri,ci]=-6.3182e-05
# mse[ri]=3.7816e-09, r2: 1-(mse.mean()=4.3419e-11)/(base.mean()=4.1301e-11)
# y_rms_sub[ci]=6.8515e-06, y_nanmean[ci]=4.2831e-09, y_lower_bound[ci]=-0.00057385, y_upper_bound[ci]=0.00042941
# preds[:,ci].mean()=-6.0382e-07, preds[:,ci].min()=-3.2944e-06, preds[:,ci].max()=2.8015e-06
# labels[:,ci].mean()=-1.9736e-07, labels[:,ci].min()=-6.3182e-05, labels[:,ci].max()=4.3095e-05
#
# 【 ptend_v_36 】
# r2_score=-0.1052
# ri=82, ci=336
# preds[ri,ci]=-1.5793e-06, labels[ri,ci]=-5.3384e-05
# mse[ri]=2.6837e-09, r2: 1-(mse.mean()=2.6998e-11)/(base.mean()=2.4429e-11)
# y_rms_sub[ci]=7.1686e-06, y_nanmean[ci]=-6.574e-08, y_lower_bound[ci]=-0.0006454, y_upper_bound[ci]=0.00055903
# preds[:,ci].mean()=-7.6582e-07, preds[:,ci].min()=-3.5601e-06, preds[:,ci].max()=2.8158e-06
# labels[:,ci].mean()=-1.9005e-07, labels[:,ci].min()=-5.3384e-05, labels[:,ci].max()=2.1006e-05
#
# 【 ptend_v_37 】
# r2_score=-0.060375
# ri=82, ci=337
# preds[ri,ci]=-1.8772e-06, labels[ri,ci]=-6.7282e-05
# mse[ri]=4.2778e-09, r2: 1-(mse.mean()=3.3481e-11)/(base.mean()=3.1574e-11)
# y_rms_sub[ci]=7.7816e-06, y_nanmean[ci]=-1.6071e-07, y_lower_bound[ci]=-0.00056502, y_upper_bound[ci]=0.00052773
# preds[:,ci].mean()=-1.0426e-06, preds[:,ci].min()=-4.0326e-06, preds[:,ci].max()=2.9067e-06
# labels[:,ci].mean()=-4.7347e-07, labels[:,ci].min()=-6.7282e-05, labels[:,ci].max()=1.7031e-05
#
# 【 ptend_v_38 】
# r2_score=-0.082665
# ri=82, ci=338
# preds[ri,ci]=-1.4135e-06, labels[ri,ci]=-6.2198e-05
# mse[ri]=3.6947e-09, r2: 1-(mse.mean()=4.1542e-11)/(base.mean()=3.837e-11)
# y_rms_sub[ci]=8.5715e-06, y_nanmean[ci]=-2.4989e-07, y_lower_bound[ci]=-0.00052173, y_upper_bound[ci]=0.00053076
# preds[:,ci].mean()=-1.1828e-06, preds[:,ci].min()=-4.3035e-06, preds[:,ci].max()=3.165e-06
# labels[:,ci].mean()=-5.6622e-07, labels[:,ci].min()=-6.2198e-05, labels[:,ci].max()=2.3098e-05
#
# 【 ptend_v_39 】
# r2_score=-0.11047
# ri=82, ci=339
# preds[ri,ci]=-1.2018e-06, labels[ri,ci]=-8.166e-05
# mse[ri]=6.4735e-09, r2: 1-(mse.mean()=4.9075e-11)/(base.mean()=4.4193e-11)
# y_rms_sub[ci]=9.3059e-06, y_nanmean[ci]=-3.0568e-07, y_lower_bound[ci]=-0.00055067, y_upper_bound[ci]=0.00047858
# preds[:,ci].mean()=-1.3842e-06, preds[:,ci].min()=-5.0173e-06, preds[:,ci].max()=3.7687e-06
# labels[:,ci].mean()=-6.7341e-07, labels[:,ci].min()=-8.166e-05, labels[:,ci].max()=1.6543e-05
#
# 【 ptend_v_40 】
# r2_score=-0.096619
# ri=82, ci=340
# preds[ri,ci]=-9.8472e-07, labels[ri,ci]=-0.00010617
# mse[ri]=1.1065e-08, r2: 1-(mse.mean()=6.9305e-11)/(base.mean()=6.3198e-11)
# y_rms_sub[ci]=9.9741e-06, y_nanmean[ci]=-3.0786e-07, y_lower_bound[ci]=-0.0005536, y_upper_bound[ci]=0.00043664
# preds[:,ci].mean()=-1.5395e-06, preds[:,ci].min()=-5.1902e-06, preds[:,ci].max()=3.6976e-06
# labels[:,ci].mean()=-8.8488e-07, labels[:,ci].min()=-0.00010617, labels[:,ci].max()=1.5165e-05
#
# 【 ptend_v_41 】
# r2_score=-0.088582
# ri=82, ci=341
# preds[ri,ci]=-9.1399e-07, labels[ri,ci]=-0.00012316
# mse[ri]=1.4944e-08, r2: 1-(mse.mean()=8.7458e-11)/(base.mean()=8.0341e-11)
# y_rms_sub[ci]=1.0626e-05, y_nanmean[ci]=-2.303e-07, y_lower_bound[ci]=-0.00053878, y_upper_bound[ci]=0.00051859
# preds[:,ci].mean()=-1.6207e-06, preds[:,ci].min()=-5.6321e-06, preds[:,ci].max()=3.4537e-06
# labels[:,ci].mean()=-1.1383e-06, labels[:,ci].min()=-0.00012316, labels[:,ci].max()=2.7765e-05
#
# 【 ptend_v_42 】
# r2_score=-0.074371
# ri=82, ci=342
# preds[ri,ci]=-8.4851e-07, labels[ri,ci]=-0.00010856
# mse[ri]=1.1601e-08, r2: 1-(mse.mean()=1.3846e-10)/(base.mean()=1.2888e-10)
# y_rms_sub[ci]=1.1307e-05, y_nanmean[ci]=-8.6547e-08, y_lower_bound[ci]=-0.00061905, y_upper_bound[ci]=0.00061273
# preds[:,ci].mean()=-1.6192e-06, preds[:,ci].min()=-5.7145e-06, preds[:,ci].max()=3.974e-06
# labels[:,ci].mean()=-1.5595e-06, labels[:,ci].min()=-0.00010856, labels[:,ci].max()=5.7267e-05
#
# 【 ptend_v_43 】
# r2_score=-0.08172
# ri=379, ci=343
# preds[ri,ci]=1.5386e-06, labels[ri,ci]=-0.00012075
# mse[ri]=1.4956e-08, r2: 1-(mse.mean()=1.2274e-10)/(base.mean()=1.1347e-10)
# y_rms_sub[ci]=1.2087e-05, y_nanmean[ci]=1.0501e-07, y_lower_bound[ci]=-0.00050406, y_upper_bound[ci]=0.00063053
# preds[:,ci].mean()=-1.6349e-06, preds[:,ci].min()=-5.5551e-06, preds[:,ci].max()=4.3426e-06
# labels[:,ci].mean()=-1.2659e-06, labels[:,ci].min()=-0.00012075, labels[:,ci].max()=3.2007e-05
#
# 【 ptend_v_44 】
# r2_score=-0.087756
# ri=379, ci=344
# preds[ri,ci]=8.0909e-07, labels[ri,ci]=-8.0071e-05
# mse[ri]=6.5415e-09, r2: 1-(mse.mean()=1.0916e-10)/(base.mean()=1.0036e-10)
# y_rms_sub[ci]=1.2977e-05, y_nanmean[ci]=3.0829e-07, y_lower_bound[ci]=-0.00057223, y_upper_bound[ci]=0.00075516
# preds[:,ci].mean()=-1.8238e-06, preds[:,ci].min()=-6.1038e-06, preds[:,ci].max()=3.78e-06
# labels[:,ci].mean()=-1.4676e-06, labels[:,ci].min()=-8.0071e-05, labels[:,ci].max()=3.6178e-05
#
# 【 ptend_v_45 】
# r2_score=-0.053987
# ri=223, ci=345
# preds[ri,ci]=-3.5776e-06, labels[ri,ci]=7.2536e-05
# mse[ri]=5.7933e-09, r2: 1-(mse.mean()=1.2172e-10)/(base.mean()=1.1548e-10)
# y_rms_sub[ci]=1.4019e-05, y_nanmean[ci]=4.772e-07, y_lower_bound[ci]=-0.00055846, y_upper_bound[ci]=0.00055678
# preds[:,ci].mean()=-1.7066e-06, preds[:,ci].min()=-5.803e-06, preds[:,ci].max()=4.6772e-06
# labels[:,ci].mean()=-1.2492e-06, labels[:,ci].min()=-7.3935e-05, labels[:,ci].max()=7.2536e-05
#
# 【 ptend_v_46 】
# r2_score=-0.034561
# ri=99, ci=346
# preds[ri,ci]=-1.278e-06, labels[ri,ci]=-7.7581e-05
# mse[ri]=5.8222e-09, r2: 1-(mse.mean()=1.2069e-10)/(base.mean()=1.1666e-10)
# y_rms_sub[ci]=1.5152e-05, y_nanmean[ci]=5.9757e-07, y_lower_bound[ci]=-0.0004354, y_upper_bound[ci]=0.00074633
# preds[:,ci].mean()=-1.9142e-06, preds[:,ci].min()=-6.3217e-06, preds[:,ci].max()=5.2667e-06
# labels[:,ci].mean()=-1.4461e-06, labels[:,ci].min()=-7.7581e-05, labels[:,ci].max()=5.3763e-05
#
# 【 ptend_v_47 】
# r2_score=0.0014166
# ri=379, ci=347
# preds[ri,ci]=8.2548e-07, labels[ri,ci]=0.00010265
# mse[ri]=1.0368e-08, r2: 1-(mse.mean()=1.8034e-10)/(base.mean()=1.8059e-10)
# y_rms_sub[ci]=1.6181e-05, y_nanmean[ci]=6.1516e-07, y_lower_bound[ci]=-0.00045268, y_upper_bound[ci]=0.00062893
# preds[:,ci].mean()=-1.9459e-06, preds[:,ci].min()=-6.722e-06, preds[:,ci].max()=5.5988e-06
# labels[:,ci].mean()=-1.1942e-06, labels[:,ci].min()=-8.0027e-05, labels[:,ci].max()=0.00010265
#
# 【 ptend_v_48 】
# r2_score=-0.011815
# ri=82, ci=348
# preds[ri,ci]=-3.8011e-06, labels[ri,ci]=7.0916e-05
# mse[ri]=5.5826e-09, r2: 1-(mse.mean()=1.7903e-10)/(base.mean()=1.7694e-10)
# y_rms_sub[ci]=1.7171e-05, y_nanmean[ci]=5.2246e-07, y_lower_bound[ci]=-0.00045699, y_upper_bound[ci]=0.00067173
# preds[:,ci].mean()=-2.161e-06, preds[:,ci].min()=-7.8716e-06, preds[:,ci].max()=6.5995e-06
# labels[:,ci].mean()=-1.6752e-06, labels[:,ci].min()=-6.4954e-05, labels[:,ci].max()=7.0916e-05
#
# 【 ptend_v_49 】
# r2_score=-0.010441
# ri=379, ci=349
# preds[ri,ci]=-1.4117e-06, labels[ri,ci]=0.00013813
# mse[ri]=1.9473e-08, r2: 1-(mse.mean()=3.178e-10)/(base.mean()=3.1452e-10)
# y_rms_sub[ci]=1.8276e-05, y_nanmean[ci]=3.3562e-07, y_lower_bound[ci]=-0.00051215, y_upper_bound[ci]=0.000759
# preds[:,ci].mean()=-2.4331e-06, preds[:,ci].min()=-8.7936e-06, preds[:,ci].max()=7.043e-06
# labels[:,ci].mean()=-7.3413e-07, labels[:,ci].min()=-9.5387e-05, labels[:,ci].max()=0.00013813
#
# 【 ptend_v_50 】
# r2_score=-0.039909
# ri=379, ci=350
# preds[ri,ci]=-3.1861e-06, labels[ri,ci]=0.0001411
# mse[ri]=2.0818e-08, r2: 1-(mse.mean()=4.0383e-10)/(base.mean()=3.8833e-10)
# y_rms_sub[ci]=1.9675e-05, y_nanmean[ci]=9.3188e-08, y_lower_bound[ci]=-0.00054517, y_upper_bound[ci]=0.00066386
# preds[:,ci].mean()=-2.9484e-06, preds[:,ci].min()=-9.4403e-06, preds[:,ci].max()=6.0952e-06
# labels[:,ci].mean()=3.7353e-08, labels[:,ci].min()=-0.00013349, labels[:,ci].max()=0.0001411
#
# 【 ptend_v_51 】
# r2_score=-0.14302
# ri=110, ci=351
# preds[ri,ci]=-1.0246e-05, labels[ri,ci]=0.00012164
# mse[ri]=1.7393e-08, r2: 1-(mse.mean()=4.3299e-10)/(base.mean()=3.7881e-10)
# y_rms_sub[ci]=2.1711e-05, y_nanmean[ci]=-2.0639e-07, y_lower_bound[ci]=-0.00075076, y_upper_bound[ci]=0.00075921
# preds[:,ci].mean()=-3.394e-06, preds[:,ci].min()=-1.0907e-05, preds[:,ci].max()=6.142e-06
# labels[:,ci].mean()=1.3713e-06, labels[:,ci].min()=-0.00012136, labels[:,ci].max()=0.00012164
#
# 【 ptend_v_52 】
# r2_score=-0.28627
# ri=111, ci=352
# preds[ri,ci]=-1.0184e-05, labels[ri,ci]=0.00012228
# mse[ri]=1.7547e-08, r2: 1-(mse.mean()=4.9287e-10)/(base.mean()=3.8318e-10)
# y_rms_sub[ci]=2.4546e-05, y_nanmean[ci]=-6.3433e-07, y_lower_bound[ci]=-0.00094299, y_upper_bound[ci]=0.00050847
# preds[:,ci].mean()=-4.2485e-06, preds[:,ci].min()=-1.2528e-05, preds[:,ci].max()=6.5778e-06
# labels[:,ci].mean()=3.8478e-06, labels[:,ci].min()=-5.8655e-05, labels[:,ci].max()=0.00012228
#
# 【 ptend_v_53 】
# r2_score=-0.35246
# ri=372, ci=353
# preds[ri,ci]=-6.4927e-06, labels[ri,ci]=0.00011684
# mse[ri]=1.5212e-08, r2: 1-(mse.mean()=5.9105e-10)/(base.mean()=4.3702e-10)
# y_rms_sub[ci]=2.7521e-05, y_nanmean[ci]=-9.8461e-07, y_lower_bound[ci]=-0.0011096, y_upper_bound[ci]=0.00066651
# preds[:,ci].mean()=-4.8725e-06, preds[:,ci].min()=-1.4752e-05, preds[:,ci].max()=7.0006e-06
# labels[:,ci].mean()=5.0258e-06, labels[:,ci].min()=-7.82e-05, labels[:,ci].max()=0.00011684
#
# 【 ptend_v_54 】
# r2_score=-0.31707
# ri=238, ci=354
# preds[ri,ci]=-4.9258e-06, labels[ri,ci]=0.00013483
# mse[ri]=1.9531e-08, r2: 1-(mse.mean()=6.8456e-10)/(base.mean()=5.1976e-10)
# y_rms_sub[ci]=2.9428e-05, y_nanmean[ci]=-1.0975e-06, y_lower_bound[ci]=-0.001148, y_upper_bound[ci]=0.00060749
# preds[:,ci].mean()=-4.9382e-06, preds[:,ci].min()=-1.7213e-05, preds[:,ci].max()=7.8973e-06
# labels[:,ci].mean()=5.3723e-06, labels[:,ci].min()=-8.4645e-05, labels[:,ci].max()=0.00013483
#
# 【 ptend_v_55 】
# r2_score=-0.28389
# ri=332, ci=355
# preds[ri,ci]=-1.2145e-05, labels[ri,ci]=0.00015413
# mse[ri]=2.7647e-08, r2: 1-(mse.mean()=6.5228e-10)/(base.mean()=5.0805e-10)
# y_rms_sub[ci]=2.9771e-05, y_nanmean[ci]=-9.9422e-07, y_lower_bound[ci]=-0.00067954, y_upper_bound[ci]=0.0006142
# preds[:,ci].mean()=-4.6115e-06, preds[:,ci].min()=-1.6755e-05, preds[:,ci].max()=7.0375e-06
# labels[:,ci].mean()=4.4225e-06, labels[:,ci].min()=-9.1767e-05, labels[:,ci].max()=0.00015413
#
# 【 ptend_v_56 】
# r2_score=-0.14457
# ri=114, ci=356
# preds[ri,ci]=1.1594e-06, labels[ri,ci]=-0.0001222
# mse[ri]=1.5218e-08, r2: 1-(mse.mean()=5.6218e-10)/(base.mean()=4.9118e-10)
# y_rms_sub[ci]=2.9421e-05, y_nanmean[ci]=-5.0803e-07, y_lower_bound[ci]=-0.00058765, y_upper_bound[ci]=0.00057799
# preds[:,ci].mean()=-3.6721e-06, preds[:,ci].min()=-1.5711e-05, preds[:,ci].max()=7.2713e-06
# labels[:,ci].mean()=1.246e-06, labels[:,ci].min()=-0.0001222, labels[:,ci].max()=0.00010089
#
# 【 ptend_v_57 】
# r2_score=-0.085241
# ri=338, ci=357
# preds[ri,ci]=3.3992e-07, labels[ri,ci]=0.00010133
# mse[ri]=1.02e-08, r2: 1-(mse.mean()=5.2624e-10)/(base.mean()=4.849e-10)
# y_rms_sub[ci]=2.7569e-05, y_nanmean[ci]=6.2312e-07, y_lower_bound[ci]=-0.00048601, y_upper_bound[ci]=0.0004859
# preds[:,ci].mean()=-1.9066e-06, preds[:,ci].min()=-1.2697e-05, preds[:,ci].max()=8.1583e-06
# labels[:,ci].mean()=1.1116e-06, labels[:,ci].min()=-9.8601e-05, labels[:,ci].max()=0.00010133
#
# 【 ptend_v_58 】
# r2_score=-0.079871
# ri=109, ci=358
# preds[ri,ci]=-1.4691e-06, labels[ri,ci]=-0.00013658
# mse[ri]=1.8256e-08, r2: 1-(mse.mean()=5.0312e-10)/(base.mean()=4.6591e-10)
# y_rms_sub[ci]=2.4282e-05, y_nanmean[ci]=1.3958e-06, y_lower_bound[ci]=-0.00055084, y_upper_bound[ci]=0.00050151
# preds[:,ci].mean()=-4.6076e-07, preds[:,ci].min()=-9.3873e-06, preds[:,ci].max()=8.0747e-06
# labels[:,ci].mean()=2.7176e-07, labels[:,ci].min()=-0.00013658, labels[:,ci].max()=8.6003e-05
#
# 【 ptend_v_59 】
# r2_score=0.0038366
# ri=223, ci=359
# preds[ri,ci]=3.8321e-06, labels[ri,ci]=-0.00017631
# mse[ri]=3.245e-08, r2: 1-(mse.mean()=1.0201e-09)/(base.mean()=1.024e-09)
# y_rms_sub[ci]=3.4253e-05, y_nanmean[ci]=6.2858e-07, y_lower_bound[ci]=-0.00077093, y_upper_bound[ci]=0.00073063
# preds[:,ci].mean()=-1.2057e-06, preds[:,ci].min()=-1.6163e-05, preds[:,ci].max()=1.0138e-05
# labels[:,ci].mean()=-1.8412e-06, labels[:,ci].min()=-0.00017631, labels[:,ci].max()=0.0001401
#
# 【 cam_out_NETSW 】
# r2_score=-0.00046325
# ri=132, ci=360
# preds[ri,ci]=157.82, labels[ri,ci]=881.22
# mse[ri]=5.233e+05, r2: 1-(mse.mean()=63354)/(base.mean()=63325)
# y_rms_sub[ci]=246.69, y_nanmean[ci]=158.3, y_lower_bound[ci]=0, y_upper_bound[ci]=1106.7
# preds[:,ci].mean()=157.82, preds[:,ci].min()=157.82, preds[:,ci].max()=157.83
# labels[:,ci].mean()=163.24, labels[:,ci].min()=0, labels[:,ci].max()=881.22
#
# 【 cam_out_FLWDS 】
# r2_score=-0.026932
# ri=361, ci=361
# preds[ri,ci]=351.64, labels[ri,ci]=103.2
# mse[ri]=61724, r2: 1-(mse.mean()=6437.2)/(base.mean()=6268.4)
# y_rms_sub[ci]=72.034, y_nanmean[ci]=351.2, y_lower_bound[ci]=57.218, y_upper_bound[ci]=528.1
# preds[:,ci].mean()=351.64, preds[:,ci].min()=351.64, preds[:,ci].max()=351.64
# labels[:,ci].mean()=338.65, labels[:,ci].min()=103.2, labels[:,ci].max()=446.29
#
# 【 cam_out_PRECSC 】
# r2_score=-0.0066496
# ri=326, ci=362
# preds[ri,ci]=2.6418e-09, labels[ri,ci]=6.3311e-08
# mse[ri]=3.6808e-15, r2: 1-(mse.mean()=6.4091e-17)/(base.mean()=6.3668e-17)
# y_rms_sub[ci]=7.4003e-09, y_nanmean[ci]=2.7387e-09, y_lower_bound[ci]=0, y_upper_bound[ci]=2.9351e-07
# preds[:,ci].mean()=2.6418e-09, preds[:,ci].min()=2.6417e-09, preds[:,ci].max()=2.6419e-09
# labels[:,ci].mean()=3.2925e-09, labels[:,ci].min()=0, labels[:,ci].max()=6.3311e-08
#
# 【 cam_out_PRECC 】
# r2_score=-0.0062553
# ri=147, ci=363
# preds[ri,ci]=3.0124e-08, labels[ri,ci]=4.5577e-07
# mse[ri]=1.8117e-13, r2: 1-(mse.mean()=4.3179e-15)/(base.mean()=4.2911e-15)
# y_rms_sub[ci]=8.1835e-08, y_nanmean[ci]=2.9191e-08, y_lower_bound[ci]=0, y_upper_bound[ci]=2.2007e-06
# preds[:,ci].mean()=3.0124e-08, preds[:,ci].min()=3.0123e-08, preds[:,ci].max()=3.0125e-08
# labels[:,ci].mean()=2.4942e-08, labels[:,ci].min()=0, labels[:,ci].max()=4.5577e-07
#
# 【 cam_out_SOLS 】
# r2_score=-3.5019e-05
# ri=149, ci=364
# preds[ri,ci]=61.731, labels[ri,ci]=418.87
# mse[ri]=1.2754e+05, r2: 1-(mse.mean()=11388)/(base.mean()=11388)
# y_rms_sub[ci]=110.25, y_nanmean[ci]=61.79, y_lower_bound[ci]=0, y_upper_bound[ci]=518.9
# preds[:,ci].mean()=61.731, preds[:,ci].min()=61.73, preds[:,ci].max()=61.733
# labels[:,ci].mean()=61.096, labels[:,ci].min()=0, labels[:,ci].max()=418.87
#
# 【 cam_out_SOLL 】
# r2_score=-8.0895e-05
# ri=132, ci=365
# preds[ri,ci]=69.582, labels[ri,ci]=441.81
# mse[ri]=1.3856e+05, r2: 1-(mse.mean()=13255)/(base.mean()=13254)
# y_rms_sub[ci]=116.42, y_nanmean[ci]=67.31, y_lower_bound[ci]=0, y_upper_bound[ci]=575.26
# preds[:,ci].mean()=69.582, preds[:,ci].min()=69.58, preds[:,ci].max()=69.584
# labels[:,ci].mean()=68.553, labels[:,ci].min()=0, labels[:,ci].max()=441.81
#
# 【 cam_out_SOLSD 】
# r2_score=-0.0002176
# ri=148, ci=366
# preds[ri,ci]=34.266, labels[ri,ci]=203.18
# mse[ri]=28532, r2: 1-(mse.mean()=2163.8)/(base.mean()=2163.4)
# y_rms_sub[ci]=46.432, y_nanmean[ci]=33.474, y_lower_bound[ci]=0, y_upper_bound[ci]=425.18
# preds[:,ci].mean()=34.266, preds[:,ci].min()=34.265, preds[:,ci].max()=34.266
# labels[:,ci].mean()=34.951, labels[:,ci].min()=0, labels[:,ci].max()=203.18
#
# 【 cam_out_SOLLD 】
# r2_score=-1.1634e-05
# ri=133, ci=367
# preds[ri,ci]=17.949, labels[ri,ci]=140.61
# mse[ri]=15046, r2: 1-(mse.mean()=811.81)/(base.mean()=811.8)
# y_rms_sub[ci]=29.733, y_nanmean[ci]=17.693, y_lower_bound[ci]=0, y_upper_bound[ci]=271.07
# preds[:,ci].mean()=17.949, preds[:,ci].min()=17.948, preds[:,ci].max()=17.949
# labels[:,ci].mean()=18.052, labels[:,ci].min()=0, labels[:,ci].max()=140.61
