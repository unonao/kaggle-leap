# %%
# %cd /kaggle/working
import matplotlib.pyplot as plt
import pandas as pd
import polars as pl
import seaborn as sns
# Out:
# /kaggle/working

# %%
test_df = pl.read_csv("input/leap-atmospheric-physics-ai-climsim/test.csv")

# %%
index = 20000

temp = test_df[index, 1:61].transpose(include_header=True)

plt.figure(figsize=(20, 10))

ax = sns.lineplot(temp, x="column", y="column_0")
ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha="right")
plt.tight_layout()
plt.grid() 
plt.show()
# Out:
# /tmp/ipykernel_4347/1391209388.py:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha="right")
